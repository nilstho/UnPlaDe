# %% [markdown]
# # Uncertainty calculation of plastic emission fate factors (FF)
#
# In this notebook the uncertainty and distribution of plastic emission fate factors is conducted. Therefore, the following approach is followed:
# 1. Import and handling/parsing of the excel sheet named *Supplementary Material 2.xlsx*
# 2. Calculation of the [coefficient of variation](https://en.wikipedia.org/wiki/Coefficient_of_variation) and cleaning of the dataframe
# 3. Setting a dataframe called (df_SSDR_new) which includes all the necessary stuff for calculation
# 4. Calculation of the average SSDR for all polymer types and compartments where
#     * column 'SSDR expert judgment based on' not equals Exp+compatment leading to df_SSDR_basic
#     * column 'SSDR expert judgment based on' equals Exp+compartment lead to df_exp
#     * merging of the to dataframes to retrieve the SSDR with uncertainty dataframe (df_SSDR)
# 5.

# %%
# importing the usual stuff
import random
import scipy
from scipy import stats, optimize, interpolate
from scipy.stats import skew, gmean, gstd
from statistics import geometric_mean
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import time
import re
import seaborn as sns
from openpyxl import load_workbook
import matplotlib.gridspec as gridspec
from matplotlib.lines import Line2D

TodaysDate = time.strftime("%Y%m%d")

# %% [markdown]
# ## Defining the function for calculating the coefficient of variation (CV) using the predefined data quality indicators and calculating CVs for each data point

# %%
# defining function for CV calculation
def CV(rel, comp1, comp2, temp, geo, mea, exp):
    # function depended on the DQIS for reliability, completeness 1,
    # completeness2, temporal correlation, geographical correlation,
    # and mearuement method. Expert judgments are handled differently
    a_rel = 0.75  # a parameters b parameter defined as explained in manuscript
    a_comp1 = 1.5
    a_comp2 = 1.5
    a_temp = 0.375
    a_geo = 1.5
    a_mea = 1.5
    a_exp = 2.5
    b = 1.105
    if exp == 0:
        # calculates all CVs for the data points expect for the ones which
        # are based on expert judgment
        CV_rel = a_rel*math.exp(b*rel)
        if comp1 == 1:
            # if comp1 is 1 then CV is 0 this is the case as it is assumed
            # that there is no uncertainty when DQIS is 1 in the comp1
            CV_comp1 = 0
        else:
            CV_comp1 = a_comp1*math.exp(b*(comp1-1))
        if comp2 == 1:
            CV_comp2 = 0
        else:
            CV_comp2 = a_comp2*math.exp(b*(comp2-1))
        if temp == 1:
            CV_temp = 0
        else:
            CV_temp = a_temp*math.exp(b*(temp-1))
        if geo == 1:
            CV_geo = 0
        else:
            CV_geo = a_geo*math.exp(b*(geo-1))
        CV_mea = a_mea*math.exp(b*mea)
        # sum of all
        return math.sqrt(((CV_rel/100)**2+1) * ((CV_comp1/100)**2+1) *
                         ((CV_comp2/100)**2+1) * ((CV_temp/100)**2+1) *
                         ((CV_geo/100)**2+1) * ((CV_mea/100)**2+1)-1)
    # CV squares and the square root to calculate the total CV for
    # the data point under investigation
    else:
        # calulation of CV if an expert judgment
        # was applied for data generation
        return a_exp*math.exp(b*exp)/100

# %%
# reading excel file with name "Supplementary Material 2.xlsx"
# and calculating CV relying on DQIS
df = pd.read_excel('Supplementary Material 2.xlsx',
                   sheet_name='DQ of SSDR', skiprows=2)
df['CV'] = df.apply(lambda row: CV(float(row['DQIS_rel']),
                                   float(row['DQIS_comp1']),
                                   float(row['DQIS_comp2']),
                                   float(row['DQIS_temp']),
                                   float(row['DQIS_geo']),
                                   float(row['DQIS_mea']),
                                   float(row['DQIS_exp'])), axis=1)

# %%
# Creating an excel file with the original data and the calculated CVs
excel_name = TodaysDate + '_fate_factor_calculation.xlsx'
writer = pd.ExcelWriter(excel_name, engine='openpyxl')
df.to_excel(writer, sheet_name='Original_with_CV', index=False)
writer.save()

# %%
# get a list of all polymers used in the excel file
poly = df['Polymer type'].unique().tolist()
# get a list of all compartments in the excel file and remove
# fresh water as it is not considered in further calculations
comp = df['Compartment'].unique().tolist()
# comp.remove('fresh water')
# create a new dataframe with only the colums of
# polymer type, compartment, SSDR, CV and Uncertainty
df_SSDR_new = pd.DataFrame(columns=['Polymer type', 'Compartment', 'SSDR',
                                    'CV', 'SSDR expert judgment based on'])
# generating a reduced df (df_poly_reduced) for each polymer
# and each compartment containing polymer type, compartment,
# SSDR, CV, Uncertainty
for polymer in poly:
    df_poly_reduced = df.loc[(df['Polymer type'] == polymer), ['Polymer type',
                                                               'Compartment',
                                                               'SSDR',
                                                               'CV',
                                                               'SSDR expert judgment based on']]
    for compartment in comp:
        df_poly_comp_reduced = df_poly_reduced.loc[(
            df_poly_reduced['Compartment'] == compartment), :]
        # finding the lowest CV
        min_CV = df_poly_comp_reduced['CV'].min()
        # finding the number how often the minimal CV occurs
        num_min_CV = df_poly_comp_reduced.CV.value_counts()[min_CV]
        # Difference between cases were the number of minimal
        # CVs occurs is equal to one or not
        if num_min_CV == 1:
            # retrieving SSDR for min_CV value from dataframe (df_poly_reduced)
            # and adding this to the dataframe (df_SSDR_new)
            df_poly_comp_reduced = df_poly_comp_reduced.loc[(
                df_poly_comp_reduced['CV'] == min_CV), :]
            df_SSDR_new.loc[len(df_SSDR_new.index)] = [polymer, compartment,
                                                       df_poly_comp_reduced.values[0][2],
                                                       df_poly_comp_reduced.values[0][3],
                                                       df_poly_comp_reduced.values[0][4]]
        else:
            # same as in the if statetment but using mean of SSDR
            # because SSDR is occuring several times with the same min_CV value
            df_poly_comp_reduced = df_poly_comp_reduced.loc[(
                df_poly_comp_reduced['CV'] == min_CV), :]
            SSDR = scipy.stats.gmean(df_poly_comp_reduced['SSDR'])
            df_SSDR_new.loc[len(df_SSDR_new.index)] = [
                polymer, compartment, SSDR, min_CV, 'NaN']
df_SSDR_new
# Out:
#     Polymer type      Compartment        SSDR        CV  \
# 0           HDPE  marine sediment   11.703125  0.227893
# 1           HDPE     marine water   11.699359  0.630773
# 2           HDPE   river sediment   11.703125  0.227893
# 3           HDPE             soil   11.703125  0.227893
# 4           LDPE  marine sediment    0.706833  0.472005
# ..           ...              ...         ...       ...
# 91           PVC             soil    0.001000  2.077407
# 92  Starch-blend  marine sediment   42.740047  0.227893
# 93  Starch-blend     marine water  101.290255  0.146425
# 94  Starch-blend   river sediment   42.740047  0.227893
# 95  Starch-blend             soil   42.740047  0.240464
#
#    SSDR expert judgment based on
# 0               EXP+marine water
# 1                            NaN
# 2               EXP+marine water
# 3               EXP+marine water
# 4                            NaN
# ..                           ...
# 91                           NaN
# 92                      EXP+soil
# 93                           NaN
# 94                      EXP+soil
# 95                           NaN
#
# [96 rows x 5 columns]

# %%
# setting a list which includes only expert estimates
# and the compartment which they rely on and build dataframes
exp = ['EXP+marine water', 'EXP+marine sediment',
       'EXP+soil', 'EXP+river sediment']
df_SSDR_basic = df_SSDR_new.loc[~df_SSDR_new['SSDR expert judgment based on']
                                .isin(exp)]
df_SSDR_exp = df_SSDR_new.loc[df_SSDR_new['SSDR expert judgment based on']
                              .isin(exp)]

# creating of several dictionaries which will be
# filled for the expert judgment uncertainty
CV_dict_exp = dict()
CV_dict_basic = dict()
SSDR_dict_exp = dict()

# filling the CV_dict_basic dictionary with the names
# and SSDR for already set polymer types and compartments
for i in range(0, len(df_SSDR_basic)):
    name_basic = df_SSDR_basic.iloc[i]['Polymer type'] + \
        ', ' + df_SSDR_basic.iloc[i]['Compartment']
    CV_dict_basic[name_basic] = (
        df_SSDR_basic.iloc[i]['SSDR'], df_SSDR_basic.iloc[i]['CV']**2)

# filling the CV_dict_exp dictionaries with the name and SSDR of the
# expert judgments and calculating the new CV for the expert judgments
# consiting of the already calculated CV for the expert judgment and the
# basic uncertainty of the addtional uncertainy coming from the inital
# value the SSDR is taken from
for i in range(0, len(df_SSDR_exp)):
    name_exp = df_SSDR_exp.iloc[i]['Polymer type'] + ', ' + df_SSDR_exp.iloc[i]['Compartment'] + \
        ', ' + \
        re.findall('\+(.+)', df_SSDR_exp.iloc[i]
                   ['SSDR expert judgment based on'])[0]
    SSDR_dict_exp[name_exp] = CV_dict_basic.get(
        name_exp.split(', ')[0] + ', ' + name_exp.split(', ')[2], 0)[0]
    CV_dict_exp[name_exp] = (df_SSDR_exp.iloc[i]['CV'])**2
    CV_dict_exp[name_exp] = math.sqrt((CV_dict_exp.get(name_exp, 0)+1) * (
        CV_dict_basic.get(name_exp.split(', ')[0] + ', ' + name_exp.split(', ')[2], 0)[1]+1)-1)

# merging of the two dictionaries consisting of the SSDRs and CVs
# for the expert estimates (SSDR_dict_exp and CV_dict_exp)
dcts = [SSDR_dict_exp, CV_dict_exp]

# organizing of the new dataframe (df_SSDR_exp)
df_SSDR_exp = pd.DataFrame(dcts).T
df_SSDR_exp.reset_index(level=0, inplace=True)
cols = {'columns': {'index': 'Polymer', 0: 'SSDR', 1: 'CV'}}
df_SSDR_exp = df_SSDR_exp.rename(**cols)
df_SSDR_exp
df_SSDR_exp[['Polymer type', 'Compartment', 'Exp']
            ] = df_SSDR_exp.Polymer.str.split(', ', expand=True)
df_SSDR_exp = df_SSDR_exp[['Polymer type', 'Compartment', 'SSDR', 'CV']]

# merging of the two dataframes consisting either the
# already set SSDRs and CVs and expert values
frames = [df_SSDR_basic, df_SSDR_exp]
df_SSDR = pd.concat(frames)
df_SSDR = df_SSDR[['Polymer type', 'Compartment', 'SSDR', 'CV']]
df_SSDR
# Out:
#     Polymer type      Compartment        SSDR        CV
# 1           HDPE     marine water   11.699359  0.630773
# 4           LDPE  marine sediment    0.706833  0.472005
# 5           LDPE     marine water    5.657500  0.253505
# 9         NR/SBR     marine water   43.650000  0.629620
# 13            PA     marine water  292.000000  0.146425
# ..           ...              ...         ...       ...
# 43            PU  marine sediment  193.000000  0.517929
# 44            PU   river sediment  193.000000  0.517929
# 45            PU             soil  193.000000  0.517929
# 46  Starch-blend  marine sediment   42.740047  0.335799
# 47  Starch-blend   river sediment   42.740047  0.335799
#
# [96 rows x 4 columns]

# %% [markdown]
# # Calculationg of standard deviation based on the CV for each data point

# %%
# calculation of the geometric standard deviation
# according to Muller et al. (2016)
def GSD(CV):
    return math.exp(math.sqrt(math.log((CV**2)+1)))

# %%
# Application of the GSD function to all rows and SSDRs and sorting by polymer type and compartment
df_SSDR['GSD'] = df_SSDR.apply(lambda row: GSD(float(row['CV'])), axis=1)
df_SSDR = df_SSDR.sort_values(by=['Polymer type', 'Compartment'])

# %%
# Building of a dictionary containing the name as key (composed of polymer type and compartment) and a tuple as value
# containing the SSDR and GSD
SSDR_dict = {}

for i in range(0, len(df_SSDR)):
    name = df_SSDR.iloc[i]['Polymer type'] + \
        ', ' + df_SSDR.iloc[i]['Compartment']
    SSDR_dict[name] = df_SSDR.iloc[i]['SSDR'], df_SSDR.iloc[i]['GSD']
SSDR_dict
# Out:
# {'HDPE, marine sediment': (11.699358956797559, 1.8607030663907251),
#  'HDPE, marine water': (11.699358956797559, 1.7838093127266956),
#  'HDPE, river sediment': (11.699358956797559, 1.8607030663907251),
#  'HDPE, soil': (11.699358956797559, 1.8607030663907251),
#  'LDPE, marine sediment': (0.7068333758372778, 1.5659304140921921),
#  'LDPE, marine water': (5.6575, 1.2834711338964044),
#  'LDPE, river sediment': (0.7068333758372778, 1.651630269428027),
#  'LDPE, soil': (5.6575, 1.3993802474041053),
#  'NR/SBR, marine sediment': (43.65000000000001, 1.8591449594304925),
#  'NR/SBR, marine water': (43.65000000000001, 1.7822065562437492),
#  'NR/SBR, river sediment': (43.65000000000001, 1.8591449594304925),
#  'NR/SBR, soil': (43.65000000000001, 1.8591449594304925),
#  'PA, marine sediment': (292.0, 1.3073990159314974),
#  'PA, marine water': (292.0, 1.1567906541587107),
#  'PA, river sediment': (292.0, 1.3073990159314974),
#  'PA, soil': (292.0, 1.3073990159314974),
#  'PBAT, marine sediment': (1.9647872340425547, 1.8591449594304925),
#  'PBAT, marine water': (11.75022705050614, 1.5352507074922717),
#  'PBAT, river sediment': (1.9647872340425547, 1.8591449594304925),
#  'PBAT, soil': (1.9647872340425547, 1.7822065562437492),
#  'PBS, marine sediment': (6.336805555555556, 1.437266060853234),
#  'PBS, marine water': (6.336805555555556, 1.3291219574778883),
#  'PBS, river sediment': (6.336805555555556, 1.437266060853234),
#  'PBS, soil': (61.11937736660423, 1.2142616701550326),
#  'PBSA, marine sediment': (92.17641969038921, 1.3781722776734169),
#  'PBSA, marine water': (92.17641969038921, 1.2568291915636591),
#  'PBSA, river sediment': (92.17641969038921, 1.3781722776734169),
#  'PBSA, soil': (50.414364640883996, 1.2838373185769794),
#  'PBSe, marine sediment': (2.50962596259626, 1.0981215093515928),
#  'PBSe, marine water': (2.5517848657549664, 1.0981215093515928),
#  'PBSe, river sediment': (2.50962596259626, 1.2759692133746712),
#  'PBSe, soil': (24.57136777380047, 1.2326786424407017),
#  'PBSeT, marine sediment': (2.130018674136321, 1.0981215093515928),
#  'PBSeT, marine water': (1.7160061852294537, 1.0981215093515928),
#  'PBSeT, river sediment': (2.130018674136321, 1.2759692133746712),
#  'PBSeT, soil': (19.655684523809523, 1.2326786424407017),
#  'PC, marine sediment': (5.175000000000012, 1.8607030663907251),
#  'PC, marine water': (5.175000000000012, 1.7838093127266956),
#  'PC, river sediment': (5.175000000000012, 1.8607030663907251),
#  'PC, soil': (5.175000000000012, 1.8607030663907251),
#  'PCL, marine sediment': (433.52325279537865, 1.3370303520790934),
#  'PCL, marine water': (433.52325279537865, 1.2016048931614587),
#  'PCL, river sediment': (433.52325279537865, 1.3370303520790934),
#  'PCL, soil': (433.52325279537865, 1.3370303520790934),
#  'PE, marine sediment': (0.001, 1.8470437384635119),
#  'PE, marine water': (0.001, 1.769750613029825),
#  'PE, river sediment': (0.001, 1.8470437384635119),
#  'PE, soil': (0.6254147053324317, 1.5771335732803868),
#  'PEA, marine sediment': (423.66071428571433, 1.3370303520790934),
#  'PEA, marine water': (423.66071428571433, 1.2016048931614587),
#  'PEA, river sediment': (423.66071428571433, 1.3370303520790934),
#  'PEA, soil': (423.66071428571433, 1.3370303520790934),
#  'PES, marine sediment': (11.289259727904302, 1.6350387743991752),
#  'PES, marine water': (11.289259727904302, 1.5482960041364726),
#  'PES, river sediment': (11.289259727904302, 1.6350387743991752),
#  'PES, soil': (11.289259727904302, 1.6350387743991752),
#  'PET, marine sediment': (0.6944444444444452, 1.3746765434419783),
#  'PET, marine water': (0.6944444444444452, 1.2523407905944957),
#  'PET, river sediment': (0.6944444444444452, 1.3746765434419783),
#  'PET, soil': (0.8333333333333333, 2.8651968541302204),
#  'PHA, marine sediment': (12.36449864498645, 1.0981215093515928),
#  'PHA, marine water': (21.27039627039627, 1.0981215093515928),
#  'PHA, river sediment': (12.36449864498645, 1.2759692133746712),
#  'PHA, soil': (1564.2857142857144, 1.2838373185769794),
#  'PHB, marine sediment': (521.4285714285714, 1.3123702932623182),
#  'PHB, marine water': (521.4285714285714, 1.1647671325475215),
#  'PHB, river sediment': (521.4285714285714, 1.3123702932623182),
#  'PHB, soil': (508.6503402815122, 1.522213415682457),
#  'PHBV, marine sediment': (50.46082949308756, 1.3866220474038289),
#  'PHBV, marine water': (338.3119959602037, 1.527794215650524),
#  'PHBV, river sediment': (50.46082949308756, 1.3866220474038289),
#  'PHBV, soil': (50.46082949308756, 1.2675584838403926),
#  'PLA(-blend), marine sediment': (0.0011262857142862617, 1.6104112748312414),
#  'PLA(-blend), marine water': (0.001, 1.6013921518987684),
#  'PLA(-blend), river sediment': (0.0011262857142862617, 1.521981197392326),
#  'PLA(-blend), soil': (78.6947243008506, 1.220208402268304),
#  'PP, marine sediment': (0.2977598412109672, 1.6622044844458415),
#  'PP, marine water': (6.088539438978756, 1.7838093127266956),
#  'PP, river sediment': (0.2977598412109672, 1.6622044844458415),
#  'PP, soil': (0.2977598412109672, 1.5771335732803868),
#  'PS, marine sediment': (0.001, 3.6420115857881514),
#  'PS, marine water': (0.001, 3.6420115857881514),
#  'PS, river sediment': (0.001, 3.6420115857881514),
#  'PS, soil': (0.001, 3.6420115857881514),
#  'PU, marine sediment': (193.00000000000006, 1.6282102068858726),
#  'PU, marine water': (193.00000000000006, 1.541017014197046),
#  'PU, river sediment': (193.00000000000006, 1.6282102068858726),
#  'PU, soil': (193.00000000000006, 1.6282102068858726),
#  'PVC, marine sediment': (0.001, 3.6420115857881514),
#  'PVC, marine water': (0.001, 3.6420115857881514),
#  'PVC, river sediment': (0.001, 3.6420115857881514),
#  'PVC, soil': (0.001, 3.6420115857881514),
#  'Starch-blend, marine sediment': (42.74004683840751, 1.3866220474038289),
#  'Starch-blend, marine water': (101.29025539691933, 1.1567906541587107),
#  'Starch-blend, river sediment': (42.74004683840751, 1.3866220474038289),
#  'Starch-blend, soil': (42.74004683840751, 1.2675584838403926)}

# %%
# Creating an excel file with the SSDR and uncertainty based on df_SSDR
book = load_workbook(excel_name)
writer = pd.ExcelWriter(excel_name, engine='openpyxl')
writer.book = book
df_SSDR.to_excel(writer, sheet_name='SSDR_with_Uncertainty', index=False)
writer.save()

# %% [markdown]
# # Fate factor calculation

# %%
# defining elements (polymer type, compartment, shape, characterisitc length) for the calculation of the fate factor
polymer_type = df_SSDR['Polymer type'].unique().tolist()
compartment = ['air', 'fresh water', 'marine water', 'soil']
shape_dict = {'film': 2, 'fiber': 4, 'particle': 6}
shape = list(shape_dict.keys())
char_length = ['0.01-0.1 mm', '0.1-1 mm', '1-10 mm']

# building a list of all environmental flows containing the above describe elements
flows = list()
for polymer in polymer_type:
    for form in shape:
        for length in char_length:
            for comp in compartment:
                flows.append('DE: ' + polymer + ' ' + form + ' ' + length +
                            ' ' + '(emission to ' + comp + ')')
# setting up a dictionary for the elementary flows
flows_dict = {}
# building of a dictionary containing the environmental flow as key and a tuple containing the polymer type, shape,
# characterisitc lenght and initial compartment as value
for flow in flows:
    names = re.findall('^DE: (.+)', flow)
    polymer_type = names[0].split(' ')[0]
    shape = names[0].split(' ')[1]
    characteristic_length = float(names[0].split(
        ' ')[2].split('-')[1].replace(',', '.'))
    initial_compartment = re.findall(
        'to (.+)', re.findall('\((.*?)\)', names[0])[-1])[0]
    flows_dict[names[0]] = polymer_type, shape, characteristic_length, initial_compartment

# %%
flows_dict
# Out:
# {'HDPE film 0.01-0.1 mm (emission to air)': ('HDPE', 'film', 0.1, 'air'),
#  'HDPE film 0.01-0.1 mm (emission to fresh water)': ('HDPE',
#   'film',
#   0.1,
#   'fresh water'),
#  'HDPE film 0.01-0.1 mm (emission to marine water)': ('HDPE',
#   'film',
#   0.1,
#   'marine water'),
#  'HDPE film 0.01-0.1 mm (emission to soil)': ('HDPE', 'film', 0.1, 'soil'),
#  'HDPE film 0.1-1 mm (emission to air)': ('HDPE', 'film', 1.0, 'air'),
#  'HDPE film 0.1-1 mm (emission to fresh water)': ('HDPE',
#   'film',
#   1.0,
#   'fresh water'),
#  'HDPE film 0.1-1 mm (emission to marine water)': ('HDPE',
#   'film',
#   1.0,
#   'marine water'),
#  'HDPE film 0.1-1 mm (emission to soil)': ('HDPE', 'film', 1.0, 'soil'),
#  'HDPE film 1-10 mm (emission to air)': ('HDPE', 'film', 10.0, 'air'),
#  'HDPE film 1-10 mm (emission to fresh water)': ('HDPE',
#   'film',
#   10.0,
#   'fresh water'),
#  'HDPE film 1-10 mm (emission to marine water)': ('HDPE',
#   'film',
#   10.0,
#   'marine water'),
#  'HDPE film 1-10 mm (emission to soil)': ('HDPE', 'film', 10.0, 'soil'),
#  'HDPE fiber 0.01-0.1 mm (emission to air)': ('HDPE', 'fiber', 0.1, 'air'),
#  'HDPE fiber 0.01-0.1 mm (emission to fresh water)': ('HDPE',
#   'fiber',
#   0.1,
#   'fresh water'),
#  'HDPE fiber 0.01-0.1 mm (emission to marine water)': ('HDPE',
#   'fiber',
#   0.1,
#   'marine water'),
#  'HDPE fiber 0.01-0.1 mm (emission to soil)': ('HDPE', 'fiber', 0.1, 'soil'),
#  'HDPE fiber 0.1-1 mm (emission to air)': ('HDPE', 'fiber', 1.0, 'air'),
#  'HDPE fiber 0.1-1 mm (emission to fresh water)': ('HDPE',
#   'fiber',
#   1.0,
#   'fresh water'),
#  'HDPE fiber 0.1-1 mm (emission to marine water)': ('HDPE',
#   'fiber',
#   1.0,
#   'marine water'),
#  'HDPE fiber 0.1-1 mm (emission to soil)': ('HDPE', 'fiber', 1.0, 'soil'),
#  'HDPE fiber 1-10 mm (emission to air)': ('HDPE', 'fiber', 10.0, 'air'),
#  'HDPE fiber 1-10 mm (emission to fresh water)': ('HDPE',
#   'fiber',
#   10.0,
#   'fresh water'),
#  'HDPE fiber 1-10 mm (emission to marine water)': ('HDPE',
#   'fiber',
#   10.0,
#   'marine water'),
#  'HDPE fiber 1-10 mm (emission to soil)': ('HDPE', 'fiber', 10.0, 'soil'),
#  'HDPE particle 0.01-0.1 mm (emission to air)': ('HDPE',
#   'particle',
#   0.1,
#   'air'),
#  'HDPE particle 0.01-0.1 mm (emission to fresh water)': ('HDPE',
#   'particle',
#   0.1,
#   'fresh water'),
#  'HDPE particle 0.01-0.1 mm (emission to marine water)': ('HDPE',
#   'particle',
#   0.1,
#   'marine water'),
#  'HDPE particle 0.01-0.1 mm (emission to soil)': ('HDPE',
#   'particle',
#   0.1,
#   'soil'),
#  'HDPE particle 0.1-1 mm (emission to air)': ('HDPE', 'particle', 1.0, 'air'),
#  'HDPE particle 0.1-1 mm (emission to fresh water)': ('HDPE',
#   'particle',
#   1.0,
#   'fresh water'),
#  'HDPE particle 0.1-1 mm (emission to marine water)': ('HDPE',
#   'particle',
#   1.0,
#   'marine water'),
#  'HDPE particle 0.1-1 mm (emission to soil)': ('HDPE',
#   'particle',
#   1.0,
#   'soil'),
#  'HDPE particle 1-10 mm (emission to air)': ('HDPE', 'particle', 10.0, 'air'),
#  'HDPE particle 1-10 mm (emission to fresh water)': ('HDPE',
#   'particle',
#   10.0,
#   'fresh water'),
#  'HDPE particle 1-10 mm (emission to marine water)': ('HDPE',
#   'particle',
#   10.0,
#   'marine water'),
#  'HDPE particle 1-10 mm (emission to soil)': ('HDPE',
#   'particle',
#   10.0,
#   'soil'),
#  'LDPE film 0.01-0.1 mm (emission to air)': ('LDPE', 'film', 0.1, 'air'),
#  'LDPE film 0.01-0.1 mm (emission to fresh water)': ('LDPE',
#   'film',
#   0.1,
#   'fresh water'),
#  'LDPE film 0.01-0.1 mm (emission to marine water)': ('LDPE',
#   'film',
#   0.1,
#   'marine water'),
#  'LDPE film 0.01-0.1 mm (emission to soil)': ('LDPE', 'film', 0.1, 'soil'),
#  'LDPE film 0.1-1 mm (emission to air)': ('LDPE', 'film', 1.0, 'air'),
#  'LDPE film 0.1-1 mm (emission to fresh water)': ('LDPE',
#   'film',
#   1.0,
#   'fresh water'),
#  'LDPE film 0.1-1 mm (emission to marine water)': ('LDPE',
#   'film',
#   1.0,
#   'marine water'),
#  'LDPE film 0.1-1 mm (emission to soil)': ('LDPE', 'film', 1.0, 'soil'),
#  'LDPE film 1-10 mm (emission to air)': ('LDPE', 'film', 10.0, 'air'),
#  'LDPE film 1-10 mm (emission to fresh water)': ('LDPE',
#   'film',
#   10.0,
#   'fresh water'),
#  'LDPE film 1-10 mm (emission to marine water)': ('LDPE',
#   'film',
#   10.0,
#   'marine water'),
#  'LDPE film 1-10 mm (emission to soil)': ('LDPE', 'film', 10.0, 'soil'),
#  'LDPE fiber 0.01-0.1 mm (emission to air)': ('LDPE', 'fiber', 0.1, 'air'),
#  'LDPE fiber 0.01-0.1 mm (emission to fresh water)': ('LDPE',
#   'fiber',
#   0.1,
#   'fresh water'),
#  'LDPE fiber 0.01-0.1 mm (emission to marine water)': ('LDPE',
#   'fiber',
#   0.1,
#   'marine water'),
#  'LDPE fiber 0.01-0.1 mm (emission to soil)': ('LDPE', 'fiber', 0.1, 'soil'),
#  'LDPE fiber 0.1-1 mm (emission to air)': ('LDPE', 'fiber', 1.0, 'air'),
#  'LDPE fiber 0.1-1 mm (emission to fresh water)': ('LDPE',
#   'fiber',
#   1.0,
#   'fresh water'),
#  'LDPE fiber 0.1-1 mm (emission to marine water)': ('LDPE',
#   'fiber',
#   1.0,
#   'marine water'),
#  'LDPE fiber 0.1-1 mm (emission to soil)': ('LDPE', 'fiber', 1.0, 'soil'),
#  'LDPE fiber 1-10 mm (emission to air)': ('LDPE', 'fiber', 10.0, 'air'),
#  'LDPE fiber 1-10 mm (emission to fresh water)': ('LDPE',
#   'fiber',
#   10.0,
#   'fresh water'),
#  'LDPE fiber 1-10 mm (emission to marine water)': ('LDPE',
#   'fiber',
#   10.0,
#   'marine water'),
#  'LDPE fiber 1-10 mm (emission to soil)': ('LDPE', 'fiber', 10.0, 'soil'),
#  'LDPE particle 0.01-0.1 mm (emission to air)': ('LDPE',
#   'particle',
#   0.1,
#   'air'),
#  'LDPE particle 0.01-0.1 mm (emission to fresh water)': ('LDPE',
#   'particle',
#   0.1,
#   'fresh water'),
#  'LDPE particle 0.01-0.1 mm (emission to marine water)': ('LDPE',
#   'particle',
#   0.1,
#   'marine water'),
#  'LDPE particle 0.01-0.1 mm (emission to soil)': ('LDPE',
#   'particle',
#   0.1,
#   'soil'),
#  'LDPE particle 0.1-1 mm (emission to air)': ('LDPE', 'particle', 1.0, 'air'),
#  'LDPE particle 0.1-1 mm (emission to fresh water)': ('LDPE',
#   'particle',
#   1.0,
#   'fresh water'),
#  'LDPE particle 0.1-1 mm (emission to marine water)': ('LDPE',
#   'particle',
#   1.0,
#   'marine water'),
#  'LDPE particle 0.1-1 mm (emission to soil)': ('LDPE',
#   'particle',
#   1.0,
#   'soil'),
#  'LDPE particle 1-10 mm (emission to air)': ('LDPE', 'particle', 10.0, 'air'),
#  'LDPE particle 1-10 mm (emission to fresh water)': ('LDPE',
#   'particle',
#   10.0,
#   'fresh water'),
#  'LDPE particle 1-10 mm (emission to marine water)': ('LDPE',
#   'particle',
#   10.0,
#   'marine water'),
#  'LDPE particle 1-10 mm (emission to soil)': ('LDPE',
#   'particle',
#   10.0,
#   'soil'),
#  'NR/SBR film 0.01-0.1 mm (emission to air)': ('NR/SBR', 'film', 0.1, 'air'),
#  'NR/SBR film 0.01-0.1 mm (emission to fresh water)': ('NR/SBR',
#   'film',
#   0.1,
#   'fresh water'),
#  'NR/SBR film 0.01-0.1 mm (emission to marine water)': ('NR/SBR',
#   'film',
#   0.1,
#   'marine water'),
#  'NR/SBR film 0.01-0.1 mm (emission to soil)': ('NR/SBR', 'film', 0.1, 'soil'),
#  'NR/SBR film 0.1-1 mm (emission to air)': ('NR/SBR', 'film', 1.0, 'air'),
#  'NR/SBR film 0.1-1 mm (emission to fresh water)': ('NR/SBR',
#   'film',
#   1.0,
#   'fresh water'),
#  'NR/SBR film 0.1-1 mm (emission to marine water)': ('NR/SBR',
#   'film',
#   1.0,
#   'marine water'),
#  'NR/SBR film 0.1-1 mm (emission to soil)': ('NR/SBR', 'film', 1.0, 'soil'),
#  'NR/SBR film 1-10 mm (emission to air)': ('NR/SBR', 'film', 10.0, 'air'),
#  'NR/SBR film 1-10 mm (emission to fresh water)': ('NR/SBR',
#   'film',
#   10.0,
#   'fresh water'),
#  'NR/SBR film 1-10 mm (emission to marine water)': ('NR/SBR',
#   'film',
#   10.0,
#   'marine water'),
#  'NR/SBR film 1-10 mm (emission to soil)': ('NR/SBR', 'film', 10.0, 'soil'),
#  'NR/SBR fiber 0.01-0.1 mm (emission to air)': ('NR/SBR', 'fiber', 0.1, 'air'),
#  'NR/SBR fiber 0.01-0.1 mm (emission to fresh water)': ('NR/SBR',
#   'fiber',
#   0.1,
#   'fresh water'),
#  'NR/SBR fiber 0.01-0.1 mm (emission to marine water)': ('NR/SBR',
#   'fiber',
#   0.1,
#   'marine water'),
#  'NR/SBR fiber 0.01-0.1 mm (emission to soil)': ('NR/SBR',
#   'fiber',
#   0.1,
#   'soil'),
#  'NR/SBR fiber 0.1-1 mm (emission to air)': ('NR/SBR', 'fiber', 1.0, 'air'),
#  'NR/SBR fiber 0.1-1 mm (emission to fresh water)': ('NR/SBR',
#   'fiber',
#   1.0,
#   'fresh water'),
#  'NR/SBR fiber 0.1-1 mm (emission to marine water)': ('NR/SBR',
#   'fiber',
#   1.0,
#   'marine water'),
#  'NR/SBR fiber 0.1-1 mm (emission to soil)': ('NR/SBR', 'fiber', 1.0, 'soil'),
#  'NR/SBR fiber 1-10 mm (emission to air)': ('NR/SBR', 'fiber', 10.0, 'air'),
#  'NR/SBR fiber 1-10 mm (emission to fresh water)': ('NR/SBR',
#   'fiber',
#   10.0,
#   'fresh water'),
#  'NR/SBR fiber 1-10 mm (emission to marine water)': ('NR/SBR',
#   'fiber',
#   10.0,
#   'marine water'),
#  'NR/SBR fiber 1-10 mm (emission to soil)': ('NR/SBR', 'fiber', 10.0, 'soil'),
#  'NR/SBR particle 0.01-0.1 mm (emission to air)': ('NR/SBR',
#   'particle',
#   0.1,
#   'air'),
#  'NR/SBR particle 0.01-0.1 mm (emission to fresh water)': ('NR/SBR',
#   'particle',
#   0.1,
#   'fresh water'),
#  'NR/SBR particle 0.01-0.1 mm (emission to marine water)': ('NR/SBR',
#   'particle',
#   0.1,
#   'marine water'),
#  'NR/SBR particle 0.01-0.1 mm (emission to soil)': ('NR/SBR',
#   'particle',
#   0.1,
#   'soil'),
#  'NR/SBR particle 0.1-1 mm (emission to air)': ('NR/SBR',
#   'particle',
#   1.0,
#   'air'),
#  'NR/SBR particle 0.1-1 mm (emission to fresh water)': ('NR/SBR',
#   'particle',
#   1.0,
#   'fresh water'),
#  'NR/SBR particle 0.1-1 mm (emission to marine water)': ('NR/SBR',
#   'particle',
#   1.0,
#   'marine water'),
#  'NR/SBR particle 0.1-1 mm (emission to soil)': ('NR/SBR',
#   'particle',
#   1.0,
#   'soil'),
#  'NR/SBR particle 1-10 mm (emission to air)': ('NR/SBR',
#   'particle',
#   10.0,
#   'air'),
#  'NR/SBR particle 1-10 mm (emission to fresh water)': ('NR/SBR',
#   'particle',
#   10.0,
#   'fresh water'),
#  'NR/SBR particle 1-10 mm (emission to marine water)': ('NR/SBR',
#   'particle',
#   10.0,
#   'marine water'),
#  'NR/SBR particle 1-10 mm (emission to soil)': ('NR/SBR',
#   'particle',
#   10.0,
#   'soil'),
#  'PA film 0.01-0.1 mm (emission to air)': ('PA', 'film', 0.1, 'air'),
#  'PA film 0.01-0.1 mm (emission to fresh water)': ('PA',
#   'film',
#   0.1,
#   'fresh water'),
#  'PA film 0.01-0.1 mm (emission to marine water)': ('PA',
#   'film',
#   0.1,
#   'marine water'),
#  'PA film 0.01-0.1 mm (emission to soil)': ('PA', 'film', 0.1, 'soil'),
#  'PA film 0.1-1 mm (emission to air)': ('PA', 'film', 1.0, 'air'),
#  'PA film 0.1-1 mm (emission to fresh water)': ('PA',
#   'film',
#   1.0,
#   'fresh water'),
#  'PA film 0.1-1 mm (emission to marine water)': ('PA',
#   'film',
#   1.0,
#   'marine water'),
#  'PA film 0.1-1 mm (emission to soil)': ('PA', 'film', 1.0, 'soil'),
#  'PA film 1-10 mm (emission to air)': ('PA', 'film', 10.0, 'air'),
#  'PA film 1-10 mm (emission to fresh water)': ('PA',
#   'film',
#   10.0,
#   'fresh water'),
#  'PA film 1-10 mm (emission to marine water)': ('PA',
#   'film',
#   10.0,
#   'marine water'),
#  'PA film 1-10 mm (emission to soil)': ('PA', 'film', 10.0, 'soil'),
#  'PA fiber 0.01-0.1 mm (emission to air)': ('PA', 'fiber', 0.1, 'air'),
#  'PA fiber 0.01-0.1 mm (emission to fresh water)': ('PA',
#   'fiber',
#   0.1,
#   'fresh water'),
#  'PA fiber 0.01-0.1 mm (emission to marine water)': ('PA',
#   'fiber',
#   0.1,
#   'marine water'),
#  'PA fiber 0.01-0.1 mm (emission to soil)': ('PA', 'fiber', 0.1, 'soil'),
#  'PA fiber 0.1-1 mm (emission to air)': ('PA', 'fiber', 1.0, 'air'),
#  'PA fiber 0.1-1 mm (emission to fresh water)': ('PA',
#   'fiber',
#   1.0,
#   'fresh water'),
#  'PA fiber 0.1-1 mm (emission to marine water)': ('PA',
#   'fiber',
#   1.0,
#   'marine water'),
#  'PA fiber 0.1-1 mm (emission to soil)': ('PA', 'fiber', 1.0, 'soil'),
#  'PA fiber 1-10 mm (emission to air)': ('PA', 'fiber', 10.0, 'air'),
#  'PA fiber 1-10 mm (emission to fresh water)': ('PA',
#   'fiber',
#   10.0,
#   'fresh water'),
#  'PA fiber 1-10 mm (emission to marine water)': ('PA',
#   'fiber',
#   10.0,
#   'marine water'),
#  'PA fiber 1-10 mm (emission to soil)': ('PA', 'fiber', 10.0, 'soil'),
#  'PA particle 0.01-0.1 mm (emission to air)': ('PA', 'particle', 0.1, 'air'),
#  'PA particle 0.01-0.1 mm (emission to fresh water)': ('PA',
#   'particle',
#   0.1,
#   'fresh water'),
#  'PA particle 0.01-0.1 mm (emission to marine water)': ('PA',
#   'particle',
#   0.1,
#   'marine water'),
#  'PA particle 0.01-0.1 mm (emission to soil)': ('PA', 'particle', 0.1, 'soil'),
#  'PA particle 0.1-1 mm (emission to air)': ('PA', 'particle', 1.0, 'air'),
#  'PA particle 0.1-1 mm (emission to fresh water)': ('PA',
#   'particle',
#   1.0,
#   'fresh water'),
#  'PA particle 0.1-1 mm (emission to marine water)': ('PA',
#   'particle',
#   1.0,
#   'marine water'),
#  'PA particle 0.1-1 mm (emission to soil)': ('PA', 'particle', 1.0, 'soil'),
#  'PA particle 1-10 mm (emission to air)': ('PA', 'particle', 10.0, 'air'),
#  'PA particle 1-10 mm (emission to fresh water)': ('PA',
#   'particle',
#   10.0,
#   'fresh water'),
#  'PA particle 1-10 mm (emission to marine water)': ('PA',
#   'particle',
#   10.0,
#   'marine water'),
#  'PA particle 1-10 mm (emission to soil)': ('PA', 'particle', 10.0, 'soil'),
#  'PBAT film 0.01-0.1 mm (emission to air)': ('PBAT', 'film', 0.1, 'air'),
#  'PBAT film 0.01-0.1 mm (emission to fresh water)': ('PBAT',
#   'film',
#   0.1,
#   'fresh water'),
#  'PBAT film 0.01-0.1 mm (emission to marine water)': ('PBAT',
#   'film',
#   0.1,
#   'marine water'),
#  'PBAT film 0.01-0.1 mm (emission to soil)': ('PBAT', 'film', 0.1, 'soil'),
#  'PBAT film 0.1-1 mm (emission to air)': ('PBAT', 'film', 1.0, 'air'),
#  'PBAT film 0.1-1 mm (emission to fresh water)': ('PBAT',
#   'film',
#   1.0,
#   'fresh water'),
#  'PBAT film 0.1-1 mm (emission to marine water)': ('PBAT',
#   'film',
#   1.0,
#   'marine water'),
#  'PBAT film 0.1-1 mm (emission to soil)': ('PBAT', 'film', 1.0, 'soil'),
#  'PBAT film 1-10 mm (emission to air)': ('PBAT', 'film', 10.0, 'air'),
#  'PBAT film 1-10 mm (emission to fresh water)': ('PBAT',
#   'film',
#   10.0,
#   'fresh water'),
#  'PBAT film 1-10 mm (emission to marine water)': ('PBAT',
#   'film',
#   10.0,
#   'marine water'),
#  'PBAT film 1-10 mm (emission to soil)': ('PBAT', 'film', 10.0, 'soil'),
#  'PBAT fiber 0.01-0.1 mm (emission to air)': ('PBAT', 'fiber', 0.1, 'air'),
#  'PBAT fiber 0.01-0.1 mm (emission to fresh water)': ('PBAT',
#   'fiber',
#   0.1,
#   'fresh water'),
#  'PBAT fiber 0.01-0.1 mm (emission to marine water)': ('PBAT',
#   'fiber',
#   0.1,
#   'marine water'),
#  'PBAT fiber 0.01-0.1 mm (emission to soil)': ('PBAT', 'fiber', 0.1, 'soil'),
#  'PBAT fiber 0.1-1 mm (emission to air)': ('PBAT', 'fiber', 1.0, 'air'),
#  'PBAT fiber 0.1-1 mm (emission to fresh water)': ('PBAT',
#   'fiber',
#   1.0,
#   'fresh water'),
#  'PBAT fiber 0.1-1 mm (emission to marine water)': ('PBAT',
#   'fiber',
#   1.0,
#   'marine water'),
#  'PBAT fiber 0.1-1 mm (emission to soil)': ('PBAT', 'fiber', 1.0, 'soil'),
#  'PBAT fiber 1-10 mm (emission to air)': ('PBAT', 'fiber', 10.0, 'air'),
#  'PBAT fiber 1-10 mm (emission to fresh water)': ('PBAT',
#   'fiber',
#   10.0,
#   'fresh water'),
#  'PBAT fiber 1-10 mm (emission to marine water)': ('PBAT',
#   'fiber',
#   10.0,
#   'marine water'),
#  'PBAT fiber 1-10 mm (emission to soil)': ('PBAT', 'fiber', 10.0, 'soil'),
#  'PBAT particle 0.01-0.1 mm (emission to air)': ('PBAT',
#   'particle',
#   0.1,
#   'air'),
#  'PBAT particle 0.01-0.1 mm (emission to fresh water)': ('PBAT',
#   'particle',
#   0.1,
#   'fresh water'),
#  'PBAT particle 0.01-0.1 mm (emission to marine water)': ('PBAT',
#   'particle',
#   0.1,
#   'marine water'),
#  'PBAT particle 0.01-0.1 mm (emission to soil)': ('PBAT',
#   'particle',
#   0.1,
#   'soil'),
#  'PBAT particle 0.1-1 mm (emission to air)': ('PBAT', 'particle', 1.0, 'air'),
#  'PBAT particle 0.1-1 mm (emission to fresh water)': ('PBAT',
#   'particle',
#   1.0,
#   'fresh water'),
#  'PBAT particle 0.1-1 mm (emission to marine water)': ('PBAT',
#   'particle',
#   1.0,
#   'marine water'),
#  'PBAT particle 0.1-1 mm (emission to soil)': ('PBAT',
#   'particle',
#   1.0,
#   'soil'),
#  'PBAT particle 1-10 mm (emission to air)': ('PBAT', 'particle', 10.0, 'air'),
#  'PBAT particle 1-10 mm (emission to fresh water)': ('PBAT',
#   'particle',
#   10.0,
#   'fresh water'),
#  'PBAT particle 1-10 mm (emission to marine water)': ('PBAT',
#   'particle',
#   10.0,
#   'marine water'),
#  'PBAT particle 1-10 mm (emission to soil)': ('PBAT',
#   'particle',
#   10.0,
#   'soil'),
#  'PBS film 0.01-0.1 mm (emission to air)': ('PBS', 'film', 0.1, 'air'),
#  'PBS film 0.01-0.1 mm (emission to fresh water)': ('PBS',
#   'film',
#   0.1,
#   'fresh water'),
#  'PBS film 0.01-0.1 mm (emission to marine water)': ('PBS',
#   'film',
#   0.1,
#   'marine water'),
#  'PBS film 0.01-0.1 mm (emission to soil)': ('PBS', 'film', 0.1, 'soil'),
#  'PBS film 0.1-1 mm (emission to air)': ('PBS', 'film', 1.0, 'air'),
#  'PBS film 0.1-1 mm (emission to fresh water)': ('PBS',
#   'film',
#   1.0,
#   'fresh water'),
#  'PBS film 0.1-1 mm (emission to marine water)': ('PBS',
#   'film',
#   1.0,
#   'marine water'),
#  'PBS film 0.1-1 mm (emission to soil)': ('PBS', 'film', 1.0, 'soil'),
#  'PBS film 1-10 mm (emission to air)': ('PBS', 'film', 10.0, 'air'),
#  'PBS film 1-10 mm (emission to fresh water)': ('PBS',
#   'film',
#   10.0,
#   'fresh water'),
#  'PBS film 1-10 mm (emission to marine water)': ('PBS',
#   'film',
#   10.0,
#   'marine water'),
#  'PBS film 1-10 mm (emission to soil)': ('PBS', 'film', 10.0, 'soil'),
#  'PBS fiber 0.01-0.1 mm (emission to air)': ('PBS', 'fiber', 0.1, 'air'),
#  'PBS fiber 0.01-0.1 mm (emission to fresh water)': ('PBS',
#   'fiber',
#   0.1,
#   'fresh water'),
#  'PBS fiber 0.01-0.1 mm (emission to marine water)': ('PBS',
#   'fiber',
#   0.1,
#   'marine water'),
#  'PBS fiber 0.01-0.1 mm (emission to soil)': ('PBS', 'fiber', 0.1, 'soil'),
#  'PBS fiber 0.1-1 mm (emission to air)': ('PBS', 'fiber', 1.0, 'air'),
#  'PBS fiber 0.1-1 mm (emission to fresh water)': ('PBS',
#   'fiber',
#   1.0,
#   'fresh water'),
#  'PBS fiber 0.1-1 mm (emission to marine water)': ('PBS',
#   'fiber',
#   1.0,
#   'marine water'),
#  'PBS fiber 0.1-1 mm (emission to soil)': ('PBS', 'fiber', 1.0, 'soil'),
#  'PBS fiber 1-10 mm (emission to air)': ('PBS', 'fiber', 10.0, 'air'),
#  'PBS fiber 1-10 mm (emission to fresh water)': ('PBS',
#   'fiber',
#   10.0,
#   'fresh water'),
#  'PBS fiber 1-10 mm (emission to marine water)': ('PBS',
#   'fiber',
#   10.0,
#   'marine water'),
#  'PBS fiber 1-10 mm (emission to soil)': ('PBS', 'fiber', 10.0, 'soil'),
#  'PBS particle 0.01-0.1 mm (emission to air)': ('PBS', 'particle', 0.1, 'air'),
#  'PBS particle 0.01-0.1 mm (emission to fresh water)': ('PBS',
#   'particle',
#   0.1,
#   'fresh water'),
#  'PBS particle 0.01-0.1 mm (emission to marine water)': ('PBS',
#   'particle',
#   0.1,
#   'marine water'),
#  'PBS particle 0.01-0.1 mm (emission to soil)': ('PBS',
#   'particle',
#   0.1,
#   'soil'),
#  'PBS particle 0.1-1 mm (emission to air)': ('PBS', 'particle', 1.0, 'air'),
#  'PBS particle 0.1-1 mm (emission to fresh water)': ('PBS',
#   'particle',
#   1.0,
#   'fresh water'),
#  'PBS particle 0.1-1 mm (emission to marine water)': ('PBS',
#   'particle',
#   1.0,
#   'marine water'),
#  'PBS particle 0.1-1 mm (emission to soil)': ('PBS', 'particle', 1.0, 'soil'),
#  'PBS particle 1-10 mm (emission to air)': ('PBS', 'particle', 10.0, 'air'),
#  'PBS particle 1-10 mm (emission to fresh water)': ('PBS',
#   'particle',
#   10.0,
#   'fresh water'),
#  'PBS particle 1-10 mm (emission to marine water)': ('PBS',
#   'particle',
#   10.0,
#   'marine water'),
#  'PBS particle 1-10 mm (emission to soil)': ('PBS', 'particle', 10.0, 'soil'),
#  'PBSA film 0.01-0.1 mm (emission to air)': ('PBSA', 'film', 0.1, 'air'),
#  'PBSA film 0.01-0.1 mm (emission to fresh water)': ('PBSA',
#   'film',
#   0.1,
#   'fresh water'),
#  'PBSA film 0.01-0.1 mm (emission to marine water)': ('PBSA',
#   'film',
#   0.1,
#   'marine water'),
#  'PBSA film 0.01-0.1 mm (emission to soil)': ('PBSA', 'film', 0.1, 'soil'),
#  'PBSA film 0.1-1 mm (emission to air)': ('PBSA', 'film', 1.0, 'air'),
#  'PBSA film 0.1-1 mm (emission to fresh water)': ('PBSA',
#   'film',
#   1.0,
#   'fresh water'),
#  'PBSA film 0.1-1 mm (emission to marine water)': ('PBSA',
#   'film',
#   1.0,
#   'marine water'),
#  'PBSA film 0.1-1 mm (emission to soil)': ('PBSA', 'film', 1.0, 'soil'),
#  'PBSA film 1-10 mm (emission to air)': ('PBSA', 'film', 10.0, 'air'),
#  'PBSA film 1-10 mm (emission to fresh water)': ('PBSA',
#   'film',
#   10.0,
#   'fresh water'),
#  'PBSA film 1-10 mm (emission to marine water)': ('PBSA',
#   'film',
#   10.0,
#   'marine water'),
#  'PBSA film 1-10 mm (emission to soil)': ('PBSA', 'film', 10.0, 'soil'),
#  'PBSA fiber 0.01-0.1 mm (emission to air)': ('PBSA', 'fiber', 0.1, 'air'),
#  'PBSA fiber 0.01-0.1 mm (emission to fresh water)': ('PBSA',
#   'fiber',
#   0.1,
#   'fresh water'),
#  'PBSA fiber 0.01-0.1 mm (emission to marine water)': ('PBSA',
#   'fiber',
#   0.1,
#   'marine water'),
#  'PBSA fiber 0.01-0.1 mm (emission to soil)': ('PBSA', 'fiber', 0.1, 'soil'),
#  'PBSA fiber 0.1-1 mm (emission to air)': ('PBSA', 'fiber', 1.0, 'air'),
#  'PBSA fiber 0.1-1 mm (emission to fresh water)': ('PBSA',
#   'fiber',
#   1.0,
#   'fresh water'),
#  'PBSA fiber 0.1-1 mm (emission to marine water)': ('PBSA',
#   'fiber',
#   1.0,
#   'marine water'),
#  'PBSA fiber 0.1-1 mm (emission to soil)': ('PBSA', 'fiber', 1.0, 'soil'),
#  'PBSA fiber 1-10 mm (emission to air)': ('PBSA', 'fiber', 10.0, 'air'),
#  'PBSA fiber 1-10 mm (emission to fresh water)': ('PBSA',
#   'fiber',
#   10.0,
#   'fresh water'),
#  'PBSA fiber 1-10 mm (emission to marine water)': ('PBSA',
#   'fiber',
#   10.0,
#   'marine water'),
#  'PBSA fiber 1-10 mm (emission to soil)': ('PBSA', 'fiber', 10.0, 'soil'),
#  'PBSA particle 0.01-0.1 mm (emission to air)': ('PBSA',
#   'particle',
#   0.1,
#   'air'),
#  'PBSA particle 0.01-0.1 mm (emission to fresh water)': ('PBSA',
#   'particle',
#   0.1,
#   'fresh water'),
#  'PBSA particle 0.01-0.1 mm (emission to marine water)': ('PBSA',
#   'particle',
#   0.1,
#   'marine water'),
#  'PBSA particle 0.01-0.1 mm (emission to soil)': ('PBSA',
#   'particle',
#   0.1,
#   'soil'),
#  'PBSA particle 0.1-1 mm (emission to air)': ('PBSA', 'particle', 1.0, 'air'),
#  'PBSA particle 0.1-1 mm (emission to fresh water)': ('PBSA',
#   'particle',
#   1.0,
#   'fresh water'),
#  'PBSA particle 0.1-1 mm (emission to marine water)': ('PBSA',
#   'particle',
#   1.0,
#   'marine water'),
#  'PBSA particle 0.1-1 mm (emission to soil)': ('PBSA',
#   'particle',
#   1.0,
#   'soil'),
#  'PBSA particle 1-10 mm (emission to air)': ('PBSA', 'particle', 10.0, 'air'),
#  'PBSA particle 1-10 mm (emission to fresh water)': ('PBSA',
#   'particle',
#   10.0,
#   'fresh water'),
#  'PBSA particle 1-10 mm (emission to marine water)': ('PBSA',
#   'particle',
#   10.0,
#   'marine water'),
#  'PBSA particle 1-10 mm (emission to soil)': ('PBSA',
#   'particle',
#   10.0,
#   'soil'),
#  'PBSe film 0.01-0.1 mm (emission to air)': ('PBSe', 'film', 0.1, 'air'),
#  'PBSe film 0.01-0.1 mm (emission to fresh water)': ('PBSe',
#   'film',
#   0.1,
#   'fresh water'),
#  'PBSe film 0.01-0.1 mm (emission to marine water)': ('PBSe',
#   'film',
#   0.1,
#   'marine water'),
#  'PBSe film 0.01-0.1 mm (emission to soil)': ('PBSe', 'film', 0.1, 'soil'),
#  'PBSe film 0.1-1 mm (emission to air)': ('PBSe', 'film', 1.0, 'air'),
#  'PBSe film 0.1-1 mm (emission to fresh water)': ('PBSe',
#   'film',
#   1.0,
#   'fresh water'),
#  'PBSe film 0.1-1 mm (emission to marine water)': ('PBSe',
#   'film',
#   1.0,
#   'marine water'),
#  'PBSe film 0.1-1 mm (emission to soil)': ('PBSe', 'film', 1.0, 'soil'),
#  'PBSe film 1-10 mm (emission to air)': ('PBSe', 'film', 10.0, 'air'),
#  'PBSe film 1-10 mm (emission to fresh water)': ('PBSe',
#   'film',
#   10.0,
#   'fresh water'),
#  'PBSe film 1-10 mm (emission to marine water)': ('PBSe',
#   'film',
#   10.0,
#   'marine water'),
#  'PBSe film 1-10 mm (emission to soil)': ('PBSe', 'film', 10.0, 'soil'),
#  'PBSe fiber 0.01-0.1 mm (emission to air)': ('PBSe', 'fiber', 0.1, 'air'),
#  'PBSe fiber 0.01-0.1 mm (emission to fresh water)': ('PBSe',
#   'fiber',
#   0.1,
#   'fresh water'),
#  'PBSe fiber 0.01-0.1 mm (emission to marine water)': ('PBSe',
#   'fiber',
#   0.1,
#   'marine water'),
#  'PBSe fiber 0.01-0.1 mm (emission to soil)': ('PBSe', 'fiber', 0.1, 'soil'),
#  'PBSe fiber 0.1-1 mm (emission to air)': ('PBSe', 'fiber', 1.0, 'air'),
#  'PBSe fiber 0.1-1 mm (emission to fresh water)': ('PBSe',
#   'fiber',
#   1.0,
#   'fresh water'),
#  'PBSe fiber 0.1-1 mm (emission to marine water)': ('PBSe',
#   'fiber',
#   1.0,
#   'marine water'),
#  'PBSe fiber 0.1-1 mm (emission to soil)': ('PBSe', 'fiber', 1.0, 'soil'),
#  'PBSe fiber 1-10 mm (emission to air)': ('PBSe', 'fiber', 10.0, 'air'),
#  'PBSe fiber 1-10 mm (emission to fresh water)': ('PBSe',
#   'fiber',
#   10.0,
#   'fresh water'),
#  'PBSe fiber 1-10 mm (emission to marine water)': ('PBSe',
#   'fiber',
#   10.0,
#   'marine water'),
#  'PBSe fiber 1-10 mm (emission to soil)': ('PBSe', 'fiber', 10.0, 'soil'),
#  'PBSe particle 0.01-0.1 mm (emission to air)': ('PBSe',
#   'particle',
#   0.1,
#   'air'),
#  'PBSe particle 0.01-0.1 mm (emission to fresh water)': ('PBSe',
#   'particle',
#   0.1,
#   'fresh water'),
#  'PBSe particle 0.01-0.1 mm (emission to marine water)': ('PBSe',
#   'particle',
#   0.1,
#   'marine water'),
#  'PBSe particle 0.01-0.1 mm (emission to soil)': ('PBSe',
#   'particle',
#   0.1,
#   'soil'),
#  'PBSe particle 0.1-1 mm (emission to air)': ('PBSe', 'particle', 1.0, 'air'),
#  'PBSe particle 0.1-1 mm (emission to fresh water)': ('PBSe',
#   'particle',
#   1.0,
#   'fresh water'),
#  'PBSe particle 0.1-1 mm (emission to marine water)': ('PBSe',
#   'particle',
#   1.0,
#   'marine water'),
#  'PBSe particle 0.1-1 mm (emission to soil)': ('PBSe',
#   'particle',
#   1.0,
#   'soil'),
#  'PBSe particle 1-10 mm (emission to air)': ('PBSe', 'particle', 10.0, 'air'),
#  'PBSe particle 1-10 mm (emission to fresh water)': ('PBSe',
#   'particle',
#   10.0,
#   'fresh water'),
#  'PBSe particle 1-10 mm (emission to marine water)': ('PBSe',
#   'particle',
#   10.0,
#   'marine water'),
#  'PBSe particle 1-10 mm (emission to soil)': ('PBSe',
#   'particle',
#   10.0,
#   'soil'),
#  'PBSeT film 0.01-0.1 mm (emission to air)': ('PBSeT', 'film', 0.1, 'air'),
#  'PBSeT film 0.01-0.1 mm (emission to fresh water)': ('PBSeT',
#   'film',
#   0.1,
#   'fresh water'),
#  'PBSeT film 0.01-0.1 mm (emission to marine water)': ('PBSeT',
#   'film',
#   0.1,
#   'marine water'),
#  'PBSeT film 0.01-0.1 mm (emission to soil)': ('PBSeT', 'film', 0.1, 'soil'),
#  'PBSeT film 0.1-1 mm (emission to air)': ('PBSeT', 'film', 1.0, 'air'),
#  'PBSeT film 0.1-1 mm (emission to fresh water)': ('PBSeT',
#   'film',
#   1.0,
#   'fresh water'),
#  'PBSeT film 0.1-1 mm (emission to marine water)': ('PBSeT',
#   'film',
#   1.0,
#   'marine water'),
#  'PBSeT film 0.1-1 mm (emission to soil)': ('PBSeT', 'film', 1.0, 'soil'),
#  'PBSeT film 1-10 mm (emission to air)': ('PBSeT', 'film', 10.0, 'air'),
#  'PBSeT film 1-10 mm (emission to fresh water)': ('PBSeT',
#   'film',
#   10.0,
#   'fresh water'),
#  'PBSeT film 1-10 mm (emission to marine water)': ('PBSeT',
#   'film',
#   10.0,
#   'marine water'),
#  'PBSeT film 1-10 mm (emission to soil)': ('PBSeT', 'film', 10.0, 'soil'),
#  'PBSeT fiber 0.01-0.1 mm (emission to air)': ('PBSeT', 'fiber', 0.1, 'air'),
#  'PBSeT fiber 0.01-0.1 mm (emission to fresh water)': ('PBSeT',
#   'fiber',
#   0.1,
#   'fresh water'),
#  'PBSeT fiber 0.01-0.1 mm (emission to marine water)': ('PBSeT',
#   'fiber',
#   0.1,
#   'marine water'),
#  'PBSeT fiber 0.01-0.1 mm (emission to soil)': ('PBSeT', 'fiber', 0.1, 'soil'),
#  'PBSeT fiber 0.1-1 mm (emission to air)': ('PBSeT', 'fiber', 1.0, 'air'),
#  'PBSeT fiber 0.1-1 mm (emission to fresh water)': ('PBSeT',
#   'fiber',
#   1.0,
#   'fresh water'),
#  'PBSeT fiber 0.1-1 mm (emission to marine water)': ('PBSeT',
#   'fiber',
#   1.0,
#   'marine water'),
#  'PBSeT fiber 0.1-1 mm (emission to soil)': ('PBSeT', 'fiber', 1.0, 'soil'),
#  'PBSeT fiber 1-10 mm (emission to air)': ('PBSeT', 'fiber', 10.0, 'air'),
#  'PBSeT fiber 1-10 mm (emission to fresh water)': ('PBSeT',
#   'fiber',
#   10.0,
#   'fresh water'),
#  'PBSeT fiber 1-10 mm (emission to marine water)': ('PBSeT',
#   'fiber',
#   10.0,
#   'marine water'),
#  'PBSeT fiber 1-10 mm (emission to soil)': ('PBSeT', 'fiber', 10.0, 'soil'),
#  'PBSeT particle 0.01-0.1 mm (emission to air)': ('PBSeT',
#   'particle',
#   0.1,
#   'air'),
#  'PBSeT particle 0.01-0.1 mm (emission to fresh water)': ('PBSeT',
#   'particle',
#   0.1,
#   'fresh water'),
#  'PBSeT particle 0.01-0.1 mm (emission to marine water)': ('PBSeT',
#   'particle',
#   0.1,
#   'marine water'),
#  'PBSeT particle 0.01-0.1 mm (emission to soil)': ('PBSeT',
#   'particle',
#   0.1,
#   'soil'),
#  'PBSeT particle 0.1-1 mm (emission to air)': ('PBSeT',
#   'particle',
#   1.0,
#   'air'),
#  'PBSeT particle 0.1-1 mm (emission to fresh water)': ('PBSeT',
#   'particle',
#   1.0,
#   'fresh water'),
#  'PBSeT particle 0.1-1 mm (emission to marine water)': ('PBSeT',
#   'particle',
#   1.0,
#   'marine water'),
#  'PBSeT particle 0.1-1 mm (emission to soil)': ('PBSeT',
#   'particle',
#   1.0,
#   'soil'),
#  'PBSeT particle 1-10 mm (emission to air)': ('PBSeT',
#   'particle',
#   10.0,
#   'air'),
#  'PBSeT particle 1-10 mm (emission to fresh water)': ('PBSeT',
#   'particle',
#   10.0,
#   'fresh water'),
#  'PBSeT particle 1-10 mm (emission to marine water)': ('PBSeT',
#   'particle',
#   10.0,
#   'marine water'),
#  'PBSeT particle 1-10 mm (emission to soil)': ('PBSeT',
#   'particle',
#   10.0,
#   'soil'),
#  'PC film 0.01-0.1 mm (emission to air)': ('PC', 'film', 0.1, 'air'),
#  'PC film 0.01-0.1 mm (emission to fresh water)': ('PC',
#   'film',
#   0.1,
#   'fresh water'),
#  'PC film 0.01-0.1 mm (emission to marine water)': ('PC',
#   'film',
#   0.1,
#   'marine water'),
#  'PC film 0.01-0.1 mm (emission to soil)': ('PC', 'film', 0.1, 'soil'),
#  'PC film 0.1-1 mm (emission to air)': ('PC', 'film', 1.0, 'air'),
#  'PC film 0.1-1 mm (emission to fresh water)': ('PC',
#   'film',
#   1.0,
#   'fresh water'),
#  'PC film 0.1-1 mm (emission to marine water)': ('PC',
#   'film',
#   1.0,
#   'marine water'),
#  'PC film 0.1-1 mm (emission to soil)': ('PC', 'film', 1.0, 'soil'),
#  'PC film 1-10 mm (emission to air)': ('PC', 'film', 10.0, 'air'),
#  'PC film 1-10 mm (emission to fresh water)': ('PC',
#   'film',
#   10.0,
#   'fresh water'),
#  'PC film 1-10 mm (emission to marine water)': ('PC',
#   'film',
#   10.0,
#   'marine water'),
#  'PC film 1-10 mm (emission to soil)': ('PC', 'film', 10.0, 'soil'),
#  'PC fiber 0.01-0.1 mm (emission to air)': ('PC', 'fiber', 0.1, 'air'),
#  'PC fiber 0.01-0.1 mm (emission to fresh water)': ('PC',
#   'fiber',
#   0.1,
#   'fresh water'),
#  'PC fiber 0.01-0.1 mm (emission to marine water)': ('PC',
#   'fiber',
#   0.1,
#   'marine water'),
#  'PC fiber 0.01-0.1 mm (emission to soil)': ('PC', 'fiber', 0.1, 'soil'),
#  'PC fiber 0.1-1 mm (emission to air)': ('PC', 'fiber', 1.0, 'air'),
#  'PC fiber 0.1-1 mm (emission to fresh water)': ('PC',
#   'fiber',
#   1.0,
#   'fresh water'),
#  'PC fiber 0.1-1 mm (emission to marine water)': ('PC',
#   'fiber',
#   1.0,
#   'marine water'),
#  'PC fiber 0.1-1 mm (emission to soil)': ('PC', 'fiber', 1.0, 'soil'),
#  'PC fiber 1-10 mm (emission to air)': ('PC', 'fiber', 10.0, 'air'),
#  'PC fiber 1-10 mm (emission to fresh water)': ('PC',
#   'fiber',
#   10.0,
#   'fresh water'),
#  'PC fiber 1-10 mm (emission to marine water)': ('PC',
#   'fiber',
#   10.0,
#   'marine water'),
#  'PC fiber 1-10 mm (emission to soil)': ('PC', 'fiber', 10.0, 'soil'),
#  'PC particle 0.01-0.1 mm (emission to air)': ('PC', 'particle', 0.1, 'air'),
#  'PC particle 0.01-0.1 mm (emission to fresh water)': ('PC',
#   'particle',
#   0.1,
#   'fresh water'),
#  'PC particle 0.01-0.1 mm (emission to marine water)': ('PC',
#   'particle',
#   0.1,
#   'marine water'),
#  'PC particle 0.01-0.1 mm (emission to soil)': ('PC', 'particle', 0.1, 'soil'),
#  'PC particle 0.1-1 mm (emission to air)': ('PC', 'particle', 1.0, 'air'),
#  'PC particle 0.1-1 mm (emission to fresh water)': ('PC',
#   'particle',
#   1.0,
#   'fresh water'),
#  'PC particle 0.1-1 mm (emission to marine water)': ('PC',
#   'particle',
#   1.0,
#   'marine water'),
#  'PC particle 0.1-1 mm (emission to soil)': ('PC', 'particle', 1.0, 'soil'),
#  'PC particle 1-10 mm (emission to air)': ('PC', 'particle', 10.0, 'air'),
#  'PC particle 1-10 mm (emission to fresh water)': ('PC',
#   'particle',
#   10.0,
#   'fresh water'),
#  'PC particle 1-10 mm (emission to marine water)': ('PC',
#   'particle',
#   10.0,
#   'marine water'),
#  'PC particle 1-10 mm (emission to soil)': ('PC', 'particle', 10.0, 'soil'),
#  'PCL film 0.01-0.1 mm (emission to air)': ('PCL', 'film', 0.1, 'air'),
#  'PCL film 0.01-0.1 mm (emission to fresh water)': ('PCL',
#   'film',
#   0.1,
#   'fresh water'),
#  'PCL film 0.01-0.1 mm (emission to marine water)': ('PCL',
#   'film',
#   0.1,
#   'marine water'),
#  'PCL film 0.01-0.1 mm (emission to soil)': ('PCL', 'film', 0.1, 'soil'),
#  'PCL film 0.1-1 mm (emission to air)': ('PCL', 'film', 1.0, 'air'),
#  'PCL film 0.1-1 mm (emission to fresh water)': ('PCL',
#   'film',
#   1.0,
#   'fresh water'),
#  'PCL film 0.1-1 mm (emission to marine water)': ('PCL',
#   'film',
#   1.0,
#   'marine water'),
#  'PCL film 0.1-1 mm (emission to soil)': ('PCL', 'film', 1.0, 'soil'),
#  'PCL film 1-10 mm (emission to air)': ('PCL', 'film', 10.0, 'air'),
#  'PCL film 1-10 mm (emission to fresh water)': ('PCL',
#   'film',
#   10.0,
#   'fresh water'),
#  'PCL film 1-10 mm (emission to marine water)': ('PCL',
#   'film',
#   10.0,
#   'marine water'),
#  'PCL film 1-10 mm (emission to soil)': ('PCL', 'film', 10.0, 'soil'),
#  'PCL fiber 0.01-0.1 mm (emission to air)': ('PCL', 'fiber', 0.1, 'air'),
#  'PCL fiber 0.01-0.1 mm (emission to fresh water)': ('PCL',
#   'fiber',
#   0.1,
#   'fresh water'),
#  'PCL fiber 0.01-0.1 mm (emission to marine water)': ('PCL',
#   'fiber',
#   0.1,
#   'marine water'),
#  'PCL fiber 0.01-0.1 mm (emission to soil)': ('PCL', 'fiber', 0.1, 'soil'),
#  'PCL fiber 0.1-1 mm (emission to air)': ('PCL', 'fiber', 1.0, 'air'),
#  'PCL fiber 0.1-1 mm (emission to fresh water)': ('PCL',
#   'fiber',
#   1.0,
#   'fresh water'),
#  'PCL fiber 0.1-1 mm (emission to marine water)': ('PCL',
#   'fiber',
#   1.0,
#   'marine water'),
#  'PCL fiber 0.1-1 mm (emission to soil)': ('PCL', 'fiber', 1.0, 'soil'),
#  'PCL fiber 1-10 mm (emission to air)': ('PCL', 'fiber', 10.0, 'air'),
#  'PCL fiber 1-10 mm (emission to fresh water)': ('PCL',
#   'fiber',
#   10.0,
#   'fresh water'),
#  'PCL fiber 1-10 mm (emission to marine water)': ('PCL',
#   'fiber',
#   10.0,
#   'marine water'),
#  'PCL fiber 1-10 mm (emission to soil)': ('PCL', 'fiber', 10.0, 'soil'),
#  'PCL particle 0.01-0.1 mm (emission to air)': ('PCL', 'particle', 0.1, 'air'),
#  'PCL particle 0.01-0.1 mm (emission to fresh water)': ('PCL',
#   'particle',
#   0.1,
#   'fresh water'),
#  'PCL particle 0.01-0.1 mm (emission to marine water)': ('PCL',
#   'particle',
#   0.1,
#   'marine water'),
#  'PCL particle 0.01-0.1 mm (emission to soil)': ('PCL',
#   'particle',
#   0.1,
#   'soil'),
#  'PCL particle 0.1-1 mm (emission to air)': ('PCL', 'particle', 1.0, 'air'),
#  'PCL particle 0.1-1 mm (emission to fresh water)': ('PCL',
#   'particle',
#   1.0,
#   'fresh water'),
#  'PCL particle 0.1-1 mm (emission to marine water)': ('PCL',
#   'particle',
#   1.0,
#   'marine water'),
#  'PCL particle 0.1-1 mm (emission to soil)': ('PCL', 'particle', 1.0, 'soil'),
#  'PCL particle 1-10 mm (emission to air)': ('PCL', 'particle', 10.0, 'air'),
#  'PCL particle 1-10 mm (emission to fresh water)': ('PCL',
#   'particle',
#   10.0,
#   'fresh water'),
#  'PCL particle 1-10 mm (emission to marine water)': ('PCL',
#   'particle',
#   10.0,
#   'marine water'),
#  'PCL particle 1-10 mm (emission to soil)': ('PCL', 'particle', 10.0, 'soil'),
#  'PE film 0.01-0.1 mm (emission to air)': ('PE', 'film', 0.1, 'air'),
#  'PE film 0.01-0.1 mm (emission to fresh water)': ('PE',
#   'film',
#   0.1,
#   'fresh water'),
#  'PE film 0.01-0.1 mm (emission to marine water)': ('PE',
#   'film',
#   0.1,
#   'marine water'),
#  'PE film 0.01-0.1 mm (emission to soil)': ('PE', 'film', 0.1, 'soil'),
#  'PE film 0.1-1 mm (emission to air)': ('PE', 'film', 1.0, 'air'),
#  'PE film 0.1-1 mm (emission to fresh water)': ('PE',
#   'film',
#   1.0,
#   'fresh water'),
#  'PE film 0.1-1 mm (emission to marine water)': ('PE',
#   'film',
#   1.0,
#   'marine water'),
#  'PE film 0.1-1 mm (emission to soil)': ('PE', 'film', 1.0, 'soil'),
#  'PE film 1-10 mm (emission to air)': ('PE', 'film', 10.0, 'air'),
#  'PE film 1-10 mm (emission to fresh water)': ('PE',
#   'film',
#   10.0,
#   'fresh water'),
#  'PE film 1-10 mm (emission to marine water)': ('PE',
#   'film',
#   10.0,
#   'marine water'),
#  'PE film 1-10 mm (emission to soil)': ('PE', 'film', 10.0, 'soil'),
#  'PE fiber 0.01-0.1 mm (emission to air)': ('PE', 'fiber', 0.1, 'air'),
#  'PE fiber 0.01-0.1 mm (emission to fresh water)': ('PE',
#   'fiber',
#   0.1,
#   'fresh water'),
#  'PE fiber 0.01-0.1 mm (emission to marine water)': ('PE',
#   'fiber',
#   0.1,
#   'marine water'),
#  'PE fiber 0.01-0.1 mm (emission to soil)': ('PE', 'fiber', 0.1, 'soil'),
#  'PE fiber 0.1-1 mm (emission to air)': ('PE', 'fiber', 1.0, 'air'),
#  'PE fiber 0.1-1 mm (emission to fresh water)': ('PE',
#   'fiber',
#   1.0,
#   'fresh water'),
#  'PE fiber 0.1-1 mm (emission to marine water)': ('PE',
#   'fiber',
#   1.0,
#   'marine water'),
#  'PE fiber 0.1-1 mm (emission to soil)': ('PE', 'fiber', 1.0, 'soil'),
#  'PE fiber 1-10 mm (emission to air)': ('PE', 'fiber', 10.0, 'air'),
#  'PE fiber 1-10 mm (emission to fresh water)': ('PE',
#   'fiber',
#   10.0,
#   'fresh water'),
#  'PE fiber 1-10 mm (emission to marine water)': ('PE',
#   'fiber',
#   10.0,
#   'marine water'),
#  'PE fiber 1-10 mm (emission to soil)': ('PE', 'fiber', 10.0, 'soil'),
#  'PE particle 0.01-0.1 mm (emission to air)': ('PE', 'particle', 0.1, 'air'),
#  'PE particle 0.01-0.1 mm (emission to fresh water)': ('PE',
#   'particle',
#   0.1,
#   'fresh water'),
#  'PE particle 0.01-0.1 mm (emission to marine water)': ('PE',
#   'particle',
#   0.1,
#   'marine water'),
#  'PE particle 0.01-0.1 mm (emission to soil)': ('PE', 'particle', 0.1, 'soil'),
#  'PE particle 0.1-1 mm (emission to air)': ('PE', 'particle', 1.0, 'air'),
#  'PE particle 0.1-1 mm (emission to fresh water)': ('PE',
#   'particle',
#   1.0,
#   'fresh water'),
#  'PE particle 0.1-1 mm (emission to marine water)': ('PE',
#   'particle',
#   1.0,
#   'marine water'),
#  'PE particle 0.1-1 mm (emission to soil)': ('PE', 'particle', 1.0, 'soil'),
#  'PE particle 1-10 mm (emission to air)': ('PE', 'particle', 10.0, 'air'),
#  'PE particle 1-10 mm (emission to fresh water)': ('PE',
#   'particle',
#   10.0,
#   'fresh water'),
#  'PE particle 1-10 mm (emission to marine water)': ('PE',
#   'particle',
#   10.0,
#   'marine water'),
#  'PE particle 1-10 mm (emission to soil)': ('PE', 'particle', 10.0, 'soil'),
#  'PEA film 0.01-0.1 mm (emission to air)': ('PEA', 'film', 0.1, 'air'),
#  'PEA film 0.01-0.1 mm (emission to fresh water)': ('PEA',
#   'film',
#   0.1,
#   'fresh water'),
#  'PEA film 0.01-0.1 mm (emission to marine water)': ('PEA',
#   'film',
#   0.1,
#   'marine water'),
#  'PEA film 0.01-0.1 mm (emission to soil)': ('PEA', 'film', 0.1, 'soil'),
#  'PEA film 0.1-1 mm (emission to air)': ('PEA', 'film', 1.0, 'air'),
#  'PEA film 0.1-1 mm (emission to fresh water)': ('PEA',
#   'film',
#   1.0,
#   'fresh water'),
#  'PEA film 0.1-1 mm (emission to marine water)': ('PEA',
#   'film',
#   1.0,
#   'marine water'),
#  'PEA film 0.1-1 mm (emission to soil)': ('PEA', 'film', 1.0, 'soil'),
#  'PEA film 1-10 mm (emission to air)': ('PEA', 'film', 10.0, 'air'),
#  'PEA film 1-10 mm (emission to fresh water)': ('PEA',
#   'film',
#   10.0,
#   'fresh water'),
#  'PEA film 1-10 mm (emission to marine water)': ('PEA',
#   'film',
#   10.0,
#   'marine water'),
#  'PEA film 1-10 mm (emission to soil)': ('PEA', 'film', 10.0, 'soil'),
#  'PEA fiber 0.01-0.1 mm (emission to air)': ('PEA', 'fiber', 0.1, 'air'),
#  'PEA fiber 0.01-0.1 mm (emission to fresh water)': ('PEA',
#   'fiber',
#   0.1,
#   'fresh water'),
#  'PEA fiber 0.01-0.1 mm (emission to marine water)': ('PEA',
#   'fiber',
#   0.1,
#   'marine water'),
#  'PEA fiber 0.01-0.1 mm (emission to soil)': ('PEA', 'fiber', 0.1, 'soil'),
#  'PEA fiber 0.1-1 mm (emission to air)': ('PEA', 'fiber', 1.0, 'air'),
#  'PEA fiber 0.1-1 mm (emission to fresh water)': ('PEA',
#   'fiber',
#   1.0,
#   'fresh water'),
#  'PEA fiber 0.1-1 mm (emission to marine water)': ('PEA',
#   'fiber',
#   1.0,
#   'marine water'),
#  'PEA fiber 0.1-1 mm (emission to soil)': ('PEA', 'fiber', 1.0, 'soil'),
#  'PEA fiber 1-10 mm (emission to air)': ('PEA', 'fiber', 10.0, 'air'),
#  'PEA fiber 1-10 mm (emission to fresh water)': ('PEA',
#   'fiber',
#   10.0,
#   'fresh water'),
#  'PEA fiber 1-10 mm (emission to marine water)': ('PEA',
#   'fiber',
#   10.0,
#   'marine water'),
#  'PEA fiber 1-10 mm (emission to soil)': ('PEA', 'fiber', 10.0, 'soil'),
#  'PEA particle 0.01-0.1 mm (emission to air)': ('PEA', 'particle', 0.1, 'air'),
#  'PEA particle 0.01-0.1 mm (emission to fresh water)': ('PEA',
#   'particle',
#   0.1,
#   'fresh water'),
#  'PEA particle 0.01-0.1 mm (emission to marine water)': ('PEA',
#   'particle',
#   0.1,
#   'marine water'),
#  'PEA particle 0.01-0.1 mm (emission to soil)': ('PEA',
#   'particle',
#   0.1,
#   'soil'),
#  'PEA particle 0.1-1 mm (emission to air)': ('PEA', 'particle', 1.0, 'air'),
#  'PEA particle 0.1-1 mm (emission to fresh water)': ('PEA',
#   'particle',
#   1.0,
#   'fresh water'),
#  'PEA particle 0.1-1 mm (emission to marine water)': ('PEA',
#   'particle',
#   1.0,
#   'marine water'),
#  'PEA particle 0.1-1 mm (emission to soil)': ('PEA', 'particle', 1.0, 'soil'),
#  'PEA particle 1-10 mm (emission to air)': ('PEA', 'particle', 10.0, 'air'),
#  'PEA particle 1-10 mm (emission to fresh water)': ('PEA',
#   'particle',
#   10.0,
#   'fresh water'),
#  'PEA particle 1-10 mm (emission to marine water)': ('PEA',
#   'particle',
#   10.0,
#   'marine water'),
#  'PEA particle 1-10 mm (emission to soil)': ('PEA', 'particle', 10.0, 'soil'),
#  'PES film 0.01-0.1 mm (emission to air)': ('PES', 'film', 0.1, 'air'),
#  'PES film 0.01-0.1 mm (emission to fresh water)': ('PES',
#   'film',
#   0.1,
#   'fresh water'),
#  'PES film 0.01-0.1 mm (emission to marine water)': ('PES',
#   'film',
#   0.1,
#   'marine water'),
#  'PES film 0.01-0.1 mm (emission to soil)': ('PES', 'film', 0.1, 'soil'),
#  'PES film 0.1-1 mm (emission to air)': ('PES', 'film', 1.0, 'air'),
#  'PES film 0.1-1 mm (emission to fresh water)': ('PES',
#   'film',
#   1.0,
#   'fresh water'),
#  'PES film 0.1-1 mm (emission to marine water)': ('PES',
#   'film',
#   1.0,
#   'marine water'),
#  'PES film 0.1-1 mm (emission to soil)': ('PES', 'film', 1.0, 'soil'),
#  'PES film 1-10 mm (emission to air)': ('PES', 'film', 10.0, 'air'),
#  'PES film 1-10 mm (emission to fresh water)': ('PES',
#   'film',
#   10.0,
#   'fresh water'),
#  'PES film 1-10 mm (emission to marine water)': ('PES',
#   'film',
#   10.0,
#   'marine water'),
#  'PES film 1-10 mm (emission to soil)': ('PES', 'film', 10.0, 'soil'),
#  'PES fiber 0.01-0.1 mm (emission to air)': ('PES', 'fiber', 0.1, 'air'),
#  'PES fiber 0.01-0.1 mm (emission to fresh water)': ('PES',
#   'fiber',
#   0.1,
#   'fresh water'),
#  'PES fiber 0.01-0.1 mm (emission to marine water)': ('PES',
#   'fiber',
#   0.1,
#   'marine water'),
#  'PES fiber 0.01-0.1 mm (emission to soil)': ('PES', 'fiber', 0.1, 'soil'),
#  'PES fiber 0.1-1 mm (emission to air)': ('PES', 'fiber', 1.0, 'air'),
#  'PES fiber 0.1-1 mm (emission to fresh water)': ('PES',
#   'fiber',
#   1.0,
#   'fresh water'),
#  'PES fiber 0.1-1 mm (emission to marine water)': ('PES',
#   'fiber',
#   1.0,
#   'marine water'),
#  'PES fiber 0.1-1 mm (emission to soil)': ('PES', 'fiber', 1.0, 'soil'),
#  'PES fiber 1-10 mm (emission to air)': ('PES', 'fiber', 10.0, 'air'),
#  'PES fiber 1-10 mm (emission to fresh water)': ('PES',
#   'fiber',
#   10.0,
#   'fresh water'),
#  'PES fiber 1-10 mm (emission to marine water)': ('PES',
#   'fiber',
#   10.0,
#   'marine water'),
#  'PES fiber 1-10 mm (emission to soil)': ('PES', 'fiber', 10.0, 'soil'),
#  'PES particle 0.01-0.1 mm (emission to air)': ('PES', 'particle', 0.1, 'air'),
#  'PES particle 0.01-0.1 mm (emission to fresh water)': ('PES',
#   'particle',
#   0.1,
#   'fresh water'),
#  'PES particle 0.01-0.1 mm (emission to marine water)': ('PES',
#   'particle',
#   0.1,
#   'marine water'),
#  'PES particle 0.01-0.1 mm (emission to soil)': ('PES',
#   'particle',
#   0.1,
#   'soil'),
#  'PES particle 0.1-1 mm (emission to air)': ('PES', 'particle', 1.0, 'air'),
#  'PES particle 0.1-1 mm (emission to fresh water)': ('PES',
#   'particle',
#   1.0,
#   'fresh water'),
#  'PES particle 0.1-1 mm (emission to marine water)': ('PES',
#   'particle',
#   1.0,
#   'marine water'),
#  'PES particle 0.1-1 mm (emission to soil)': ('PES', 'particle', 1.0, 'soil'),
#  'PES particle 1-10 mm (emission to air)': ('PES', 'particle', 10.0, 'air'),
#  'PES particle 1-10 mm (emission to fresh water)': ('PES',
#   'particle',
#   10.0,
#   'fresh water'),
#  'PES particle 1-10 mm (emission to marine water)': ('PES',
#   'particle',
#   10.0,
#   'marine water'),
#  'PES particle 1-10 mm (emission to soil)': ('PES', 'particle', 10.0, 'soil'),
#  'PET film 0.01-0.1 mm (emission to air)': ('PET', 'film', 0.1, 'air'),
#  'PET film 0.01-0.1 mm (emission to fresh water)': ('PET',
#   'film',
#   0.1,
#   'fresh water'),
#  'PET film 0.01-0.1 mm (emission to marine water)': ('PET',
#   'film',
#   0.1,
#   'marine water'),
#  'PET film 0.01-0.1 mm (emission to soil)': ('PET', 'film', 0.1, 'soil'),
#  'PET film 0.1-1 mm (emission to air)': ('PET', 'film', 1.0, 'air'),
#  'PET film 0.1-1 mm (emission to fresh water)': ('PET',
#   'film',
#   1.0,
#   'fresh water'),
#  'PET film 0.1-1 mm (emission to marine water)': ('PET',
#   'film',
#   1.0,
#   'marine water'),
#  'PET film 0.1-1 mm (emission to soil)': ('PET', 'film', 1.0, 'soil'),
#  'PET film 1-10 mm (emission to air)': ('PET', 'film', 10.0, 'air'),
#  'PET film 1-10 mm (emission to fresh water)': ('PET',
#   'film',
#   10.0,
#   'fresh water'),
#  'PET film 1-10 mm (emission to marine water)': ('PET',
#   'film',
#   10.0,
#   'marine water'),
#  'PET film 1-10 mm (emission to soil)': ('PET', 'film', 10.0, 'soil'),
#  'PET fiber 0.01-0.1 mm (emission to air)': ('PET', 'fiber', 0.1, 'air'),
#  'PET fiber 0.01-0.1 mm (emission to fresh water)': ('PET',
#   'fiber',
#   0.1,
#   'fresh water'),
#  'PET fiber 0.01-0.1 mm (emission to marine water)': ('PET',
#   'fiber',
#   0.1,
#   'marine water'),
#  'PET fiber 0.01-0.1 mm (emission to soil)': ('PET', 'fiber', 0.1, 'soil'),
#  'PET fiber 0.1-1 mm (emission to air)': ('PET', 'fiber', 1.0, 'air'),
#  'PET fiber 0.1-1 mm (emission to fresh water)': ('PET',
#   'fiber',
#   1.0,
#   'fresh water'),
#  'PET fiber 0.1-1 mm (emission to marine water)': ('PET',
#   'fiber',
#   1.0,
#   'marine water'),
#  'PET fiber 0.1-1 mm (emission to soil)': ('PET', 'fiber', 1.0, 'soil'),
#  'PET fiber 1-10 mm (emission to air)': ('PET', 'fiber', 10.0, 'air'),
#  'PET fiber 1-10 mm (emission to fresh water)': ('PET',
#   'fiber',
#   10.0,
#   'fresh water'),
#  'PET fiber 1-10 mm (emission to marine water)': ('PET',
#   'fiber',
#   10.0,
#   'marine water'),
#  'PET fiber 1-10 mm (emission to soil)': ('PET', 'fiber', 10.0, 'soil'),
#  'PET particle 0.01-0.1 mm (emission to air)': ('PET', 'particle', 0.1, 'air'),
#  'PET particle 0.01-0.1 mm (emission to fresh water)': ('PET',
#   'particle',
#   0.1,
#   'fresh water'),
#  'PET particle 0.01-0.1 mm (emission to marine water)': ('PET',
#   'particle',
#   0.1,
#   'marine water'),
#  'PET particle 0.01-0.1 mm (emission to soil)': ('PET',
#   'particle',
#   0.1,
#   'soil'),
#  'PET particle 0.1-1 mm (emission to air)': ('PET', 'particle', 1.0, 'air'),
#  'PET particle 0.1-1 mm (emission to fresh water)': ('PET',
#   'particle',
#   1.0,
#   'fresh water'),
#  'PET particle 0.1-1 mm (emission to marine water)': ('PET',
#   'particle',
#   1.0,
#   'marine water'),
#  'PET particle 0.1-1 mm (emission to soil)': ('PET', 'particle', 1.0, 'soil'),
#  'PET particle 1-10 mm (emission to air)': ('PET', 'particle', 10.0, 'air'),
#  'PET particle 1-10 mm (emission to fresh water)': ('PET',
#   'particle',
#   10.0,
#   'fresh water'),
#  'PET particle 1-10 mm (emission to marine water)': ('PET',
#   'particle',
#   10.0,
#   'marine water'),
#  'PET particle 1-10 mm (emission to soil)': ('PET', 'particle', 10.0, 'soil'),
#  'PHA film 0.01-0.1 mm (emission to air)': ('PHA', 'film', 0.1, 'air'),
#  'PHA film 0.01-0.1 mm (emission to fresh water)': ('PHA',
#   'film',
#   0.1,
#   'fresh water'),
#  'PHA film 0.01-0.1 mm (emission to marine water)': ('PHA',
#   'film',
#   0.1,
#   'marine water'),
#  'PHA film 0.01-0.1 mm (emission to soil)': ('PHA', 'film', 0.1, 'soil'),
#  'PHA film 0.1-1 mm (emission to air)': ('PHA', 'film', 1.0, 'air'),
#  'PHA film 0.1-1 mm (emission to fresh water)': ('PHA',
#   'film',
#   1.0,
#   'fresh water'),
#  'PHA film 0.1-1 mm (emission to marine water)': ('PHA',
#   'film',
#   1.0,
#   'marine water'),
#  'PHA film 0.1-1 mm (emission to soil)': ('PHA', 'film', 1.0, 'soil'),
#  'PHA film 1-10 mm (emission to air)': ('PHA', 'film', 10.0, 'air'),
#  'PHA film 1-10 mm (emission to fresh water)': ('PHA',
#   'film',
#   10.0,
#   'fresh water'),
#  'PHA film 1-10 mm (emission to marine water)': ('PHA',
#   'film',
#   10.0,
#   'marine water'),
#  'PHA film 1-10 mm (emission to soil)': ('PHA', 'film', 10.0, 'soil'),
#  'PHA fiber 0.01-0.1 mm (emission to air)': ('PHA', 'fiber', 0.1, 'air'),
#  'PHA fiber 0.01-0.1 mm (emission to fresh water)': ('PHA',
#   'fiber',
#   0.1,
#   'fresh water'),
# ...
#   'particle',
#   10.0,
#   'soil'),
#  'PP film 0.01-0.1 mm (emission to air)': ('PP', 'film', 0.1, 'air'),
#  'PP film 0.01-0.1 mm (emission to fresh water)': ('PP',
#   'film',
#   0.1,
#   'fresh water'),
#  'PP film 0.01-0.1 mm (emission to marine water)': ('PP',
#   'film',
#   0.1,
#   'marine water'),
#  'PP film 0.01-0.1 mm (emission to soil)': ('PP', 'film', 0.1, 'soil'),
#  'PP film 0.1-1 mm (emission to air)': ('PP', 'film', 1.0, 'air'),
#  'PP film 0.1-1 mm (emission to fresh water)': ('PP',
#   'film',
#   1.0,
#   'fresh water'),
#  'PP film 0.1-1 mm (emission to marine water)': ('PP',
#   'film',
#   1.0,
#   'marine water'),
#  'PP film 0.1-1 mm (emission to soil)': ('PP', 'film', 1.0, 'soil'),
#  'PP film 1-10 mm (emission to air)': ('PP', 'film', 10.0, 'air'),
#  'PP film 1-10 mm (emission to fresh water)': ('PP',
#   'film',
#   10.0,
#   'fresh water'),
#  'PP film 1-10 mm (emission to marine water)': ('PP',
#   'film',
#   10.0,
#   'marine water'),
#  'PP film 1-10 mm (emission to soil)': ('PP', 'film', 10.0, 'soil'),
#  'PP fiber 0.01-0.1 mm (emission to air)': ('PP', 'fiber', 0.1, 'air'),
#  'PP fiber 0.01-0.1 mm (emission to fresh water)': ('PP',
#   'fiber',
#   0.1,
#   'fresh water'),
#  'PP fiber 0.01-0.1 mm (emission to marine water)': ('PP',
#   'fiber',
#   0.1,
#   'marine water'),
#  'PP fiber 0.01-0.1 mm (emission to soil)': ('PP', 'fiber', 0.1, 'soil'),
#  'PP fiber 0.1-1 mm (emission to air)': ('PP', 'fiber', 1.0, 'air'),
#  'PP fiber 0.1-1 mm (emission to fresh water)': ('PP',
#   'fiber',
#   1.0,
#   'fresh water'),
#  'PP fiber 0.1-1 mm (emission to marine water)': ('PP',
#   'fiber',
#   1.0,
#   'marine water'),
#  'PP fiber 0.1-1 mm (emission to soil)': ('PP', 'fiber', 1.0, 'soil'),
#  'PP fiber 1-10 mm (emission to air)': ('PP', 'fiber', 10.0, 'air'),
#  'PP fiber 1-10 mm (emission to fresh water)': ('PP',
#   'fiber',
#   10.0,
#   'fresh water'),
#  'PP fiber 1-10 mm (emission to marine water)': ('PP',
#   'fiber',
#   10.0,
#   'marine water'),
#  'PP fiber 1-10 mm (emission to soil)': ('PP', 'fiber', 10.0, 'soil'),
#  'PP particle 0.01-0.1 mm (emission to air)': ('PP', 'particle', 0.1, 'air'),
#  'PP particle 0.01-0.1 mm (emission to fresh water)': ('PP',
#   'particle',
#   0.1,
#   'fresh water'),
#  'PP particle 0.01-0.1 mm (emission to marine water)': ('PP',
#   'particle',
#   0.1,
#   'marine water'),
#  'PP particle 0.01-0.1 mm (emission to soil)': ('PP', 'particle', 0.1, 'soil'),
#  'PP particle 0.1-1 mm (emission to air)': ('PP', 'particle', 1.0, 'air'),
#  'PP particle 0.1-1 mm (emission to fresh water)': ('PP',
#   'particle',
#   1.0,
#   'fresh water'),
#  'PP particle 0.1-1 mm (emission to marine water)': ('PP',
#   'particle',
#   1.0,
#   'marine water'),
#  'PP particle 0.1-1 mm (emission to soil)': ('PP', 'particle', 1.0, 'soil'),
#  'PP particle 1-10 mm (emission to air)': ('PP', 'particle', 10.0, 'air'),
#  'PP particle 1-10 mm (emission to fresh water)': ('PP',
#   'particle',
#   10.0,
#   'fresh water'),
#  'PP particle 1-10 mm (emission to marine water)': ('PP',
#   'particle',
#   10.0,
#   'marine water'),
#  'PP particle 1-10 mm (emission to soil)': ('PP', 'particle', 10.0, 'soil'),
#  'PS film 0.01-0.1 mm (emission to air)': ('PS', 'film', 0.1, 'air'),
#  'PS film 0.01-0.1 mm (emission to fresh water)': ('PS',
#   'film',
#   0.1,
#   'fresh water'),
#  'PS film 0.01-0.1 mm (emission to marine water)': ('PS',
#   'film',
#   0.1,
#   'marine water'),
#  'PS film 0.01-0.1 mm (emission to soil)': ('PS', 'film', 0.1, 'soil'),
#  'PS film 0.1-1 mm (emission to air)': ('PS', 'film', 1.0, 'air'),
#  'PS film 0.1-1 mm (emission to fresh water)': ('PS',
#   'film',
#   1.0,
#   'fresh water'),
#  'PS film 0.1-1 mm (emission to marine water)': ('PS',
#   'film',
#   1.0,
#   'marine water'),
#  'PS film 0.1-1 mm (emission to soil)': ('PS', 'film', 1.0, 'soil'),
#  'PS film 1-10 mm (emission to air)': ('PS', 'film', 10.0, 'air'),
#  'PS film 1-10 mm (emission to fresh water)': ('PS',
#   'film',
#   10.0,
#   'fresh water'),
#  'PS film 1-10 mm (emission to marine water)': ('PS',
#   'film',
#   10.0,
#   'marine water'),
#  'PS film 1-10 mm (emission to soil)': ('PS', 'film', 10.0, 'soil'),
#  'PS fiber 0.01-0.1 mm (emission to air)': ('PS', 'fiber', 0.1, 'air'),
#  'PS fiber 0.01-0.1 mm (emission to fresh water)': ('PS',
#   'fiber',
#   0.1,
#   'fresh water'),
#  'PS fiber 0.01-0.1 mm (emission to marine water)': ('PS',
#   'fiber',
#   0.1,
#   'marine water'),
#  'PS fiber 0.01-0.1 mm (emission to soil)': ('PS', 'fiber', 0.1, 'soil'),
#  'PS fiber 0.1-1 mm (emission to air)': ('PS', 'fiber', 1.0, 'air'),
#  'PS fiber 0.1-1 mm (emission to fresh water)': ('PS',
#   'fiber',
#   1.0,
#   'fresh water'),
#  'PS fiber 0.1-1 mm (emission to marine water)': ('PS',
#   'fiber',
#   1.0,
#   'marine water'),
#  'PS fiber 0.1-1 mm (emission to soil)': ('PS', 'fiber', 1.0, 'soil'),
#  'PS fiber 1-10 mm (emission to air)': ('PS', 'fiber', 10.0, 'air'),
#  'PS fiber 1-10 mm (emission to fresh water)': ('PS',
#   'fiber',
#   10.0,
#   'fresh water'),
#  'PS fiber 1-10 mm (emission to marine water)': ('PS',
#   'fiber',
#   10.0,
#   'marine water'),
#  'PS fiber 1-10 mm (emission to soil)': ('PS', 'fiber', 10.0, 'soil'),
#  'PS particle 0.01-0.1 mm (emission to air)': ('PS', 'particle', 0.1, 'air'),
#  'PS particle 0.01-0.1 mm (emission to fresh water)': ('PS',
#   'particle',
#   0.1,
#   'fresh water'),
#  'PS particle 0.01-0.1 mm (emission to marine water)': ('PS',
#   'particle',
#   0.1,
#   'marine water'),
#  'PS particle 0.01-0.1 mm (emission to soil)': ('PS', 'particle', 0.1, 'soil'),
#  'PS particle 0.1-1 mm (emission to air)': ('PS', 'particle', 1.0, 'air'),
#  'PS particle 0.1-1 mm (emission to fresh water)': ('PS',
#   'particle',
#   1.0,
#   'fresh water'),
#  'PS particle 0.1-1 mm (emission to marine water)': ('PS',
#   'particle',
#   1.0,
#   'marine water'),
#  'PS particle 0.1-1 mm (emission to soil)': ('PS', 'particle', 1.0, 'soil'),
#  'PS particle 1-10 mm (emission to air)': ('PS', 'particle', 10.0, 'air'),
#  'PS particle 1-10 mm (emission to fresh water)': ('PS',
#   'particle',
#   10.0,
#   'fresh water'),
#  'PS particle 1-10 mm (emission to marine water)': ('PS',
#   'particle',
#   10.0,
#   'marine water'),
#  'PS particle 1-10 mm (emission to soil)': ('PS', 'particle', 10.0, 'soil'),
#  'PU film 0.01-0.1 mm (emission to air)': ('PU', 'film', 0.1, 'air'),
#  'PU film 0.01-0.1 mm (emission to fresh water)': ('PU',
#   'film',
#   0.1,
#   'fresh water'),
#  'PU film 0.01-0.1 mm (emission to marine water)': ('PU',
#   'film',
#   0.1,
#   'marine water'),
#  'PU film 0.01-0.1 mm (emission to soil)': ('PU', 'film', 0.1, 'soil'),
#  'PU film 0.1-1 mm (emission to air)': ('PU', 'film', 1.0, 'air'),
#  'PU film 0.1-1 mm (emission to fresh water)': ('PU',
#   'film',
#   1.0,
#   'fresh water'),
#  'PU film 0.1-1 mm (emission to marine water)': ('PU',
#   'film',
#   1.0,
#   'marine water'),
#  'PU film 0.1-1 mm (emission to soil)': ('PU', 'film', 1.0, 'soil'),
#  'PU film 1-10 mm (emission to air)': ('PU', 'film', 10.0, 'air'),
#  'PU film 1-10 mm (emission to fresh water)': ('PU',
#   'film',
#   10.0,
#   'fresh water'),
#  'PU film 1-10 mm (emission to marine water)': ('PU',
#   'film',
#   10.0,
#   'marine water'),
#  'PU film 1-10 mm (emission to soil)': ('PU', 'film', 10.0, 'soil'),
#  'PU fiber 0.01-0.1 mm (emission to air)': ('PU', 'fiber', 0.1, 'air'),
#  'PU fiber 0.01-0.1 mm (emission to fresh water)': ('PU',
#   'fiber',
#   0.1,
#   'fresh water'),
#  'PU fiber 0.01-0.1 mm (emission to marine water)': ('PU',
#   'fiber',
#   0.1,
#   'marine water'),
#  'PU fiber 0.01-0.1 mm (emission to soil)': ('PU', 'fiber', 0.1, 'soil'),
#  'PU fiber 0.1-1 mm (emission to air)': ('PU', 'fiber', 1.0, 'air'),
#  'PU fiber 0.1-1 mm (emission to fresh water)': ('PU',
#   'fiber',
#   1.0,
#   'fresh water'),
#  'PU fiber 0.1-1 mm (emission to marine water)': ('PU',
#   'fiber',
#   1.0,
#   'marine water'),
#  'PU fiber 0.1-1 mm (emission to soil)': ('PU', 'fiber', 1.0, 'soil'),
#  'PU fiber 1-10 mm (emission to air)': ('PU', 'fiber', 10.0, 'air'),
#  'PU fiber 1-10 mm (emission to fresh water)': ('PU',
#   'fiber',
#   10.0,
#   'fresh water'),
#  'PU fiber 1-10 mm (emission to marine water)': ('PU',
#   'fiber',
#   10.0,
#   'marine water'),
#  'PU fiber 1-10 mm (emission to soil)': ('PU', 'fiber', 10.0, 'soil'),
#  'PU particle 0.01-0.1 mm (emission to air)': ('PU', 'particle', 0.1, 'air'),
#  'PU particle 0.01-0.1 mm (emission to fresh water)': ('PU',
#   'particle',
#   0.1,
#   'fresh water'),
#  'PU particle 0.01-0.1 mm (emission to marine water)': ('PU',
#   'particle',
#   0.1,
#   'marine water'),
#  'PU particle 0.01-0.1 mm (emission to soil)': ('PU', 'particle', 0.1, 'soil'),
#  'PU particle 0.1-1 mm (emission to air)': ('PU', 'particle', 1.0, 'air'),
#  'PU particle 0.1-1 mm (emission to fresh water)': ('PU',
#   'particle',
#   1.0,
#   'fresh water'),
#  'PU particle 0.1-1 mm (emission to marine water)': ('PU',
#   'particle',
#   1.0,
#   'marine water'),
#  'PU particle 0.1-1 mm (emission to soil)': ('PU', 'particle', 1.0, 'soil'),
#  'PU particle 1-10 mm (emission to air)': ('PU', 'particle', 10.0, 'air'),
#  'PU particle 1-10 mm (emission to fresh water)': ('PU',
#   'particle',
#   10.0,
#   'fresh water'),
#  'PU particle 1-10 mm (emission to marine water)': ('PU',
#   'particle',
#   10.0,
#   'marine water'),
#  'PU particle 1-10 mm (emission to soil)': ('PU', 'particle', 10.0, 'soil'),
#  'PVC film 0.01-0.1 mm (emission to air)': ('PVC', 'film', 0.1, 'air'),
#  'PVC film 0.01-0.1 mm (emission to fresh water)': ('PVC',
#   'film',
#   0.1,
#   'fresh water'),
#  'PVC film 0.01-0.1 mm (emission to marine water)': ('PVC',
#   'film',
#   0.1,
#   'marine water'),
#  'PVC film 0.01-0.1 mm (emission to soil)': ('PVC', 'film', 0.1, 'soil'),
#  'PVC film 0.1-1 mm (emission to air)': ('PVC', 'film', 1.0, 'air'),
#  'PVC film 0.1-1 mm (emission to fresh water)': ('PVC',
#   'film',
#   1.0,
#   'fresh water'),
#  'PVC film 0.1-1 mm (emission to marine water)': ('PVC',
#   'film',
#   1.0,
#   'marine water'),
#  'PVC film 0.1-1 mm (emission to soil)': ('PVC', 'film', 1.0, 'soil'),
#  'PVC film 1-10 mm (emission to air)': ('PVC', 'film', 10.0, 'air'),
#  'PVC film 1-10 mm (emission to fresh water)': ('PVC',
#   'film',
#   10.0,
#   'fresh water'),
#  'PVC film 1-10 mm (emission to marine water)': ('PVC',
#   'film',
#   10.0,
#   'marine water'),
#  'PVC film 1-10 mm (emission to soil)': ('PVC', 'film', 10.0, 'soil'),
#  'PVC fiber 0.01-0.1 mm (emission to air)': ('PVC', 'fiber', 0.1, 'air'),
#  'PVC fiber 0.01-0.1 mm (emission to fresh water)': ('PVC',
#   'fiber',
#   0.1,
#   'fresh water'),
#  'PVC fiber 0.01-0.1 mm (emission to marine water)': ('PVC',
#   'fiber',
#   0.1,
#   'marine water'),
#  'PVC fiber 0.01-0.1 mm (emission to soil)': ('PVC', 'fiber', 0.1, 'soil'),
#  'PVC fiber 0.1-1 mm (emission to air)': ('PVC', 'fiber', 1.0, 'air'),
#  'PVC fiber 0.1-1 mm (emission to fresh water)': ('PVC',
#   'fiber',
#   1.0,
#   'fresh water'),
#  'PVC fiber 0.1-1 mm (emission to marine water)': ('PVC',
#   'fiber',
#   1.0,
#   'marine water'),
#  'PVC fiber 0.1-1 mm (emission to soil)': ('PVC', 'fiber', 1.0, 'soil'),
#  'PVC fiber 1-10 mm (emission to air)': ('PVC', 'fiber', 10.0, 'air'),
#  'PVC fiber 1-10 mm (emission to fresh water)': ('PVC',
#   'fiber',
#   10.0,
#   'fresh water'),
#  'PVC fiber 1-10 mm (emission to marine water)': ('PVC',
#   'fiber',
#   10.0,
#   'marine water'),
#  'PVC fiber 1-10 mm (emission to soil)': ('PVC', 'fiber', 10.0, 'soil'),
#  'PVC particle 0.01-0.1 mm (emission to air)': ('PVC', 'particle', 0.1, 'air'),
#  'PVC particle 0.01-0.1 mm (emission to fresh water)': ('PVC',
#   'particle',
#   0.1,
#   'fresh water'),
#  'PVC particle 0.01-0.1 mm (emission to marine water)': ('PVC',
#   'particle',
#   0.1,
#   'marine water'),
#  'PVC particle 0.01-0.1 mm (emission to soil)': ('PVC',
#   'particle',
#   0.1,
#   'soil'),
#  'PVC particle 0.1-1 mm (emission to air)': ('PVC', 'particle', 1.0, 'air'),
#  'PVC particle 0.1-1 mm (emission to fresh water)': ('PVC',
#   'particle',
#   1.0,
#   'fresh water'),
#  'PVC particle 0.1-1 mm (emission to marine water)': ('PVC',
#   'particle',
#   1.0,
#   'marine water'),
#  'PVC particle 0.1-1 mm (emission to soil)': ('PVC', 'particle', 1.0, 'soil'),
#  'PVC particle 1-10 mm (emission to air)': ('PVC', 'particle', 10.0, 'air'),
#  'PVC particle 1-10 mm (emission to fresh water)': ('PVC',
#   'particle',
#   10.0,
#   'fresh water'),
#  'PVC particle 1-10 mm (emission to marine water)': ('PVC',
#   'particle',
#   10.0,
#   'marine water'),
#  'PVC particle 1-10 mm (emission to soil)': ('PVC', 'particle', 10.0, 'soil'),
#  'Starch-blend film 0.01-0.1 mm (emission to air)': ('Starch-blend',
#   'film',
#   0.1,
#   'air'),
#  'Starch-blend film 0.01-0.1 mm (emission to fresh water)': ('Starch-blend',
#   'film',
#   0.1,
#   'fresh water'),
#  'Starch-blend film 0.01-0.1 mm (emission to marine water)': ('Starch-blend',
#   'film',
#   0.1,
#   'marine water'),
#  'Starch-blend film 0.01-0.1 mm (emission to soil)': ('Starch-blend',
#   'film',
#   0.1,
#   'soil'),
#  'Starch-blend film 0.1-1 mm (emission to air)': ('Starch-blend',
#   'film',
#   1.0,
#   'air'),
#  'Starch-blend film 0.1-1 mm (emission to fresh water)': ('Starch-blend',
#   'film',
#   1.0,
#   'fresh water'),
#  'Starch-blend film 0.1-1 mm (emission to marine water)': ('Starch-blend',
#   'film',
#   1.0,
#   'marine water'),
#  'Starch-blend film 0.1-1 mm (emission to soil)': ('Starch-blend',
#   'film',
#   1.0,
#   'soil'),
#  'Starch-blend film 1-10 mm (emission to air)': ('Starch-blend',
#   'film',
#   10.0,
#   'air'),
#  'Starch-blend film 1-10 mm (emission to fresh water)': ('Starch-blend',
#   'film',
#   10.0,
#   'fresh water'),
#  'Starch-blend film 1-10 mm (emission to marine water)': ('Starch-blend',
#   'film',
#   10.0,
#   'marine water'),
#  'Starch-blend film 1-10 mm (emission to soil)': ('Starch-blend',
#   'film',
#   10.0,
#   'soil'),
#  'Starch-blend fiber 0.01-0.1 mm (emission to air)': ('Starch-blend',
#   'fiber',
#   0.1,
#   'air'),
#  'Starch-blend fiber 0.01-0.1 mm (emission to fresh water)': ('Starch-blend',
#   'fiber',
#   0.1,
#   'fresh water'),
#  'Starch-blend fiber 0.01-0.1 mm (emission to marine water)': ('Starch-blend',
#   'fiber',
#   0.1,
#   'marine water'),
#  'Starch-blend fiber 0.01-0.1 mm (emission to soil)': ('Starch-blend',
#   'fiber',
#   0.1,
#   'soil'),
#  'Starch-blend fiber 0.1-1 mm (emission to air)': ('Starch-blend',
#   'fiber',
#   1.0,
#   'air'),
#  'Starch-blend fiber 0.1-1 mm (emission to fresh water)': ('Starch-blend',
#   'fiber',
#   1.0,
#   'fresh water'),
#  'Starch-blend fiber 0.1-1 mm (emission to marine water)': ('Starch-blend',
#   'fiber',
#   1.0,
#   'marine water'),
#  'Starch-blend fiber 0.1-1 mm (emission to soil)': ('Starch-blend',
#   'fiber',
#   1.0,
#   'soil'),
#  'Starch-blend fiber 1-10 mm (emission to air)': ('Starch-blend',
#   'fiber',
#   10.0,
#   'air'),
#  'Starch-blend fiber 1-10 mm (emission to fresh water)': ('Starch-blend',
#   'fiber',
#   10.0,
#   'fresh water'),
#  'Starch-blend fiber 1-10 mm (emission to marine water)': ('Starch-blend',
#   'fiber',
#   10.0,
#   'marine water'),
#  'Starch-blend fiber 1-10 mm (emission to soil)': ('Starch-blend',
#   'fiber',
#   10.0,
#   'soil'),
#  'Starch-blend particle 0.01-0.1 mm (emission to air)': ('Starch-blend',
#   'particle',
#   0.1,
#   'air'),
#  'Starch-blend particle 0.01-0.1 mm (emission to fresh water)': ('Starch-blend',
#   'particle',
#   0.1,
#   'fresh water'),
#  'Starch-blend particle 0.01-0.1 mm (emission to marine water)': ('Starch-blend',
#   'particle',
#   0.1,
#   'marine water'),
#  'Starch-blend particle 0.01-0.1 mm (emission to soil)': ('Starch-blend',
#   'particle',
#   0.1,
#   'soil'),
#  'Starch-blend particle 0.1-1 mm (emission to air)': ('Starch-blend',
#   'particle',
#   1.0,
#   'air'),
#  'Starch-blend particle 0.1-1 mm (emission to fresh water)': ('Starch-blend',
#   'particle',
#   1.0,
#   'fresh water'),
#  'Starch-blend particle 0.1-1 mm (emission to marine water)': ('Starch-blend',
#   'particle',
#   1.0,
#   'marine water'),
#  'Starch-blend particle 0.1-1 mm (emission to soil)': ('Starch-blend',
#   'particle',
#   1.0,
#   'soil'),
#  'Starch-blend particle 1-10 mm (emission to air)': ('Starch-blend',
#   'particle',
#   10.0,
#   'air'),
#  'Starch-blend particle 1-10 mm (emission to fresh water)': ('Starch-blend',
#   'particle',
#   10.0,
#   'fresh water'),
#  'Starch-blend particle 1-10 mm (emission to marine water)': ('Starch-blend',
#   'particle',
#   10.0,
#   'marine water'),
#  'Starch-blend particle 1-10 mm (emission to soil)': ('Starch-blend',
#   'particle',
#   10.0,
#   'soil')}

# %%
# creating list for the upper end of the range for the characteristic length (for calculations only)
length = [0.1, 1.0, 10.0]
length
# Out:
# [0.1, 1.0, 10.0]

# %%
# defining a function calculating the CV for expert judgments only, as this is necessary for the further calculation
def CV_exp(exp):
    a_exp = 2.5
    b = 1.105
    return a_exp*math.exp(b*exp)/100

# %%
# setting up a dictionary for the average lifetime calculation
t_i_dict = {}
# looping through the dataframe df_SSDR to get name, SSDR, and GSDi
for i in range(0, len(df_SSDR)):
    namei = df_SSDR.iloc[i]['Polymer type'] + \
        ', ' + df_SSDR.iloc[i]['Compartment']
    SSDRi = df_SSDR.iloc[i]['SSDR']
    GSDi = df_SSDR.iloc[i]['GSD']
    for l in length:  # looping through elements in lenght and shape_dict to retrieve the lenght and shape values
        for s in shape_dict:
            t_l = l*1000/(2*SSDRi)
            # calculation of the average lifetime (formular given in manuscript)
            t_i = t_l/(1+shape_dict[s]/2)
            # building dictionary with names of envionmental flows as keys and average lifetime and GSD as values
            t_i_dict[namei + ', ' + s + ', ' + str(l) + ', ' + 'inf'] = t_i, GSDi, t_l                
t_i_dict
# Out:
# {'HDPE, marine sediment, film, 0.1, inf': (2.136869215853447,
#   1.8607030663907251,
#   4.273738431706894),
#  'HDPE, marine sediment, fiber, 0.1, inf': (1.4245794772356313,
#   1.8607030663907251,
#   4.273738431706894),
#  'HDPE, marine sediment, particle, 0.1, inf': (1.0684346079267235,
#   1.8607030663907251,
#   4.273738431706894),
#  'HDPE, marine sediment, film, 1.0, inf': (21.36869215853447,
#   1.8607030663907251,
#   42.73738431706894),
#  'HDPE, marine sediment, fiber, 1.0, inf': (14.245794772356312,
#   1.8607030663907251,
#   42.73738431706894),
#  'HDPE, marine sediment, particle, 1.0, inf': (10.684346079267234,
#   1.8607030663907251,
#   42.73738431706894),
#  'HDPE, marine sediment, film, 10.0, inf': (213.6869215853447,
#   1.8607030663907251,
#   427.3738431706894),
#  'HDPE, marine sediment, fiber, 10.0, inf': (142.45794772356314,
#   1.8607030663907251,
#   427.3738431706894),
#  'HDPE, marine sediment, particle, 10.0, inf': (106.84346079267235,
#   1.8607030663907251,
#   427.3738431706894),
#  'HDPE, marine water, film, 0.1, inf': (2.136869215853447,
#   1.7838093127266956,
#   4.273738431706894),
#  'HDPE, marine water, fiber, 0.1, inf': (1.4245794772356313,
#   1.7838093127266956,
#   4.273738431706894),
#  'HDPE, marine water, particle, 0.1, inf': (1.0684346079267235,
#   1.7838093127266956,
#   4.273738431706894),
#  'HDPE, marine water, film, 1.0, inf': (21.36869215853447,
#   1.7838093127266956,
#   42.73738431706894),
#  'HDPE, marine water, fiber, 1.0, inf': (14.245794772356312,
#   1.7838093127266956,
#   42.73738431706894),
#  'HDPE, marine water, particle, 1.0, inf': (10.684346079267234,
#   1.7838093127266956,
#   42.73738431706894),
#  'HDPE, marine water, film, 10.0, inf': (213.6869215853447,
#   1.7838093127266956,
#   427.3738431706894),
#  'HDPE, marine water, fiber, 10.0, inf': (142.45794772356314,
#   1.7838093127266956,
#   427.3738431706894),
#  'HDPE, marine water, particle, 10.0, inf': (106.84346079267235,
#   1.7838093127266956,
#   427.3738431706894),
#  'HDPE, river sediment, film, 0.1, inf': (2.136869215853447,
#   1.8607030663907251,
#   4.273738431706894),
#  'HDPE, river sediment, fiber, 0.1, inf': (1.4245794772356313,
#   1.8607030663907251,
#   4.273738431706894),
#  'HDPE, river sediment, particle, 0.1, inf': (1.0684346079267235,
#   1.8607030663907251,
#   4.273738431706894),
#  'HDPE, river sediment, film, 1.0, inf': (21.36869215853447,
#   1.8607030663907251,
#   42.73738431706894),
#  'HDPE, river sediment, fiber, 1.0, inf': (14.245794772356312,
#   1.8607030663907251,
#   42.73738431706894),
#  'HDPE, river sediment, particle, 1.0, inf': (10.684346079267234,
#   1.8607030663907251,
#   42.73738431706894),
#  'HDPE, river sediment, film, 10.0, inf': (213.6869215853447,
#   1.8607030663907251,
#   427.3738431706894),
#  'HDPE, river sediment, fiber, 10.0, inf': (142.45794772356314,
#   1.8607030663907251,
#   427.3738431706894),
#  'HDPE, river sediment, particle, 10.0, inf': (106.84346079267235,
#   1.8607030663907251,
#   427.3738431706894),
#  'HDPE, soil, film, 0.1, inf': (2.136869215853447,
#   1.8607030663907251,
#   4.273738431706894),
#  'HDPE, soil, fiber, 0.1, inf': (1.4245794772356313,
#   1.8607030663907251,
#   4.273738431706894),
#  'HDPE, soil, particle, 0.1, inf': (1.0684346079267235,
#   1.8607030663907251,
#   4.273738431706894),
#  'HDPE, soil, film, 1.0, inf': (21.36869215853447,
#   1.8607030663907251,
#   42.73738431706894),
#  'HDPE, soil, fiber, 1.0, inf': (14.245794772356312,
#   1.8607030663907251,
#   42.73738431706894),
#  'HDPE, soil, particle, 1.0, inf': (10.684346079267234,
#   1.8607030663907251,
#   42.73738431706894),
#  'HDPE, soil, film, 10.0, inf': (213.6869215853447,
#   1.8607030663907251,
#   427.3738431706894),
#  'HDPE, soil, fiber, 10.0, inf': (142.45794772356314,
#   1.8607030663907251,
#   427.3738431706894),
#  'HDPE, soil, particle, 10.0, inf': (106.84346079267235,
#   1.8607030663907251,
#   427.3738431706894),
#  'LDPE, marine sediment, film, 0.1, inf': (35.369014614492855,
#   1.5659304140921921,
#   70.73802922898571),
#  'LDPE, marine sediment, fiber, 0.1, inf': (23.57934307632857,
#   1.5659304140921921,
#   70.73802922898571),
#  'LDPE, marine sediment, particle, 0.1, inf': (17.684507307246427,
#   1.5659304140921921,
#   70.73802922898571),
#  'LDPE, marine sediment, film, 1.0, inf': (353.6901461449286,
#   1.5659304140921921,
#   707.3802922898572),
#  'LDPE, marine sediment, fiber, 1.0, inf': (235.79343076328573,
#   1.5659304140921921,
#   707.3802922898572),
#  'LDPE, marine sediment, particle, 1.0, inf': (176.8450730724643,
#   1.5659304140921921,
#   707.3802922898572),
#  'LDPE, marine sediment, film, 10.0, inf': (3536.9014614492858,
#   1.5659304140921921,
#   7073.8029228985715),
#  'LDPE, marine sediment, fiber, 10.0, inf': (2357.9343076328573,
#   1.5659304140921921,
#   7073.8029228985715),
#  'LDPE, marine sediment, particle, 10.0, inf': (1768.4507307246429,
#   1.5659304140921921,
#   7073.8029228985715),
#  'LDPE, marine water, film, 0.1, inf': (4.4189129474149365,
#   1.2834711338964044,
#   8.837825894829873),
#  'LDPE, marine water, fiber, 0.1, inf': (2.945941964943291,
#   1.2834711338964044,
#   8.837825894829873),
#  'LDPE, marine water, particle, 0.1, inf': (2.2094564737074682,
#   1.2834711338964044,
#   8.837825894829873),
#  'LDPE, marine water, film, 1.0, inf': (44.18912947414936,
#   1.2834711338964044,
#   88.37825894829872),
#  'LDPE, marine water, fiber, 1.0, inf': (29.459419649432906,
#   1.2834711338964044,
#   88.37825894829872),
#  'LDPE, marine water, particle, 1.0, inf': (22.09456473707468,
#   1.2834711338964044,
#   88.37825894829872),
#  'LDPE, marine water, film, 10.0, inf': (441.8912947414936,
#   1.2834711338964044,
#   883.7825894829872),
#  'LDPE, marine water, fiber, 10.0, inf': (294.5941964943291,
#   1.2834711338964044,
#   883.7825894829872),
#  'LDPE, marine water, particle, 10.0, inf': (220.9456473707468,
#   1.2834711338964044,
#   883.7825894829872),
#  'LDPE, river sediment, film, 0.1, inf': (35.369014614492855,
#   1.651630269428027,
#   70.73802922898571),
#  'LDPE, river sediment, fiber, 0.1, inf': (23.57934307632857,
#   1.651630269428027,
#   70.73802922898571),
#  'LDPE, river sediment, particle, 0.1, inf': (17.684507307246427,
#   1.651630269428027,
#   70.73802922898571),
#  'LDPE, river sediment, film, 1.0, inf': (353.6901461449286,
#   1.651630269428027,
#   707.3802922898572),
#  'LDPE, river sediment, fiber, 1.0, inf': (235.79343076328573,
#   1.651630269428027,
#   707.3802922898572),
#  'LDPE, river sediment, particle, 1.0, inf': (176.8450730724643,
#   1.651630269428027,
#   707.3802922898572),
#  'LDPE, river sediment, film, 10.0, inf': (3536.9014614492858,
#   1.651630269428027,
#   7073.8029228985715),
#  'LDPE, river sediment, fiber, 10.0, inf': (2357.9343076328573,
#   1.651630269428027,
#   7073.8029228985715),
#  'LDPE, river sediment, particle, 10.0, inf': (1768.4507307246429,
#   1.651630269428027,
#   7073.8029228985715),
#  'LDPE, soil, film, 0.1, inf': (4.4189129474149365,
#   1.3993802474041053,
#   8.837825894829873),
#  'LDPE, soil, fiber, 0.1, inf': (2.945941964943291,
#   1.3993802474041053,
#   8.837825894829873),
#  'LDPE, soil, particle, 0.1, inf': (2.2094564737074682,
#   1.3993802474041053,
#   8.837825894829873),
#  'LDPE, soil, film, 1.0, inf': (44.18912947414936,
#   1.3993802474041053,
#   88.37825894829872),
#  'LDPE, soil, fiber, 1.0, inf': (29.459419649432906,
#   1.3993802474041053,
#   88.37825894829872),
#  'LDPE, soil, particle, 1.0, inf': (22.09456473707468,
#   1.3993802474041053,
#   88.37825894829872),
#  'LDPE, soil, film, 10.0, inf': (441.8912947414936,
#   1.3993802474041053,
#   883.7825894829872),
#  'LDPE, soil, fiber, 10.0, inf': (294.5941964943291,
#   1.3993802474041053,
#   883.7825894829872),
#  'LDPE, soil, particle, 10.0, inf': (220.9456473707468,
#   1.3993802474041053,
#   883.7825894829872),
#  'NR/SBR, marine sediment, film, 0.1, inf': (0.5727376861397478,
#   1.8591449594304925,
#   1.1454753722794957),
#  'NR/SBR, marine sediment, fiber, 0.1, inf': (0.3818251240931652,
#   1.8591449594304925,
#   1.1454753722794957),
#  'NR/SBR, marine sediment, particle, 0.1, inf': (0.2863688430698739,
#   1.8591449594304925,
#   1.1454753722794957),
#  'NR/SBR, marine sediment, film, 1.0, inf': (5.727376861397478,
#   1.8591449594304925,
#   11.454753722794957),
#  'NR/SBR, marine sediment, fiber, 1.0, inf': (3.818251240931652,
#   1.8591449594304925,
#   11.454753722794957),
#  'NR/SBR, marine sediment, particle, 1.0, inf': (2.863688430698739,
#   1.8591449594304925,
#   11.454753722794957),
#  'NR/SBR, marine sediment, film, 10.0, inf': (57.27376861397478,
#   1.8591449594304925,
#   114.54753722794956),
#  'NR/SBR, marine sediment, fiber, 10.0, inf': (38.18251240931652,
#   1.8591449594304925,
#   114.54753722794956),
#  'NR/SBR, marine sediment, particle, 10.0, inf': (28.63688430698739,
#   1.8591449594304925,
#   114.54753722794956),
#  'NR/SBR, marine water, film, 0.1, inf': (0.5727376861397478,
#   1.7822065562437492,
#   1.1454753722794957),
#  'NR/SBR, marine water, fiber, 0.1, inf': (0.3818251240931652,
#   1.7822065562437492,
#   1.1454753722794957),
#  'NR/SBR, marine water, particle, 0.1, inf': (0.2863688430698739,
#   1.7822065562437492,
#   1.1454753722794957),
#  'NR/SBR, marine water, film, 1.0, inf': (5.727376861397478,
#   1.7822065562437492,
#   11.454753722794957),
#  'NR/SBR, marine water, fiber, 1.0, inf': (3.818251240931652,
#   1.7822065562437492,
#   11.454753722794957),
#  'NR/SBR, marine water, particle, 1.0, inf': (2.863688430698739,
#   1.7822065562437492,
#   11.454753722794957),
#  'NR/SBR, marine water, film, 10.0, inf': (57.27376861397478,
#   1.7822065562437492,
#   114.54753722794956),
#  'NR/SBR, marine water, fiber, 10.0, inf': (38.18251240931652,
#   1.7822065562437492,
#   114.54753722794956),
#  'NR/SBR, marine water, particle, 10.0, inf': (28.63688430698739,
#   1.7822065562437492,
#   114.54753722794956),
#  'NR/SBR, river sediment, film, 0.1, inf': (0.5727376861397478,
#   1.8591449594304925,
#   1.1454753722794957),
#  'NR/SBR, river sediment, fiber, 0.1, inf': (0.3818251240931652,
#   1.8591449594304925,
#   1.1454753722794957),
#  'NR/SBR, river sediment, particle, 0.1, inf': (0.2863688430698739,
#   1.8591449594304925,
#   1.1454753722794957),
#  'NR/SBR, river sediment, film, 1.0, inf': (5.727376861397478,
#   1.8591449594304925,
#   11.454753722794957),
#  'NR/SBR, river sediment, fiber, 1.0, inf': (3.818251240931652,
#   1.8591449594304925,
#   11.454753722794957),
#  'NR/SBR, river sediment, particle, 1.0, inf': (2.863688430698739,
#   1.8591449594304925,
#   11.454753722794957),
#  'NR/SBR, river sediment, film, 10.0, inf': (57.27376861397478,
#   1.8591449594304925,
#   114.54753722794956),
#  'NR/SBR, river sediment, fiber, 10.0, inf': (38.18251240931652,
#   1.8591449594304925,
#   114.54753722794956),
#  'NR/SBR, river sediment, particle, 10.0, inf': (28.63688430698739,
#   1.8591449594304925,
#   114.54753722794956),
#  'NR/SBR, soil, film, 0.1, inf': (0.5727376861397478,
#   1.8591449594304925,
#   1.1454753722794957),
#  'NR/SBR, soil, fiber, 0.1, inf': (0.3818251240931652,
#   1.8591449594304925,
#   1.1454753722794957),
#  'NR/SBR, soil, particle, 0.1, inf': (0.2863688430698739,
#   1.8591449594304925,
#   1.1454753722794957),
#  'NR/SBR, soil, film, 1.0, inf': (5.727376861397478,
#   1.8591449594304925,
#   11.454753722794957),
#  'NR/SBR, soil, fiber, 1.0, inf': (3.818251240931652,
#   1.8591449594304925,
#   11.454753722794957),
#  'NR/SBR, soil, particle, 1.0, inf': (2.863688430698739,
#   1.8591449594304925,
#   11.454753722794957),
#  'NR/SBR, soil, film, 10.0, inf': (57.27376861397478,
#   1.8591449594304925,
#   114.54753722794956),
#  'NR/SBR, soil, fiber, 10.0, inf': (38.18251240931652,
#   1.8591449594304925,
#   114.54753722794956),
#  'NR/SBR, soil, particle, 10.0, inf': (28.63688430698739,
#   1.8591449594304925,
#   114.54753722794956),
#  'PA, marine sediment, film, 0.1, inf': (0.08561643835616438,
#   1.3073990159314974,
#   0.17123287671232876),
#  'PA, marine sediment, fiber, 0.1, inf': (0.05707762557077625,
#   1.3073990159314974,
#   0.17123287671232876),
#  'PA, marine sediment, particle, 0.1, inf': (0.04280821917808219,
#   1.3073990159314974,
#   0.17123287671232876),
#  'PA, marine sediment, film, 1.0, inf': (0.8561643835616438,
#   1.3073990159314974,
#   1.7123287671232876),
#  'PA, marine sediment, fiber, 1.0, inf': (0.5707762557077626,
#   1.3073990159314974,
#   1.7123287671232876),
#  'PA, marine sediment, particle, 1.0, inf': (0.4280821917808219,
#   1.3073990159314974,
#   1.7123287671232876),
#  'PA, marine sediment, film, 10.0, inf': (8.561643835616438,
#   1.3073990159314974,
#   17.123287671232877),
#  'PA, marine sediment, fiber, 10.0, inf': (5.707762557077626,
#   1.3073990159314974,
#   17.123287671232877),
#  'PA, marine sediment, particle, 10.0, inf': (4.280821917808219,
#   1.3073990159314974,
#   17.123287671232877),
#  'PA, marine water, film, 0.1, inf': (0.08561643835616438,
#   1.1567906541587107,
#   0.17123287671232876),
#  'PA, marine water, fiber, 0.1, inf': (0.05707762557077625,
#   1.1567906541587107,
#   0.17123287671232876),
#  'PA, marine water, particle, 0.1, inf': (0.04280821917808219,
#   1.1567906541587107,
#   0.17123287671232876),
#  'PA, marine water, film, 1.0, inf': (0.8561643835616438,
#   1.1567906541587107,
#   1.7123287671232876),
#  'PA, marine water, fiber, 1.0, inf': (0.5707762557077626,
#   1.1567906541587107,
#   1.7123287671232876),
#  'PA, marine water, particle, 1.0, inf': (0.4280821917808219,
#   1.1567906541587107,
#   1.7123287671232876),
#  'PA, marine water, film, 10.0, inf': (8.561643835616438,
#   1.1567906541587107,
#   17.123287671232877),
#  'PA, marine water, fiber, 10.0, inf': (5.707762557077626,
#   1.1567906541587107,
#   17.123287671232877),
#  'PA, marine water, particle, 10.0, inf': (4.280821917808219,
#   1.1567906541587107,
#   17.123287671232877),
#  'PA, river sediment, film, 0.1, inf': (0.08561643835616438,
#   1.3073990159314974,
#   0.17123287671232876),
#  'PA, river sediment, fiber, 0.1, inf': (0.05707762557077625,
#   1.3073990159314974,
#   0.17123287671232876),
#  'PA, river sediment, particle, 0.1, inf': (0.04280821917808219,
#   1.3073990159314974,
#   0.17123287671232876),
#  'PA, river sediment, film, 1.0, inf': (0.8561643835616438,
#   1.3073990159314974,
#   1.7123287671232876),
#  'PA, river sediment, fiber, 1.0, inf': (0.5707762557077626,
#   1.3073990159314974,
#   1.7123287671232876),
#  'PA, river sediment, particle, 1.0, inf': (0.4280821917808219,
#   1.3073990159314974,
#   1.7123287671232876),
#  'PA, river sediment, film, 10.0, inf': (8.561643835616438,
#   1.3073990159314974,
#   17.123287671232877),
#  'PA, river sediment, fiber, 10.0, inf': (5.707762557077626,
#   1.3073990159314974,
#   17.123287671232877),
#  'PA, river sediment, particle, 10.0, inf': (4.280821917808219,
#   1.3073990159314974,
#   17.123287671232877),
#  'PA, soil, film, 0.1, inf': (0.08561643835616438,
#   1.3073990159314974,
#   0.17123287671232876),
#  'PA, soil, fiber, 0.1, inf': (0.05707762557077625,
#   1.3073990159314974,
#   0.17123287671232876),
#  'PA, soil, particle, 0.1, inf': (0.04280821917808219,
#   1.3073990159314974,
#   0.17123287671232876),
#  'PA, soil, film, 1.0, inf': (0.8561643835616438,
#   1.3073990159314974,
#   1.7123287671232876),
#  'PA, soil, fiber, 1.0, inf': (0.5707762557077626,
#   1.3073990159314974,
#   1.7123287671232876),
#  'PA, soil, particle, 1.0, inf': (0.4280821917808219,
#   1.3073990159314974,
#   1.7123287671232876),
#  'PA, soil, film, 10.0, inf': (8.561643835616438,
#   1.3073990159314974,
#   17.123287671232877),
#  'PA, soil, fiber, 10.0, inf': (5.707762557077626,
#   1.3073990159314974,
#   17.123287671232877),
#  'PA, soil, particle, 10.0, inf': (4.280821917808219,
#   1.3073990159314974,
#   17.123287671232877),
#  'PBAT, marine sediment, film, 0.1, inf': (12.724024040283709,
#   1.8591449594304925,
#   25.448048080567418),
#  'PBAT, marine sediment, fiber, 0.1, inf': (8.482682693522472,
#   1.8591449594304925,
#   25.448048080567418),
#  'PBAT, marine sediment, particle, 0.1, inf': (6.362012020141854,
#   1.8591449594304925,
#   25.448048080567418),
#  'PBAT, marine sediment, film, 1.0, inf': (127.24024040283709,
#   1.8591449594304925,
#   254.48048080567418),
#  'PBAT, marine sediment, fiber, 1.0, inf': (84.82682693522473,
#   1.8591449594304925,
#   254.48048080567418),
#  'PBAT, marine sediment, particle, 1.0, inf': (63.620120201418544,
#   1.8591449594304925,
#   254.48048080567418),
#  'PBAT, marine sediment, film, 10.0, inf': (1272.402404028371,
#   1.8591449594304925,
#   2544.804808056742),
#  'PBAT, marine sediment, fiber, 10.0, inf': (848.2682693522473,
#   1.8591449594304925,
#   2544.804808056742),
#  'PBAT, marine sediment, particle, 10.0, inf': (636.2012020141855,
#   1.8591449594304925,
#   2544.804808056742),
#  'PBAT, marine water, film, 0.1, inf': (2.127618461544803,
#   1.5352507074922717,
#   4.255236923089606),
#  'PBAT, marine water, fiber, 0.1, inf': (1.4184123076965351,
#   1.5352507074922717,
#   4.255236923089606),
#  'PBAT, marine water, particle, 0.1, inf': (1.0638092307724014,
#   1.5352507074922717,
#   4.255236923089606),
#  'PBAT, marine water, film, 1.0, inf': (21.276184615448027,
#   1.5352507074922717,
#   42.552369230896055),
#  'PBAT, marine water, fiber, 1.0, inf': (14.184123076965351,
#   1.5352507074922717,
#   42.552369230896055),
#  'PBAT, marine water, particle, 1.0, inf': (10.638092307724014,
#   1.5352507074922717,
#   42.552369230896055),
#  'PBAT, marine water, film, 10.0, inf': (212.76184615448028,
#   1.5352507074922717,
#   425.52369230896056),
#  'PBAT, marine water, fiber, 10.0, inf': (141.84123076965352,
#   1.5352507074922717,
#   425.52369230896056),
#  'PBAT, marine water, particle, 10.0, inf': (106.38092307724014,
#   1.5352507074922717,
#   425.52369230896056),
#  'PBAT, river sediment, film, 0.1, inf': (12.724024040283709,
#   1.8591449594304925,
#   25.448048080567418),
#  'PBAT, river sediment, fiber, 0.1, inf': (8.482682693522472,
#   1.8591449594304925,
#   25.448048080567418),
#  'PBAT, river sediment, particle, 0.1, inf': (6.362012020141854,
#   1.8591449594304925,
#   25.448048080567418),
#  'PBAT, river sediment, film, 1.0, inf': (127.24024040283709,
#   1.8591449594304925,
#   254.48048080567418),
#  'PBAT, river sediment, fiber, 1.0, inf': (84.82682693522473,
#   1.8591449594304925,
#   254.48048080567418),
#  'PBAT, river sediment, particle, 1.0, inf': (63.620120201418544,
#   1.8591449594304925,
#   254.48048080567418),
#  'PBAT, river sediment, film, 10.0, inf': (1272.402404028371,
#   1.8591449594304925,
#   2544.804808056742),
#  'PBAT, river sediment, fiber, 10.0, inf': (848.2682693522473,
#   1.8591449594304925,
#   2544.804808056742),
#  'PBAT, river sediment, particle, 10.0, inf': (636.2012020141855,
#   1.8591449594304925,
#   2544.804808056742),
#  'PBAT, soil, film, 0.1, inf': (12.724024040283709,
#   1.7822065562437492,
#   25.448048080567418),
#  'PBAT, soil, fiber, 0.1, inf': (8.482682693522472,
#   1.7822065562437492,
#   25.448048080567418),
#  'PBAT, soil, particle, 0.1, inf': (6.362012020141854,
#   1.7822065562437492,
#   25.448048080567418),
#  'PBAT, soil, film, 1.0, inf': (127.24024040283709,
#   1.7822065562437492,
#   254.48048080567418),
#  'PBAT, soil, fiber, 1.0, inf': (84.82682693522473,
#   1.7822065562437492,
#   254.48048080567418),
#  'PBAT, soil, particle, 1.0, inf': (63.620120201418544,
#   1.7822065562437492,
#   254.48048080567418),
#  'PBAT, soil, film, 10.0, inf': (1272.402404028371,
#   1.7822065562437492,
#   2544.804808056742),
#  'PBAT, soil, fiber, 10.0, inf': (848.2682693522473,
#   1.7822065562437492,
#   2544.804808056742),
#  'PBAT, soil, particle, 10.0, inf': (636.2012020141855,
#   1.7822065562437492,
#   2544.804808056742),
#  'PBS, marine sediment, film, 0.1, inf': (3.9452054794520546,
#   1.437266060853234,
#   7.890410958904109),
#  'PBS, marine sediment, fiber, 0.1, inf': (2.6301369863013697,
#   1.437266060853234,
#   7.890410958904109),
#  'PBS, marine sediment, particle, 0.1, inf': (1.9726027397260273,
#   1.437266060853234,
#   7.890410958904109),
#  'PBS, marine sediment, film, 1.0, inf': (39.45205479452054,
#   1.437266060853234,
#   78.90410958904108),
#  'PBS, marine sediment, fiber, 1.0, inf': (26.301369863013694,
#   1.437266060853234,
#   78.90410958904108),
#  'PBS, marine sediment, particle, 1.0, inf': (19.72602739726027,
#   1.437266060853234,
#   78.90410958904108),
#  'PBS, marine sediment, film, 10.0, inf': (394.52054794520546,
#   1.437266060853234,
#   789.0410958904109),
#  'PBS, marine sediment, fiber, 10.0, inf': (263.01369863013696,
#   1.437266060853234,
#   789.0410958904109),
#  'PBS, marine sediment, particle, 10.0, inf': (197.26027397260273,
#   1.437266060853234,
#   789.0410958904109),
#  'PBS, marine water, film, 0.1, inf': (3.9452054794520546,
#   1.3291219574778883,
#   7.890410958904109),
#  'PBS, marine water, fiber, 0.1, inf': (2.6301369863013697,
#   1.3291219574778883,
#   7.890410958904109),
#  'PBS, marine water, particle, 0.1, inf': (1.9726027397260273,
#   1.3291219574778883,
#   7.890410958904109),
#  'PBS, marine water, film, 1.0, inf': (39.45205479452054,
#   1.3291219574778883,
#   78.90410958904108),
#  'PBS, marine water, fiber, 1.0, inf': (26.301369863013694,
#   1.3291219574778883,
#   78.90410958904108),
#  'PBS, marine water, particle, 1.0, inf': (19.72602739726027,
#   1.3291219574778883,
#   78.90410958904108),
#  'PBS, marine water, film, 10.0, inf': (394.52054794520546,
#   1.3291219574778883,
#   789.0410958904109),
#  'PBS, marine water, fiber, 10.0, inf': (263.01369863013696,
#   1.3291219574778883,
#   789.0410958904109),
#  'PBS, marine water, particle, 10.0, inf': (197.26027397260273,
#   1.3291219574778883,
#   789.0410958904109),
#  'PBS, river sediment, film, 0.1, inf': (3.9452054794520546,
#   1.437266060853234,
#   7.890410958904109),
#  'PBS, river sediment, fiber, 0.1, inf': (2.6301369863013697,
#   1.437266060853234,
#   7.890410958904109),
#  'PBS, river sediment, particle, 0.1, inf': (1.9726027397260273,
#   1.437266060853234,
#   7.890410958904109),
#  'PBS, river sediment, film, 1.0, inf': (39.45205479452054,
#   1.437266060853234,
#   78.90410958904108),
#  'PBS, river sediment, fiber, 1.0, inf': (26.301369863013694,
#   1.437266060853234,
#   78.90410958904108),
#  'PBS, river sediment, particle, 1.0, inf': (19.72602739726027,
#   1.437266060853234,
#   78.90410958904108),
#  'PBS, river sediment, film, 10.0, inf': (394.52054794520546,
#   1.437266060853234,
#   789.0410958904109),
#  'PBS, river sediment, fiber, 10.0, inf': (263.01369863013696,
#   1.437266060853234,
#   789.0410958904109),
#  'PBS, river sediment, particle, 10.0, inf': (197.26027397260273,
#   1.437266060853234,
#   789.0410958904109),
#  'PBS, soil, film, 0.1, inf': (0.4090355804844972,
#   1.2142616701550326,
#   0.8180711609689943),
#  'PBS, soil, fiber, 0.1, inf': (0.2726903869896648,
#   1.2142616701550326,
#   0.8180711609689943),
#  'PBS, soil, particle, 0.1, inf': (0.2045177902422486,
#   1.2142616701550326,
#   0.8180711609689943),
#  'PBS, soil, film, 1.0, inf': (4.090355804844972,
#   1.2142616701550326,
#   8.180711609689943),
#  'PBS, soil, fiber, 1.0, inf': (2.7269038698966477,
#   1.2142616701550326,
#   8.180711609689943),
#  'PBS, soil, particle, 1.0, inf': (2.045177902422486,
#   1.2142616701550326,
#   8.180711609689943),
#  'PBS, soil, film, 10.0, inf': (40.90355804844972,
#   1.2142616701550326,
#   81.80711609689943),
#  'PBS, soil, fiber, 10.0, inf': (27.26903869896648,
#   1.2142616701550326,
#   81.80711609689943),
#  'PBS, soil, particle, 10.0, inf': (20.45177902422486,
#   1.2142616701550326,
#   81.80711609689943),
#  'PBSA, marine sediment, film, 0.1, inf': (0.27121903935922376,
#   1.3781722776734169,
#   0.5424380787184475),
#  'PBSA, marine sediment, fiber, 0.1, inf': (0.18081269290614918,
#   1.3781722776734169,
#   0.5424380787184475),
#  'PBSA, marine sediment, particle, 0.1, inf': (0.13560951967961188,
#   1.3781722776734169,
#   0.5424380787184475),
#  'PBSA, marine sediment, film, 1.0, inf': (2.7121903935922376,
#   1.3781722776734169,
#   5.424380787184475),
#  'PBSA, marine sediment, fiber, 1.0, inf': (1.8081269290614916,
#   1.3781722776734169,
#   5.424380787184475),
#  'PBSA, marine sediment, particle, 1.0, inf': (1.3560951967961188,
#   1.3781722776734169,
#   5.424380787184475),
#  'PBSA, marine sediment, film, 10.0, inf': (27.121903935922376,
#   1.3781722776734169,
#   54.24380787184475),
#  'PBSA, marine sediment, fiber, 10.0, inf': (18.081269290614916,
#   1.3781722776734169,
#   54.24380787184475),
#  'PBSA, marine sediment, particle, 10.0, inf': (13.560951967961188,
#   1.3781722776734169,
#   54.24380787184475),
#  'PBSA, marine water, film, 0.1, inf': (0.27121903935922376,
#   1.2568291915636591,
#   0.5424380787184475),
#  'PBSA, marine water, fiber, 0.1, inf': (0.18081269290614918,
#   1.2568291915636591,
#   0.5424380787184475),
#  'PBSA, marine water, particle, 0.1, inf': (0.13560951967961188,
#   1.2568291915636591,
#   0.5424380787184475),
#  'PBSA, marine water, film, 1.0, inf': (2.7121903935922376,
#   1.2568291915636591,
#   5.424380787184475),
#  'PBSA, marine water, fiber, 1.0, inf': (1.8081269290614916,
#   1.2568291915636591,
#   5.424380787184475),
#  'PBSA, marine water, particle, 1.0, inf': (1.3560951967961188,
#   1.2568291915636591,
#   5.424380787184475),
#  'PBSA, marine water, film, 10.0, inf': (27.121903935922376,
#   1.2568291915636591,
#   54.24380787184475),
#  'PBSA, marine water, fiber, 10.0, inf': (18.081269290614916,
#   1.2568291915636591,
#   54.24380787184475),
#  'PBSA, marine water, particle, 10.0, inf': (13.560951967961188,
#   1.2568291915636591,
#   54.24380787184475),
#  'PBSA, river sediment, film, 0.1, inf': (0.27121903935922376,
#   1.3781722776734169,
#   0.5424380787184475),
#  'PBSA, river sediment, fiber, 0.1, inf': (0.18081269290614918,
#   1.3781722776734169,
#   0.5424380787184475),
#  'PBSA, river sediment, particle, 0.1, inf': (0.13560951967961188,
#   1.3781722776734169,
#   0.5424380787184475),
#  'PBSA, river sediment, film, 1.0, inf': (2.7121903935922376,
#   1.3781722776734169,
#   5.424380787184475),
#  'PBSA, river sediment, fiber, 1.0, inf': (1.8081269290614916,
#   1.3781722776734169,
#   5.424380787184475),
#  'PBSA, river sediment, particle, 1.0, inf': (1.3560951967961188,
#   1.3781722776734169,
#   5.424380787184475),
#  'PBSA, river sediment, film, 10.0, inf': (27.121903935922376,
#   1.3781722776734169,
#   54.24380787184475),
#  'PBSA, river sediment, fiber, 10.0, inf': (18.081269290614916,
#   1.3781722776734169,
#   54.24380787184475),
#  'PBSA, river sediment, particle, 10.0, inf': (13.560951967961188,
#   1.3781722776734169,
#   54.24380787184475),
#  'PBSA, soil, film, 0.1, inf': (0.49589041095890396,
#   1.2838373185769794,
#   0.9917808219178079),
#  'PBSA, soil, fiber, 0.1, inf': (0.33059360730593595,
#   1.2838373185769794,
#   0.9917808219178079),
#  'PBSA, soil, particle, 0.1, inf': (0.24794520547945198,
#   1.2838373185769794,
#   0.9917808219178079),
#  'PBSA, soil, film, 1.0, inf': (4.95890410958904,
#   1.2838373185769794,
#   9.91780821917808),
#  'PBSA, soil, fiber, 1.0, inf': (3.30593607305936,
#   1.2838373185769794,
#   9.91780821917808),
#  'PBSA, soil, particle, 1.0, inf': (2.47945205479452,
#   1.2838373185769794,
#   9.91780821917808),
#  'PBSA, soil, film, 10.0, inf': (49.589041095890394,
#   1.2838373185769794,
#   99.17808219178079),
#  'PBSA, soil, fiber, 10.0, inf': (33.059360730593596,
#   1.2838373185769794,
#   99.17808219178079),
#  'PBSA, soil, particle, 10.0, inf': (24.794520547945197,
#   1.2838373185769794,
#   99.17808219178079),
#  'PBSe, marine sediment, film, 0.1, inf': (9.961643835616437,
#   1.0981215093515928,
#   19.923287671232874),
#  'PBSe, marine sediment, fiber, 0.1, inf': (6.641095890410958,
#   1.0981215093515928,
#   19.923287671232874),
#  'PBSe, marine sediment, particle, 0.1, inf': (4.9808219178082185,
#   1.0981215093515928,
#   19.923287671232874),
#  'PBSe, marine sediment, film, 1.0, inf': (99.61643835616438,
#   1.0981215093515928,
#   199.23287671232876),
#  'PBSe, marine sediment, fiber, 1.0, inf': (66.41095890410959,
#   1.0981215093515928,
#   199.23287671232876),
#  'PBSe, marine sediment, particle, 1.0, inf': (49.80821917808219,
#   1.0981215093515928,
#   199.23287671232876),
#  'PBSe, marine sediment, film, 10.0, inf': (996.1643835616437,
#   1.0981215093515928,
#   1992.3287671232874),
#  'PBSe, marine sediment, fiber, 10.0, inf': (664.1095890410958,
#   1.0981215093515928,
#   1992.3287671232874),
#  'PBSe, marine sediment, particle, 10.0, inf': (498.08219178082186,
#   1.0981215093515928,
#   1992.3287671232874),
#  'PBSe, marine water, film, 0.1, inf': (9.797064139497333,
#   1.0981215093515928,
#   19.594128278994667),
#  'PBSe, marine water, fiber, 0.1, inf': (6.531376092998222,
#   1.0981215093515928,
#   19.594128278994667),
#  'PBSe, marine water, particle, 0.1, inf': (4.898532069748667,
#   1.0981215093515928,
#   19.594128278994667),
#  'PBSe, marine water, film, 1.0, inf': (97.97064139497334,
#   1.0981215093515928,
#   195.94128278994668),
#  'PBSe, marine water, fiber, 1.0, inf': (65.31376092998222,
#   1.0981215093515928,
#   195.94128278994668),
#  'PBSe, marine water, particle, 1.0, inf': (48.98532069748667,
#   1.0981215093515928,
#   195.94128278994668),
#  'PBSe, marine water, film, 10.0, inf': (979.7064139497334,
#   1.0981215093515928,
#   1959.4128278994667),
#  'PBSe, marine water, fiber, 10.0, inf': (653.1376092998222,
#   1.0981215093515928,
#   1959.4128278994667),
#  'PBSe, marine water, particle, 10.0, inf': (489.8532069748667,
#   1.0981215093515928,
#   1959.4128278994667),
#  'PBSe, river sediment, film, 0.1, inf': (9.961643835616437,
#   1.2759692133746712,
#   19.923287671232874),
#  'PBSe, river sediment, fiber, 0.1, inf': (6.641095890410958,
#   1.2759692133746712,
#   19.923287671232874),
#  'PBSe, river sediment, particle, 0.1, inf': (4.9808219178082185,
#   1.2759692133746712,
#   19.923287671232874),
#  'PBSe, river sediment, film, 1.0, inf': (99.61643835616438,
#   1.2759692133746712,
#   199.23287671232876),
#  'PBSe, river sediment, fiber, 1.0, inf': (66.41095890410959,
#   1.2759692133746712,
#   199.23287671232876),
#  'PBSe, river sediment, particle, 1.0, inf': (49.80821917808219,
#   1.2759692133746712,
#   199.23287671232876),
#  'PBSe, river sediment, film, 10.0, inf': (996.1643835616437,
#   1.2759692133746712,
#   1992.3287671232874),
#  'PBSe, river sediment, fiber, 10.0, inf': (664.1095890410958,
#   1.2759692133746712,
#   1992.3287671232874),
#  'PBSe, river sediment, particle, 10.0, inf': (498.08219178082186,
#   1.2759692133746712,
#   1992.3287671232874),
#  'PBSe, soil, film, 0.1, inf': (1.0174443779501996,
#   1.2326786424407017,
#   2.034888755900399),
#  'PBSe, soil, fiber, 0.1, inf': (0.6782962519667998,
#   1.2326786424407017,
#   2.034888755900399),
#  'PBSe, soil, particle, 0.1, inf': (0.5087221889750998,
#   1.2326786424407017,
#   2.034888755900399),
#  'PBSe, soil, film, 1.0, inf': (10.174443779501996,
#   1.2326786424407017,
#   20.34888755900399),
#  'PBSe, soil, fiber, 1.0, inf': (6.782962519667997,
#   1.2326786424407017,
#   20.34888755900399),
#  'PBSe, soil, particle, 1.0, inf': (5.087221889750998,
#   1.2326786424407017,
#   20.34888755900399),
#  'PBSe, soil, film, 10.0, inf': (101.74443779501995,
#   1.2326786424407017,
#   203.4888755900399),
#  'PBSe, soil, fiber, 10.0, inf': (67.82962519667997,
#   1.2326786424407017,
#   203.4888755900399),
#  'PBSe, soil, particle, 10.0, inf': (50.872218897509974,
#   1.2326786424407017,
#   203.4888755900399),
#  'PBSeT, marine sediment, film, 0.1, inf': (11.736986301369862,
#   1.0981215093515928,
#   23.473972602739725),
#  'PBSeT, marine sediment, fiber, 0.1, inf': (7.824657534246575,
#   1.0981215093515928,
#   23.473972602739725),
#  'PBSeT, marine sediment, particle, 0.1, inf': (5.868493150684931,
#   1.0981215093515928,
#   23.473972602739725),
#  'PBSeT, marine sediment, film, 1.0, inf': (117.36986301369863,
#   1.0981215093515928,
#   234.73972602739727),
#  'PBSeT, marine sediment, fiber, 1.0, inf': (78.24657534246576,
#   1.0981215093515928,
#   234.73972602739727),
#  'PBSeT, marine sediment, particle, 1.0, inf': (58.68493150684932,
#   1.0981215093515928,
#   234.73972602739727),
#  'PBSeT, marine sediment, film, 10.0, inf': (1173.6986301369864,
#   1.0981215093515928,
#   2347.3972602739727),
#  'PBSeT, marine sediment, fiber, 10.0, inf': (782.4657534246576,
#   1.0981215093515928,
#   2347.3972602739727),
#  'PBSeT, marine sediment, particle, 10.0, inf': (586.8493150684932,
#   1.0981215093515928,
#   2347.3972602739727),
#  'PBSeT, marine water, film, 0.1, inf': (14.568712056627671,
#   1.0981215093515928,
#   29.137424113255342),
#  'PBSeT, marine water, fiber, 0.1, inf': (9.712474704418447,
#   1.0981215093515928,
#   29.137424113255342),
#  'PBSeT, marine water, particle, 0.1, inf': (7.2843560283138356,
#   1.0981215093515928,
#   29.137424113255342),
#  'PBSeT, marine water, film, 1.0, inf': (145.68712056627672,
#   1.0981215093515928,
#   291.37424113255344),
#  'PBSeT, marine water, fiber, 1.0, inf': (97.12474704418447,
#   1.0981215093515928,
#   291.37424113255344),
#  'PBSeT, marine water, particle, 1.0, inf': (72.84356028313836,
#   1.0981215093515928,
#   291.37424113255344),
#  'PBSeT, marine water, film, 10.0, inf': (1456.8712056627671,
#   1.0981215093515928,
#   2913.7424113255342),
#  'PBSeT, marine water, fiber, 10.0, inf': (971.2474704418447,
#   1.0981215093515928,
#   2913.7424113255342),
#  'PBSeT, marine water, particle, 10.0, inf': (728.4356028313836,
#   1.0981215093515928,
#   2913.7424113255342),
#  'PBSeT, river sediment, film, 0.1, inf': (11.736986301369862,
#   1.2759692133746712,
#   23.473972602739725),
#  'PBSeT, river sediment, fiber, 0.1, inf': (7.824657534246575,
#   1.2759692133746712,
#   23.473972602739725),
#  'PBSeT, river sediment, particle, 0.1, inf': (5.868493150684931,
#   1.2759692133746712,
#   23.473972602739725),
#  'PBSeT, river sediment, film, 1.0, inf': (117.36986301369863,
#   1.2759692133746712,
#   234.73972602739727),
#  'PBSeT, river sediment, fiber, 1.0, inf': (78.24657534246576,
#   1.2759692133746712,
#   234.73972602739727),
#  'PBSeT, river sediment, particle, 1.0, inf': (58.68493150684932,
#   1.2759692133746712,
#   234.73972602739727),
#  'PBSeT, river sediment, film, 10.0, inf': (1173.6986301369864,
#   1.2759692133746712,
#   2347.3972602739727),
#  'PBSeT, river sediment, fiber, 10.0, inf': (782.4657534246576,
#   1.2759692133746712,
#   2347.3972602739727),
#  'PBSeT, river sediment, particle, 10.0, inf': (586.8493150684932,
#   1.2759692133746712,
#   2347.3972602739727),
#  'PBSeT, soil, film, 0.1, inf': (1.27189668564922,
#   1.2326786424407017,
#   2.54379337129844),
#  'PBSeT, soil, fiber, 0.1, inf': (0.8479311237661467,
#   1.2326786424407017,
#   2.54379337129844),
#  'PBSeT, soil, particle, 0.1, inf': (0.63594834282461,
#   1.2326786424407017,
#   2.54379337129844),
#  'PBSeT, soil, film, 1.0, inf': (12.7189668564922,
#   1.2326786424407017,
#   25.4379337129844),
#  'PBSeT, soil, fiber, 1.0, inf': (8.479311237661467,
#   1.2326786424407017,
#   25.4379337129844),
#  'PBSeT, soil, particle, 1.0, inf': (6.3594834282461,
#   1.2326786424407017,
#   25.4379337129844),
#  'PBSeT, soil, film, 10.0, inf': (127.189668564922,
#   1.2326786424407017,
#   254.379337129844),
#  'PBSeT, soil, fiber, 10.0, inf': (84.79311237661467,
#   1.2326786424407017,
#   254.379337129844),
#  'PBSeT, soil, particle, 10.0, inf': (63.594834282461,
#   1.2326786424407017,
#   254.379337129844),
#  'PC, marine sediment, film, 0.1, inf': (4.830917874396124,
#   1.8607030663907251,
#   9.661835748792248),
#  'PC, marine sediment, fiber, 0.1, inf': (3.2206119162640827,
#   1.8607030663907251,
#   9.661835748792248),
#  'PC, marine sediment, particle, 0.1, inf': (2.415458937198062,
#   1.8607030663907251,
#   9.661835748792248),
#  'PC, marine sediment, film, 1.0, inf': (48.30917874396124,
#   1.8607030663907251,
#   96.61835748792248),
#  'PC, marine sediment, fiber, 1.0, inf': (32.206119162640825,
#   1.8607030663907251,
#   96.61835748792248),
#  'PC, marine sediment, particle, 1.0, inf': (24.15458937198062,
#   1.8607030663907251,
#   96.61835748792248),
#  'PC, marine sediment, film, 10.0, inf': (483.0917874396124,
#   1.8607030663907251,
#   966.1835748792248),
#  'PC, marine sediment, fiber, 10.0, inf': (322.0611916264083,
#   1.8607030663907251,
#   966.1835748792248),
#  'PC, marine sediment, particle, 10.0, inf': (241.5458937198062,
#   1.8607030663907251,
#   966.1835748792248),
#  'PC, marine water, film, 0.1, inf': (4.830917874396124,
#   1.7838093127266956,
#   9.661835748792248),
#  'PC, marine water, fiber, 0.1, inf': (3.2206119162640827,
#   1.7838093127266956,
#   9.661835748792248),
#  'PC, marine water, particle, 0.1, inf': (2.415458937198062,
#   1.7838093127266956,
#   9.661835748792248),
#  'PC, marine water, film, 1.0, inf': (48.30917874396124,
#   1.7838093127266956,
#   96.61835748792248),
#  'PC, marine water, fiber, 1.0, inf': (32.206119162640825,
#   1.7838093127266956,
#   96.61835748792248),
#  'PC, marine water, particle, 1.0, inf': (24.15458937198062,
#   1.7838093127266956,
#   96.61835748792248),
#  'PC, marine water, film, 10.0, inf': (483.0917874396124,
#   1.7838093127266956,
#   966.1835748792248),
#  'PC, marine water, fiber, 10.0, inf': (322.0611916264083,
#   1.7838093127266956,
#   966.1835748792248),
#  'PC, marine water, particle, 10.0, inf': (241.5458937198062,
#   1.7838093127266956,
#   966.1835748792248),
#  'PC, river sediment, film, 0.1, inf': (4.830917874396124,
#   1.8607030663907251,
#   9.661835748792248),
#  'PC, river sediment, fiber, 0.1, inf': (3.2206119162640827,
#   1.8607030663907251,
#   9.661835748792248),
#  'PC, river sediment, particle, 0.1, inf': (2.415458937198062,
#   1.8607030663907251,
#   9.661835748792248),
#  'PC, river sediment, film, 1.0, inf': (48.30917874396124,
#   1.8607030663907251,
#   96.61835748792248),
#  'PC, river sediment, fiber, 1.0, inf': (32.206119162640825,
#   1.8607030663907251,
#   96.61835748792248),
#  'PC, river sediment, particle, 1.0, inf': (24.15458937198062,
#   1.8607030663907251,
#   96.61835748792248),
#  'PC, river sediment, film, 10.0, inf': (483.0917874396124,
#   1.8607030663907251,
#   966.1835748792248),
#  'PC, river sediment, fiber, 10.0, inf': (322.0611916264083,
#   1.8607030663907251,
#   966.1835748792248),
#  'PC, river sediment, particle, 10.0, inf': (241.5458937198062,
#   1.8607030663907251,
#   966.1835748792248),
#  'PC, soil, film, 0.1, inf': (4.830917874396124,
#   1.8607030663907251,
#   9.661835748792248),
#  'PC, soil, fiber, 0.1, inf': (3.2206119162640827,
#   1.8607030663907251,
#   9.661835748792248),
#  'PC, soil, particle, 0.1, inf': (2.415458937198062,
#   1.8607030663907251,
#   9.661835748792248),
#  'PC, soil, film, 1.0, inf': (48.30917874396124,
#   1.8607030663907251,
#   96.61835748792248),
#  'PC, soil, fiber, 1.0, inf': (32.206119162640825,
#   1.8607030663907251,
#   96.61835748792248),
#  'PC, soil, particle, 1.0, inf': (24.15458937198062,
#   1.8607030663907251,
#   96.61835748792248),
#  'PC, soil, film, 10.0, inf': (483.0917874396124,
#   1.8607030663907251,
#   966.1835748792248),
#  'PC, soil, fiber, 10.0, inf': (322.0611916264083,
#   1.8607030663907251,
#   966.1835748792248),
#  'PC, soil, particle, 10.0, inf': (241.5458937198062,
#   1.8607030663907251,
#   966.1835748792248),
#  'PCL, marine sediment, film, 0.1, inf': (0.05766703363383349,
#   1.3370303520790934,
#   0.11533406726766698),
#  'PCL, marine sediment, fiber, 0.1, inf': (0.03844468908922233,
#   1.3370303520790934,
#   0.11533406726766698),
#  'PCL, marine sediment, particle, 0.1, inf': (0.028833516816916746,
#   1.3370303520790934,
#   0.11533406726766698),
#  'PCL, marine sediment, film, 1.0, inf': (0.5766703363383349,
#   1.3370303520790934,
#   1.1533406726766697),
#  'PCL, marine sediment, fiber, 1.0, inf': (0.3844468908922232,
#   1.3370303520790934,
#   1.1533406726766697),
#  'PCL, marine sediment, particle, 1.0, inf': (0.28833516816916743,
#   1.3370303520790934,
#   1.1533406726766697),
#  'PCL, marine sediment, film, 10.0, inf': (5.766703363383349,
#   1.3370303520790934,
#   11.533406726766698),
#  'PCL, marine sediment, fiber, 10.0, inf': (3.8444689089222326,
#   1.3370303520790934,
#   11.533406726766698),
#  'PCL, marine sediment, particle, 10.0, inf': (2.8833516816916744,
#   1.3370303520790934,
#   11.533406726766698),
#  'PCL, marine water, film, 0.1, inf': (0.05766703363383349,
#   1.2016048931614587,
#   0.11533406726766698),
#  'PCL, marine water, fiber, 0.1, inf': (0.03844468908922233,
#   1.2016048931614587,
#   0.11533406726766698),
#  'PCL, marine water, particle, 0.1, inf': (0.028833516816916746,
#   1.2016048931614587,
#   0.11533406726766698),
#  'PCL, marine water, film, 1.0, inf': (0.5766703363383349,
#   1.2016048931614587,
#   1.1533406726766697),
#  'PCL, marine water, fiber, 1.0, inf': (0.3844468908922232,
#   1.2016048931614587,
#   1.1533406726766697),
#  'PCL, marine water, particle, 1.0, inf': (0.28833516816916743,
#   1.2016048931614587,
#   1.1533406726766697),
#  'PCL, marine water, film, 10.0, inf': (5.766703363383349,
#   1.2016048931614587,
#   11.533406726766698),
#  'PCL, marine water, fiber, 10.0, inf': (3.8444689089222326,
#   1.2016048931614587,
#   11.533406726766698),
#  'PCL, marine water, particle, 10.0, inf': (2.8833516816916744,
#   1.2016048931614587,
#   11.533406726766698),
#  'PCL, river sediment, film, 0.1, inf': (0.05766703363383349,
#   1.3370303520790934,
#   0.11533406726766698),
#  'PCL, river sediment, fiber, 0.1, inf': (0.03844468908922233,
#   1.3370303520790934,
#   0.11533406726766698),
#  'PCL, river sediment, particle, 0.1, inf': (0.028833516816916746,
#   1.3370303520790934,
#   0.11533406726766698),
#  'PCL, river sediment, film, 1.0, inf': (0.5766703363383349,
#   1.3370303520790934,
#   1.1533406726766697),
#  'PCL, river sediment, fiber, 1.0, inf': (0.3844468908922232,
#   1.3370303520790934,
#   1.1533406726766697),
#  'PCL, river sediment, particle, 1.0, inf': (0.28833516816916743,
#   1.3370303520790934,
#   1.1533406726766697),
#  'PCL, river sediment, film, 10.0, inf': (5.766703363383349,
#   1.3370303520790934,
#   11.533406726766698),
#  'PCL, river sediment, fiber, 10.0, inf': (3.8444689089222326,
#   1.3370303520790934,
#   11.533406726766698),
#  'PCL, river sediment, particle, 10.0, inf': (2.8833516816916744,
#   1.3370303520790934,
#   11.533406726766698),
#  'PCL, soil, film, 0.1, inf': (0.05766703363383349,
#   1.3370303520790934,
#   0.11533406726766698),
#  'PCL, soil, fiber, 0.1, inf': (0.03844468908922233,
#   1.3370303520790934,
#   0.11533406726766698),
#  'PCL, soil, particle, 0.1, inf': (0.028833516816916746,
#   1.3370303520790934,
#   0.11533406726766698),
#  'PCL, soil, film, 1.0, inf': (0.5766703363383349,
#   1.3370303520790934,
#   1.1533406726766697),
#  'PCL, soil, fiber, 1.0, inf': (0.3844468908922232,
#   1.3370303520790934,
#   1.1533406726766697),
#  'PCL, soil, particle, 1.0, inf': (0.28833516816916743,
#   1.3370303520790934,
#   1.1533406726766697),
#  'PCL, soil, film, 10.0, inf': (5.766703363383349,
#   1.3370303520790934,
#   11.533406726766698),
#  'PCL, soil, fiber, 10.0, inf': (3.8444689089222326,
#   1.3370303520790934,
#   11.533406726766698),
#  'PCL, soil, particle, 10.0, inf': (2.8833516816916744,
#   1.3370303520790934,
#   11.533406726766698),
#  'PE, marine sediment, film, 0.1, inf': (25000.0, 1.8470437384635119, 50000.0),
#  'PE, marine sediment, fiber, 0.1, inf': (16666.666666666668,
#   1.8470437384635119,
#   50000.0),
#  'PE, marine sediment, particle, 0.1, inf': (12500.0,
#   1.8470437384635119,
#   50000.0),
#  'PE, marine sediment, film, 1.0, inf': (250000.0,
#   1.8470437384635119,
#   500000.0),
#  'PE, marine sediment, fiber, 1.0, inf': (166666.66666666666,
#   1.8470437384635119,
#   500000.0),
#  'PE, marine sediment, particle, 1.0, inf': (125000.0,
#   1.8470437384635119,
#   500000.0),
#  'PE, marine sediment, film, 10.0, inf': (2500000.0,
#   1.8470437384635119,
#   5000000.0),
#  'PE, marine sediment, fiber, 10.0, inf': (1666666.6666666667,
#   1.8470437384635119,
#   5000000.0),
#  'PE, marine sediment, particle, 10.0, inf': (1250000.0,
#   1.8470437384635119,
#   5000000.0),
#  'PE, marine water, film, 0.1, inf': (25000.0, 1.769750613029825, 50000.0),
#  'PE, marine water, fiber, 0.1, inf': (16666.666666666668,
#   1.769750613029825,
#   50000.0),
#  'PE, marine water, particle, 0.1, inf': (12500.0, 1.769750613029825, 50000.0),
#  'PE, marine water, film, 1.0, inf': (250000.0, 1.769750613029825, 500000.0),
#  'PE, marine water, fiber, 1.0, inf': (166666.66666666666,
#   1.769750613029825,
#   500000.0),
#  'PE, marine water, particle, 1.0, inf': (125000.0,
#   1.769750613029825,
#   500000.0),
#  'PE, marine water, film, 10.0, inf': (2500000.0,
#   1.769750613029825,
#   5000000.0),
#  'PE, marine water, fiber, 10.0, inf': (1666666.6666666667,
#   1.769750613029825,
#   5000000.0),
#  'PE, marine water, particle, 10.0, inf': (1250000.0,
#   1.769750613029825,
#   5000000.0),
#  'PE, river sediment, film, 0.1, inf': (25000.0, 1.8470437384635119, 50000.0),
#  'PE, river sediment, fiber, 0.1, inf': (16666.666666666668,
#   1.8470437384635119,
#   50000.0),
#  'PE, river sediment, particle, 0.1, inf': (12500.0,
#   1.8470437384635119,
#   50000.0),
#  'PE, river sediment, film, 1.0, inf': (250000.0,
#   1.8470437384635119,
#   500000.0),
#  'PE, river sediment, fiber, 1.0, inf': (166666.66666666666,
#   1.8470437384635119,
#   500000.0),
#  'PE, river sediment, particle, 1.0, inf': (125000.0,
#   1.8470437384635119,
#   500000.0),
#  'PE, river sediment, film, 10.0, inf': (2500000.0,
#   1.8470437384635119,
#   5000000.0),
#  'PE, river sediment, fiber, 10.0, inf': (1666666.6666666667,
#   1.8470437384635119,
#   5000000.0),
#  'PE, river sediment, particle, 10.0, inf': (1250000.0,
#   1.8470437384635119,
#   5000000.0),
#  'PE, soil, film, 0.1, inf': (39.973476457851355,
#   1.5771335732803868,
#   79.94695291570271),
#  'PE, soil, fiber, 0.1, inf': (26.648984305234237,
#   1.5771335732803868,
#   79.94695291570271),
#  'PE, soil, particle, 0.1, inf': (19.986738228925677,
#   1.5771335732803868,
#   79.94695291570271),
#  'PE, soil, film, 1.0, inf': (399.73476457851353,
#   1.5771335732803868,
#   799.4695291570271),
#  'PE, soil, fiber, 1.0, inf': (266.48984305234234,
#   1.5771335732803868,
#   799.4695291570271),
#  'PE, soil, particle, 1.0, inf': (199.86738228925677,
#   1.5771335732803868,
#   799.4695291570271),
#  'PE, soil, film, 10.0, inf': (3997.3476457851352,
#   1.5771335732803868,
#   7994.6952915702705),
#  'PE, soil, fiber, 10.0, inf': (2664.8984305234235,
#   1.5771335732803868,
#   7994.6952915702705),
#  'PE, soil, particle, 10.0, inf': (1998.6738228925676,
#   1.5771335732803868,
#   7994.6952915702705),
#  'PEA, marine sediment, film, 0.1, inf': (0.05900948366701791,
#   1.3370303520790934,
#   0.11801896733403582),
#  'PEA, marine sediment, fiber, 0.1, inf': (0.03933965577801194,
#   1.3370303520790934,
#   0.11801896733403582),
#  'PEA, marine sediment, particle, 0.1, inf': (0.029504741833508954,
#   1.3370303520790934,
#   0.11801896733403582),
#  'PEA, marine sediment, film, 1.0, inf': (0.590094836670179,
#   1.3370303520790934,
#   1.180189673340358),
#  'PEA, marine sediment, fiber, 1.0, inf': (0.39339655778011934,
#   1.3370303520790934,
#   1.180189673340358),
#  'PEA, marine sediment, particle, 1.0, inf': (0.2950474183350895,
#   1.3370303520790934,
#   1.180189673340358),
#  'PEA, marine sediment, film, 10.0, inf': (5.90094836670179,
#   1.3370303520790934,
#   11.80189673340358),
#  'PEA, marine sediment, fiber, 10.0, inf': (3.9339655778011937,
#   1.3370303520790934,
#   11.80189673340358),
#  'PEA, marine sediment, particle, 10.0, inf': (2.950474183350895,
#   1.3370303520790934,
#   11.80189673340358),
#  'PEA, marine water, film, 0.1, inf': (0.05900948366701791,
#   1.2016048931614587,
#   0.11801896733403582),
#  'PEA, marine water, fiber, 0.1, inf': (0.03933965577801194,
#   1.2016048931614587,
#   0.11801896733403582),
#  'PEA, marine water, particle, 0.1, inf': (0.029504741833508954,
#   1.2016048931614587,
#   0.11801896733403582),
#  'PEA, marine water, film, 1.0, inf': (0.590094836670179,
#   1.2016048931614587,
#   1.180189673340358),
#  'PEA, marine water, fiber, 1.0, inf': (0.39339655778011934,
#   1.2016048931614587,
#   1.180189673340358),
#  'PEA, marine water, particle, 1.0, inf': (0.2950474183350895,
#   1.2016048931614587,
#   1.180189673340358),
#  'PEA, marine water, film, 10.0, inf': (5.90094836670179,
#   1.2016048931614587,
#   11.80189673340358),
#  'PEA, marine water, fiber, 10.0, inf': (3.9339655778011937,
#   1.2016048931614587,
#   11.80189673340358),
#  'PEA, marine water, particle, 10.0, inf': (2.950474183350895,
#   1.2016048931614587,
#   11.80189673340358),
#  'PEA, river sediment, film, 0.1, inf': (0.05900948366701791,
#   1.3370303520790934,
#   0.11801896733403582),
#  'PEA, river sediment, fiber, 0.1, inf': (0.03933965577801194,
#   1.3370303520790934,
#   0.11801896733403582),
#  'PEA, river sediment, particle, 0.1, inf': (0.029504741833508954,
#   1.3370303520790934,
#   0.11801896733403582),
#  'PEA, river sediment, film, 1.0, inf': (0.590094836670179,
#   1.3370303520790934,
#   1.180189673340358),
#  'PEA, river sediment, fiber, 1.0, inf': (0.39339655778011934,
#   1.3370303520790934,
#   1.180189673340358),
#  'PEA, river sediment, particle, 1.0, inf': (0.2950474183350895,
#   1.3370303520790934,
#   1.180189673340358),
#  'PEA, river sediment, film, 10.0, inf': (5.90094836670179,
#   1.3370303520790934,
#   11.80189673340358),
#  'PEA, river sediment, fiber, 10.0, inf': (3.9339655778011937,
#   1.3370303520790934,
#   11.80189673340358),
#  'PEA, river sediment, particle, 10.0, inf': (2.950474183350895,
#   1.3370303520790934,
#   11.80189673340358),
#  'PEA, soil, film, 0.1, inf': (0.05900948366701791,
#   1.3370303520790934,
#   0.11801896733403582),
#  'PEA, soil, fiber, 0.1, inf': (0.03933965577801194,
#   1.3370303520790934,
#   0.11801896733403582),
# ...
#   1.7838093127266956,
#   821.2150138980886),
#  'PP, river sediment, film, 0.1, inf': (83.96028120624612,
#   1.6622044844458415,
#   167.92056241249225),
#  'PP, river sediment, fiber, 0.1, inf': (55.97352080416408,
#   1.6622044844458415,
#   167.92056241249225),
#  'PP, river sediment, particle, 0.1, inf': (41.98014060312306,
#   1.6622044844458415,
#   167.92056241249225),
#  'PP, river sediment, film, 1.0, inf': (839.6028120624612,
#   1.6622044844458415,
#   1679.2056241249225),
#  'PP, river sediment, fiber, 1.0, inf': (559.7352080416408,
#   1.6622044844458415,
#   1679.2056241249225),
#  'PP, river sediment, particle, 1.0, inf': (419.8014060312306,
#   1.6622044844458415,
#   1679.2056241249225),
#  'PP, river sediment, film, 10.0, inf': (8396.028120624613,
#   1.6622044844458415,
#   16792.056241249225),
#  'PP, river sediment, fiber, 10.0, inf': (5597.352080416408,
#   1.6622044844458415,
#   16792.056241249225),
#  'PP, river sediment, particle, 10.0, inf': (4198.014060312306,
#   1.6622044844458415,
#   16792.056241249225),
#  'PP, soil, film, 0.1, inf': (83.96028120624612,
#   1.5771335732803868,
#   167.92056241249225),
#  'PP, soil, fiber, 0.1, inf': (55.97352080416408,
#   1.5771335732803868,
#   167.92056241249225),
#  'PP, soil, particle, 0.1, inf': (41.98014060312306,
#   1.5771335732803868,
#   167.92056241249225),
#  'PP, soil, film, 1.0, inf': (839.6028120624612,
#   1.5771335732803868,
#   1679.2056241249225),
#  'PP, soil, fiber, 1.0, inf': (559.7352080416408,
#   1.5771335732803868,
#   1679.2056241249225),
#  'PP, soil, particle, 1.0, inf': (419.8014060312306,
#   1.5771335732803868,
#   1679.2056241249225),
#  'PP, soil, film, 10.0, inf': (8396.028120624613,
#   1.5771335732803868,
#   16792.056241249225),
#  'PP, soil, fiber, 10.0, inf': (5597.352080416408,
#   1.5771335732803868,
#   16792.056241249225),
#  'PP, soil, particle, 10.0, inf': (4198.014060312306,
#   1.5771335732803868,
#   16792.056241249225),
#  'PS, marine sediment, film, 0.1, inf': (25000.0, 3.6420115857881514, 50000.0),
#  'PS, marine sediment, fiber, 0.1, inf': (16666.666666666668,
#   3.6420115857881514,
#   50000.0),
#  'PS, marine sediment, particle, 0.1, inf': (12500.0,
#   3.6420115857881514,
#   50000.0),
#  'PS, marine sediment, film, 1.0, inf': (250000.0,
#   3.6420115857881514,
#   500000.0),
#  'PS, marine sediment, fiber, 1.0, inf': (166666.66666666666,
#   3.6420115857881514,
#   500000.0),
#  'PS, marine sediment, particle, 1.0, inf': (125000.0,
#   3.6420115857881514,
#   500000.0),
#  'PS, marine sediment, film, 10.0, inf': (2500000.0,
#   3.6420115857881514,
#   5000000.0),
#  'PS, marine sediment, fiber, 10.0, inf': (1666666.6666666667,
#   3.6420115857881514,
#   5000000.0),
#  'PS, marine sediment, particle, 10.0, inf': (1250000.0,
#   3.6420115857881514,
#   5000000.0),
#  'PS, marine water, film, 0.1, inf': (25000.0, 3.6420115857881514, 50000.0),
#  'PS, marine water, fiber, 0.1, inf': (16666.666666666668,
#   3.6420115857881514,
#   50000.0),
#  'PS, marine water, particle, 0.1, inf': (12500.0,
#   3.6420115857881514,
#   50000.0),
#  'PS, marine water, film, 1.0, inf': (250000.0, 3.6420115857881514, 500000.0),
#  'PS, marine water, fiber, 1.0, inf': (166666.66666666666,
#   3.6420115857881514,
#   500000.0),
#  'PS, marine water, particle, 1.0, inf': (125000.0,
#   3.6420115857881514,
#   500000.0),
#  'PS, marine water, film, 10.0, inf': (2500000.0,
#   3.6420115857881514,
#   5000000.0),
#  'PS, marine water, fiber, 10.0, inf': (1666666.6666666667,
#   3.6420115857881514,
#   5000000.0),
#  'PS, marine water, particle, 10.0, inf': (1250000.0,
#   3.6420115857881514,
#   5000000.0),
#  'PS, river sediment, film, 0.1, inf': (25000.0, 3.6420115857881514, 50000.0),
#  'PS, river sediment, fiber, 0.1, inf': (16666.666666666668,
#   3.6420115857881514,
#   50000.0),
#  'PS, river sediment, particle, 0.1, inf': (12500.0,
#   3.6420115857881514,
#   50000.0),
#  'PS, river sediment, film, 1.0, inf': (250000.0,
#   3.6420115857881514,
#   500000.0),
#  'PS, river sediment, fiber, 1.0, inf': (166666.66666666666,
#   3.6420115857881514,
#   500000.0),
#  'PS, river sediment, particle, 1.0, inf': (125000.0,
#   3.6420115857881514,
#   500000.0),
#  'PS, river sediment, film, 10.0, inf': (2500000.0,
#   3.6420115857881514,
#   5000000.0),
#  'PS, river sediment, fiber, 10.0, inf': (1666666.6666666667,
#   3.6420115857881514,
#   5000000.0),
#  'PS, river sediment, particle, 10.0, inf': (1250000.0,
#   3.6420115857881514,
#   5000000.0),
#  'PS, soil, film, 0.1, inf': (25000.0, 3.6420115857881514, 50000.0),
#  'PS, soil, fiber, 0.1, inf': (16666.666666666668,
#   3.6420115857881514,
#   50000.0),
#  'PS, soil, particle, 0.1, inf': (12500.0, 3.6420115857881514, 50000.0),
#  'PS, soil, film, 1.0, inf': (250000.0, 3.6420115857881514, 500000.0),
#  'PS, soil, fiber, 1.0, inf': (166666.66666666666,
#   3.6420115857881514,
#   500000.0),
#  'PS, soil, particle, 1.0, inf': (125000.0, 3.6420115857881514, 500000.0),
#  'PS, soil, film, 10.0, inf': (2500000.0, 3.6420115857881514, 5000000.0),
#  'PS, soil, fiber, 10.0, inf': (1666666.6666666667,
#   3.6420115857881514,
#   5000000.0),
#  'PS, soil, particle, 10.0, inf': (1250000.0, 3.6420115857881514, 5000000.0),
#  'PU, marine sediment, film, 0.1, inf': (0.12953367875647664,
#   1.6282102068858726,
#   0.2590673575129533),
#  'PU, marine sediment, fiber, 0.1, inf': (0.08635578583765109,
#   1.6282102068858726,
#   0.2590673575129533),
#  'PU, marine sediment, particle, 0.1, inf': (0.06476683937823832,
#   1.6282102068858726,
#   0.2590673575129533),
#  'PU, marine sediment, film, 1.0, inf': (1.2953367875647666,
#   1.6282102068858726,
#   2.590673575129533),
#  'PU, marine sediment, fiber, 1.0, inf': (0.863557858376511,
#   1.6282102068858726,
#   2.590673575129533),
#  'PU, marine sediment, particle, 1.0, inf': (0.6476683937823833,
#   1.6282102068858726,
#   2.590673575129533),
#  'PU, marine sediment, film, 10.0, inf': (12.953367875647665,
#   1.6282102068858726,
#   25.90673575129533),
#  'PU, marine sediment, fiber, 10.0, inf': (8.63557858376511,
#   1.6282102068858726,
#   25.90673575129533),
#  'PU, marine sediment, particle, 10.0, inf': (6.476683937823832,
#   1.6282102068858726,
#   25.90673575129533),
#  'PU, marine water, film, 0.1, inf': (0.12953367875647664,
#   1.541017014197046,
#   0.2590673575129533),
#  'PU, marine water, fiber, 0.1, inf': (0.08635578583765109,
#   1.541017014197046,
#   0.2590673575129533),
#  'PU, marine water, particle, 0.1, inf': (0.06476683937823832,
#   1.541017014197046,
#   0.2590673575129533),
#  'PU, marine water, film, 1.0, inf': (1.2953367875647666,
#   1.541017014197046,
#   2.590673575129533),
#  'PU, marine water, fiber, 1.0, inf': (0.863557858376511,
#   1.541017014197046,
#   2.590673575129533),
#  'PU, marine water, particle, 1.0, inf': (0.6476683937823833,
#   1.541017014197046,
#   2.590673575129533),
#  'PU, marine water, film, 10.0, inf': (12.953367875647665,
#   1.541017014197046,
#   25.90673575129533),
#  'PU, marine water, fiber, 10.0, inf': (8.63557858376511,
#   1.541017014197046,
#   25.90673575129533),
#  'PU, marine water, particle, 10.0, inf': (6.476683937823832,
#   1.541017014197046,
#   25.90673575129533),
#  'PU, river sediment, film, 0.1, inf': (0.12953367875647664,
#   1.6282102068858726,
#   0.2590673575129533),
#  'PU, river sediment, fiber, 0.1, inf': (0.08635578583765109,
#   1.6282102068858726,
#   0.2590673575129533),
#  'PU, river sediment, particle, 0.1, inf': (0.06476683937823832,
#   1.6282102068858726,
#   0.2590673575129533),
#  'PU, river sediment, film, 1.0, inf': (1.2953367875647666,
#   1.6282102068858726,
#   2.590673575129533),
#  'PU, river sediment, fiber, 1.0, inf': (0.863557858376511,
#   1.6282102068858726,
#   2.590673575129533),
#  'PU, river sediment, particle, 1.0, inf': (0.6476683937823833,
#   1.6282102068858726,
#   2.590673575129533),
#  'PU, river sediment, film, 10.0, inf': (12.953367875647665,
#   1.6282102068858726,
#   25.90673575129533),
#  'PU, river sediment, fiber, 10.0, inf': (8.63557858376511,
#   1.6282102068858726,
#   25.90673575129533),
#  'PU, river sediment, particle, 10.0, inf': (6.476683937823832,
#   1.6282102068858726,
#   25.90673575129533),
#  'PU, soil, film, 0.1, inf': (0.12953367875647664,
#   1.6282102068858726,
#   0.2590673575129533),
#  'PU, soil, fiber, 0.1, inf': (0.08635578583765109,
#   1.6282102068858726,
#   0.2590673575129533),
#  'PU, soil, particle, 0.1, inf': (0.06476683937823832,
#   1.6282102068858726,
#   0.2590673575129533),
#  'PU, soil, film, 1.0, inf': (1.2953367875647666,
#   1.6282102068858726,
#   2.590673575129533),
#  'PU, soil, fiber, 1.0, inf': (0.863557858376511,
#   1.6282102068858726,
#   2.590673575129533),
#  'PU, soil, particle, 1.0, inf': (0.6476683937823833,
#   1.6282102068858726,
#   2.590673575129533),
#  'PU, soil, film, 10.0, inf': (12.953367875647665,
#   1.6282102068858726,
#   25.90673575129533),
#  'PU, soil, fiber, 10.0, inf': (8.63557858376511,
#   1.6282102068858726,
#   25.90673575129533),
#  'PU, soil, particle, 10.0, inf': (6.476683937823832,
#   1.6282102068858726,
#   25.90673575129533),
#  'PVC, marine sediment, film, 0.1, inf': (25000.0,
#   3.6420115857881514,
#   50000.0),
#  'PVC, marine sediment, fiber, 0.1, inf': (16666.666666666668,
#   3.6420115857881514,
#   50000.0),
#  'PVC, marine sediment, particle, 0.1, inf': (12500.0,
#   3.6420115857881514,
#   50000.0),
#  'PVC, marine sediment, film, 1.0, inf': (250000.0,
#   3.6420115857881514,
#   500000.0),
#  'PVC, marine sediment, fiber, 1.0, inf': (166666.66666666666,
#   3.6420115857881514,
#   500000.0),
#  'PVC, marine sediment, particle, 1.0, inf': (125000.0,
#   3.6420115857881514,
#   500000.0),
#  'PVC, marine sediment, film, 10.0, inf': (2500000.0,
#   3.6420115857881514,
#   5000000.0),
#  'PVC, marine sediment, fiber, 10.0, inf': (1666666.6666666667,
#   3.6420115857881514,
#   5000000.0),
#  'PVC, marine sediment, particle, 10.0, inf': (1250000.0,
#   3.6420115857881514,
#   5000000.0),
#  'PVC, marine water, film, 0.1, inf': (25000.0, 3.6420115857881514, 50000.0),
#  'PVC, marine water, fiber, 0.1, inf': (16666.666666666668,
#   3.6420115857881514,
#   50000.0),
#  'PVC, marine water, particle, 0.1, inf': (12500.0,
#   3.6420115857881514,
#   50000.0),
#  'PVC, marine water, film, 1.0, inf': (250000.0, 3.6420115857881514, 500000.0),
#  'PVC, marine water, fiber, 1.0, inf': (166666.66666666666,
#   3.6420115857881514,
#   500000.0),
#  'PVC, marine water, particle, 1.0, inf': (125000.0,
#   3.6420115857881514,
#   500000.0),
#  'PVC, marine water, film, 10.0, inf': (2500000.0,
#   3.6420115857881514,
#   5000000.0),
#  'PVC, marine water, fiber, 10.0, inf': (1666666.6666666667,
#   3.6420115857881514,
#   5000000.0),
#  'PVC, marine water, particle, 10.0, inf': (1250000.0,
#   3.6420115857881514,
#   5000000.0),
#  'PVC, river sediment, film, 0.1, inf': (25000.0, 3.6420115857881514, 50000.0),
#  'PVC, river sediment, fiber, 0.1, inf': (16666.666666666668,
#   3.6420115857881514,
#   50000.0),
#  'PVC, river sediment, particle, 0.1, inf': (12500.0,
#   3.6420115857881514,
#   50000.0),
#  'PVC, river sediment, film, 1.0, inf': (250000.0,
#   3.6420115857881514,
#   500000.0),
#  'PVC, river sediment, fiber, 1.0, inf': (166666.66666666666,
#   3.6420115857881514,
#   500000.0),
#  'PVC, river sediment, particle, 1.0, inf': (125000.0,
#   3.6420115857881514,
#   500000.0),
#  'PVC, river sediment, film, 10.0, inf': (2500000.0,
#   3.6420115857881514,
#   5000000.0),
#  'PVC, river sediment, fiber, 10.0, inf': (1666666.6666666667,
#   3.6420115857881514,
#   5000000.0),
#  'PVC, river sediment, particle, 10.0, inf': (1250000.0,
#   3.6420115857881514,
#   5000000.0),
#  'PVC, soil, film, 0.1, inf': (25000.0, 3.6420115857881514, 50000.0),
#  'PVC, soil, fiber, 0.1, inf': (16666.666666666668,
#   3.6420115857881514,
#   50000.0),
#  'PVC, soil, particle, 0.1, inf': (12500.0, 3.6420115857881514, 50000.0),
#  'PVC, soil, film, 1.0, inf': (250000.0, 3.6420115857881514, 500000.0),
#  'PVC, soil, fiber, 1.0, inf': (166666.66666666666,
#   3.6420115857881514,
#   500000.0),
#  'PVC, soil, particle, 1.0, inf': (125000.0, 3.6420115857881514, 500000.0),
#  'PVC, soil, film, 10.0, inf': (2500000.0, 3.6420115857881514, 5000000.0),
#  'PVC, soil, fiber, 10.0, inf': (1666666.6666666667,
#   3.6420115857881514,
#   5000000.0),
#  'PVC, soil, particle, 10.0, inf': (1250000.0, 3.6420115857881514, 5000000.0),
#  'Starch-blend, marine sediment, film, 0.1, inf': (0.5849315068493148,
#   1.3866220474038289,
#   1.1698630136986297),
#  'Starch-blend, marine sediment, fiber, 0.1, inf': (0.3899543378995432,
#   1.3866220474038289,
#   1.1698630136986297),
#  'Starch-blend, marine sediment, particle, 0.1, inf': (0.2924657534246574,
#   1.3866220474038289,
#   1.1698630136986297),
#  'Starch-blend, marine sediment, film, 1.0, inf': (5.849315068493149,
#   1.3866220474038289,
#   11.698630136986298),
#  'Starch-blend, marine sediment, fiber, 1.0, inf': (3.8995433789954324,
#   1.3866220474038289,
#   11.698630136986298),
#  'Starch-blend, marine sediment, particle, 1.0, inf': (2.9246575342465744,
#   1.3866220474038289,
#   11.698630136986298),
#  'Starch-blend, marine sediment, film, 10.0, inf': (58.493150684931486,
#   1.3866220474038289,
#   116.98630136986297),
#  'Starch-blend, marine sediment, fiber, 10.0, inf': (38.995433789954326,
#   1.3866220474038289,
#   116.98630136986297),
#  'Starch-blend, marine sediment, particle, 10.0, inf': (29.246575342465743,
#   1.3866220474038289,
#   116.98630136986297),
#  'Starch-blend, marine water, film, 0.1, inf': (0.24681545033166494,
#   1.1567906541587107,
#   0.4936309006633299),
#  'Starch-blend, marine water, fiber, 0.1, inf': (0.1645436335544433,
#   1.1567906541587107,
#   0.4936309006633299),
#  'Starch-blend, marine water, particle, 0.1, inf': (0.12340772516583247,
#   1.1567906541587107,
#   0.4936309006633299),
#  'Starch-blend, marine water, film, 1.0, inf': (2.4681545033166494,
#   1.1567906541587107,
#   4.936309006633299),
#  'Starch-blend, marine water, fiber, 1.0, inf': (1.645436335544433,
#   1.1567906541587107,
#   4.936309006633299),
#  'Starch-blend, marine water, particle, 1.0, inf': (1.2340772516583247,
#   1.1567906541587107,
#   4.936309006633299),
#  'Starch-blend, marine water, film, 10.0, inf': (24.681545033166493,
#   1.1567906541587107,
#   49.36309006633299),
#  'Starch-blend, marine water, fiber, 10.0, inf': (16.45436335544433,
#   1.1567906541587107,
#   49.36309006633299),
#  'Starch-blend, marine water, particle, 10.0, inf': (12.340772516583247,
#   1.1567906541587107,
#   49.36309006633299),
#  'Starch-blend, river sediment, film, 0.1, inf': (0.5849315068493148,
#   1.3866220474038289,
#   1.1698630136986297),
#  'Starch-blend, river sediment, fiber, 0.1, inf': (0.3899543378995432,
#   1.3866220474038289,
#   1.1698630136986297),
#  'Starch-blend, river sediment, particle, 0.1, inf': (0.2924657534246574,
#   1.3866220474038289,
#   1.1698630136986297),
#  'Starch-blend, river sediment, film, 1.0, inf': (5.849315068493149,
#   1.3866220474038289,
#   11.698630136986298),
#  'Starch-blend, river sediment, fiber, 1.0, inf': (3.8995433789954324,
#   1.3866220474038289,
#   11.698630136986298),
#  'Starch-blend, river sediment, particle, 1.0, inf': (2.9246575342465744,
#   1.3866220474038289,
#   11.698630136986298),
#  'Starch-blend, river sediment, film, 10.0, inf': (58.493150684931486,
#   1.3866220474038289,
#   116.98630136986297),
#  'Starch-blend, river sediment, fiber, 10.0, inf': (38.995433789954326,
#   1.3866220474038289,
#   116.98630136986297),
#  'Starch-blend, river sediment, particle, 10.0, inf': (29.246575342465743,
#   1.3866220474038289,
#   116.98630136986297),
#  'Starch-blend, soil, film, 0.1, inf': (0.5849315068493148,
#   1.2675584838403926,
#   1.1698630136986297),
#  'Starch-blend, soil, fiber, 0.1, inf': (0.3899543378995432,
#   1.2675584838403926,
#   1.1698630136986297),
#  'Starch-blend, soil, particle, 0.1, inf': (0.2924657534246574,
#   1.2675584838403926,
#   1.1698630136986297),
#  'Starch-blend, soil, film, 1.0, inf': (5.849315068493149,
#   1.2675584838403926,
#   11.698630136986298),
#  'Starch-blend, soil, fiber, 1.0, inf': (3.8995433789954324,
#   1.2675584838403926,
#   11.698630136986298),
#  'Starch-blend, soil, particle, 1.0, inf': (2.9246575342465744,
#   1.2675584838403926,
#   11.698630136986298),
#  'Starch-blend, soil, film, 10.0, inf': (58.493150684931486,
#   1.2675584838403926,
#   116.98630136986297),
#  'Starch-blend, soil, fiber, 10.0, inf': (38.995433789954326,
#   1.2675584838403926,
#   116.98630136986297),
#  'Starch-blend, soil, particle, 10.0, inf': (29.246575342465743,
#   1.2675584838403926,
#   116.98630136986297)}

# %%
# building a dataframe (df_average_lifetime) based on the t_i_dict
df_average_lifetime = pd.DataFrame(t_i_dict).T
df_average_lifetime.reset_index(level=0, inplace=True)
cols = {'columns': {'index': 'Environmental_flow', 0: 'Average lifetime', 1: 'GSD', 2: 'Lifetime'}}
df_average_lifetime = df_average_lifetime.rename(**cols)

df_average_lifetime[['Polymer type', 'Compartment', 'Shape', 'Characteristic length',
                  'Time horizon']] = df_average_lifetime.Environmental_flow.str.split(', ', expand=True)
df_average_lifetime = df_average_lifetime[['Polymer type', 'Compartment',
                                     'Shape', 'Characteristic length', 'Time horizon', 'Average lifetime', 'GSD', 'Lifetime']]
df_average_lifetime['Characteristic length'] = df_average_lifetime['Characteristic length'].astype(
    float)
df_average_lifetime
# Out:
#      Polymer type      Compartment     Shape  Characteristic length  \
# 0            HDPE  marine sediment      film                    0.1
# 1            HDPE  marine sediment     fiber                    0.1
# 2            HDPE  marine sediment  particle                    0.1
# 3            HDPE  marine sediment      film                    1.0
# 4            HDPE  marine sediment     fiber                    1.0
# ..            ...              ...       ...                    ...
# 859  Starch-blend             soil     fiber                    1.0
# 860  Starch-blend             soil  particle                    1.0
# 861  Starch-blend             soil      film                   10.0
# 862  Starch-blend             soil     fiber                   10.0
# 863  Starch-blend             soil  particle                   10.0
#
#     Time horizon  Average lifetime       GSD    Lifetime
# 0            inf          2.136869  1.860703    4.273738
# 1            inf          1.424579  1.860703    4.273738
# 2            inf          1.068435  1.860703    4.273738
# 3            inf         21.368692  1.860703   42.737384
# 4            inf         14.245795  1.860703   42.737384
# ..           ...               ...       ...         ...
# 859          inf          3.899543  1.267558   11.698630
# 860          inf          2.924658  1.267558   11.698630
# 861          inf         58.493151  1.267558  116.986301
# 862          inf         38.995434  1.267558  116.986301
# 863          inf         29.246575  1.267558  116.986301
#
# [864 rows x 8 columns]

# %%
# Creating an excel file with the average lifetime and uncertainty based on df_average_lifetime
book = load_workbook(excel_name)
writer = pd.ExcelWriter(excel_name, engine='openpyxl')
writer.book = book
df_average_lifetime.to_excel(
    writer, sheet_name='Average_lifetime_with_Uncertainty', index=False)
writer.save()
# Out:
# C:\Users\thni\.conda\envs\py39\lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")

# %% [markdown]
# ## Retrieving the redistribution factors of plastic emissions

# %%
# reading excel file with name "Supplementary Material 2.xlsx" and sheet_name = 'DQ of transfer coefficients' for
# retrieving the data quality score for the redistribution factors and storing them in the dataframe df_redistribution
df_redistribution = pd.read_excel('Supplementary Material 2.xlsx', sheet_name='DQ of transfer coefficients', skiprows=16)
df_redistribution['Emission'] = df_redistribution['Emission'].fillna(
    method='ffill')
df_redistribution = df_redistribution.rename(columns={'Redistribution to …': 'Redistribution to soil', 'Unnamed: 4': 'Redistribution to marine water',
                                                      'Unnamed: 5': 'Redistribution to river sediment', 'Unnamed: 6': 'Redistribution to marine sediment'})
empty_rows = df_redistribution.loc[pd.isna(
    df_redistribution['Initial compartment']), :].index.tolist()
df_redistribution = df_redistribution.drop(empty_rows)
df_redistribution = df_redistribution[['Emission', 'Initial compartment', 'Redistribution to soil', 'Redistribution to marine water',
                                       'Redistribution to river sediment', 'Redistribution to marine sediment', 'Data quality expert judgment']]
df_redistribution['Initial compartment'] = df_redistribution['Initial compartment'].str.lower()
# calculation of the CV and GSD based on the defined functions
df_redistribution['CV'] = df_redistribution.apply(
    lambda row: CV_exp(float(row['Data quality expert judgment'])), axis=1)
df_redistribution['GSD'] = df_redistribution.apply(
    lambda row: GSD(float(row['CV'])), axis=1)

df_redistribution
# Out:
#                             Emission Initial compartment  \
# 1                             NR/SBR                soil
# 3                             NR/SBR         fresh water
# 5                             NR/SBR        marine water
# 7                             NR/SBR                 air
# 9   Polymers with a density ≥1 g/cm3                soil
# 11  Polymers with a density ≥1 g/cm3         fresh water
# 13  Polymers with a density ≥1 g/cm3        marine water
# 15  Polymers with a density ≥1 g/cm3                 air
# 17  Polymers with a density <1 g/cm3                soil
# 19  Polymers with a density <1 g/cm3         fresh water
# 21  Polymers with a density <1 g/cm3        marine water
# 23  Polymers with a density <1 g/cm3                 air
#
#    Redistribution to soil Redistribution to marine water  \
# 1                       1                              0
# 3                       0                              0
# 5                       0                              0
# 7                   0.948                              0
# 9                    0.97                              0
# 11                      0                              0
# 13                      0                              0
# 15                  0.948                              0
# 17                   0.97                           0.03
# 19                      0                              1
# 21                      0                              1
# 23                  0.948                          0.052
#
#    Redistribution to river sediment Redistribution to marine sediment  \
# 1                                 0                                 0
# 3                             0.889                             0.111
# 5                                 0                                 1
# 7                             0.047                             0.005
# 9                             0.027                             0.003
# 11                            0.889                             0.111
# 13                                0                                 1
# 15                            0.047                             0.005
# 17                                0                                 0
# 19                                0                                 0
# 21                                0                                 0
# 23                                0                                 0
#
#     Data quality expert judgment        CV       GSD
# 1                            2.0  0.227893  1.252341
# 3                            2.0  0.227893  1.252341
# 5                            2.0  0.227893  1.252341
# 7                            2.0  0.227893  1.252341
# 9                            2.0  0.227893  1.252341
# 11                           2.0  0.227893  1.252341
# 13                           2.0  0.227893  1.252341
# 15                           2.0  0.227893  1.252341
# 17                           2.0  0.227893  1.252341
# 19                           2.0  0.227893  1.252341
# 21                           2.0  0.227893  1.252341
# 23                           2.0  0.227893  1.252341

# %%
df_redistribution.loc[(df_redistribution['Emission'] == 'Polymers with a density <1 g/cm3') 
                                               & (df_redistribution['Initial compartment'] == 'soil'),
                      ['Redistribution to soil', 'Redistribution to marine water',
                       'Redistribution to river sediment', 'Redistribution to marine sediment']].to_numpy()[0][0]
# Out:
# 0.97

# %% [markdown]
# ## Calculation of plastic emissions fate factor

# %%
runs = 10000
ff_total_dict = {}
#defining list for low and high density polymers
low_density_poly = ['HDPE', 'LDPE', 'PE', 'PEA', 'PES', 'PP']
high_density_poly = ['PA', 'PBAT', 'PBS', 'PBSA', 'PBSe', 'PBSeT', 'PC', 'PCL', 'PET', 'PHA', 'PHB', 'PHBV', 'PLA(-blend)', 'PS', 'PU', 'PVC', 'Starch-blend']
#beginning of the fate factor calculation
for key, value in flows_dict.items():#getting items of the flows_dict as key and value as the basis
    #retrieving the compartment, average lifetime and GSD for the environmental flows
    t_i = df_average_lifetime.loc[(df_average_lifetime['Polymer type'] == value[0]) & (df_average_lifetime['Shape'] == value[1]) 
                     & (df_average_lifetime['Characteristic length'] == value[2]),
                        ['Compartment', 'Average lifetime', 'GSD', 'Lifetime']].to_numpy()
    #first case distinction for polymers which have a low density
    if value[0] in low_density_poly:
        #retrieving redistribution factors from data frame (df_redistribution)
        redistribution = df_redistribution.loc[(df_redistribution['Emission'] == 'Polymers with a density <1 g/cm3') 
                                               & (df_redistribution['Initial compartment'] == value[3]), 
                                               ['Redistribution to soil', 'Redistribution to marine water', 
                                                'Redistribution to river sediment', 'Redistribution to marine sediment', 
                                                'GSD']].to_numpy()
        #Running the Monte-Carlo simulation for each redistribtuion type excluding zero values
        if redistribution[0][0] != 0:
            rng = np.random.default_rng(seed=42)
            red_soil = rng.lognormal(math.log(redistribution[0][0]), math.log(redistribution[0][4]), runs)
        else:
            red_soil = 0
        if redistribution[0][1] != 0:
            rng = np.random.default_rng(seed=45)
            red_marine_water = rng.lognormal(math.log(redistribution[0][1]), math.log(redistribution[0][4]), runs)
        else:
            red_marine_water = 0
        if redistribution[0][2] != 0:
            rng = np.random.default_rng(seed=50)
            red_river_sediment = rng.lognormal(math.log(redistribution[0][2]), math.log(redistribution[0][4]), runs)
        else:
            red_river_sediment = 0
        if redistribution[0][3] != 0:
            rng = np.random.default_rng(seed=9)
            red_marine_sediment = rng.lognormal(math.log(redistribution[0][3]), math.log(redistribution[0][4]), runs)
        else:
            red_marine_sediment = 0
        #summing up the redistribution factors to a total value
        red_tot = red_soil + red_marine_water + red_river_sediment + red_marine_sediment
        #normalizing the redistribution factors as the sum should not be greater than 1 (percentages!)
        red_soil = red_soil/red_tot
        red_marine_water = red_marine_water/red_tot
        red_river_sediment = red_river_sediment/red_tot
        red_marine_sediment = red_marine_sediment/red_tot
        #Running the Monte-Carlo simulation for each average lifetime
        rng = np.random.default_rng(seed=5)
        t_i_marine_sediment = rng.lognormal(math.log(t_i[0][1]), math.log(t_i[0][2]), runs)
        t_i_marine_water = rng.lognormal(math.log(t_i[1][1]), math.log(t_i[1][2]), runs)
        t_i_river_sediment = rng.lognormal(math.log(t_i[2][1]), math.log(t_i[2][2]), runs)
        t_i_soil = rng.lognormal(math.log(t_i[3][1]), math.log(t_i[3][2]), runs)
        #calculating the fate factors for each compartment
        FF_marine_sediment = t_i_marine_sediment*red_marine_sediment
        FF_marine_water =  t_i_marine_water*red_marine_water
        FF_river_sediment =  t_i_river_sediment*red_river_sediment 
        FF_soil = t_i_soil*red_soil
        #calculating the total fate factors        
        FF_total = FF_marine_sediment + FF_marine_water + FF_river_sediment + FF_soil
        if np.sum(FF_marine_sediment) != 0:
            FF_marine_sediment = geometric_mean(FF_marine_sediment)
        else:
            FF_marine_sediment = 0
        if np.sum(FF_marine_water) != 0:
            FF_marine_water = geometric_mean(FF_marine_water)
        else:
            FF_marine_water = 0
        if np.sum(FF_river_sediment) != 0:
            FF_river_sediment = geometric_mean(FF_river_sediment)
        else:
            FF_river_sediment = 0
        if np.sum(FF_soil) != 0:
            FF_soil = geometric_mean(FF_soil)
        else:
            FF_soil = 0
        FF_total_sum = FF_marine_sediment + FF_marine_water + FF_river_sediment + FF_soil

        #creating a dictionary containing the geometric mean of each fate factors compartment and the GSD for the total fate factor
        flows_dict[key] = flows_dict[key] + (FF_marine_sediment,
                                             FF_marine_water,
                                             FF_river_sediment,
                                             FF_soil,
                                             FF_total_sum,
                                             scipy.stats.gstd(FF_total),
                                             t_i[0][3],
                                             t_i[1][3],
                                             t_i[2][3],
                                             t_i[3][3])
    #second case distinction for polymers which have a high density
    elif value[0] in high_density_poly:
        redistribution = df_redistribution.loc[(df_redistribution['Emission'] == 'Polymers with a density ≥1 g/cm3') 
                                               & (df_redistribution['Initial compartment'] == value[3]), 
                                               ['Redistribution to soil', 'Redistribution to marine water', 
                                                'Redistribution to river sediment', 'Redistribution to marine sediment', 
                                                'GSD']].to_numpy()
        
        if redistribution[0][0] != 0:
            rng = np.random.default_rng(seed=42)
            red_soil = rng.lognormal(math.log(redistribution[0][0]), math.log(redistribution[0][4]), runs)
        else:
            red_soil = 0
        if redistribution[0][1] != 0:
            rng = np.random.default_rng(seed=45)
            red_marine_water = rng.lognormal(math.log(redistribution[0][1]), math.log(redistribution[0][4]), runs)
        else:
            red_marine_water = 0
        if redistribution[0][2] != 0:
            rng = np.random.default_rng(seed=50)
            red_river_sediment = rng.lognormal(math.log(redistribution[0][2]), math.log(redistribution[0][4]), runs)
        else:
            red_river_sediment = 0
        if redistribution[0][3] != 0:
            rng = np.random.default_rng(seed=9)
            red_marine_sediment = rng.lognormal(math.log(redistribution[0][3]), math.log(redistribution[0][4]), runs)
        else:
            red_marine_sediment = 0
        red_tot = red_soil + red_marine_water + red_river_sediment + red_marine_sediment
        
        red_soil = red_soil/red_tot
        red_marine_water = red_marine_water/red_tot
        red_river_sediment = red_river_sediment/red_tot
        red_marine_sediment = red_marine_sediment/red_tot
        
        rng = np.random.default_rng(seed=5)
        t_i_marine_sediment = rng.lognormal(math.log(t_i[0][1]), math.log(t_i[0][2]), runs)
        t_i_marine_water = rng.lognormal(math.log(t_i[1][1]), math.log(t_i[1][2]), runs)
        t_i_river_sediment = rng.lognormal(math.log(t_i[2][1]), math.log(t_i[2][2]), runs)
        t_i_soil = rng.lognormal(math.log(t_i[3][1]), math.log(t_i[3][2]), runs)

        FF_marine_sediment = t_i_marine_sediment*red_marine_sediment
        FF_marine_water =  t_i_marine_water*red_marine_water
        FF_river_sediment =  t_i_river_sediment*red_river_sediment 
        FF_soil = t_i_soil*red_soil
        
        FF_total = FF_marine_sediment + FF_marine_water + FF_river_sediment + FF_soil
        if np.sum(FF_marine_sediment) != 0:
            FF_marine_sediment = geometric_mean(FF_marine_sediment)
        else:
            FF_marine_sediment = 0
        if np.sum(FF_marine_water) != 0:
            FF_marine_water = geometric_mean(FF_marine_water)
        else:
            FF_marine_water = 0
        if np.sum(FF_river_sediment) != 0:
            FF_river_sediment = geometric_mean(FF_river_sediment)
        else:
            FF_river_sediment = 0
        if np.sum(FF_soil) != 0:
            FF_soil = geometric_mean(FF_soil)
        else:
            FF_soil = 0
        FF_total_sum = FF_marine_sediment + FF_marine_water + FF_river_sediment + FF_soil
            
        flows_dict[key] = flows_dict[key] + (FF_marine_sediment,
                                             FF_marine_water,
                                             FF_river_sediment,
                                             FF_soil,
                                             FF_total_sum,
                                             scipy.stats.gstd(FF_total),
                                             t_i[0][3],
                                             t_i[1][3],
                                             t_i[2][3],
                                             t_i[3][3])
    #third case distinction for polymers which are rubbers
    else:
        redistribution = df_redistribution.loc[(df_redistribution['Emission'] == 'NR/SBR') 
                                               & (df_redistribution['Initial compartment'] == value[3]), 
                                               ['Redistribution to soil', 'Redistribution to marine water', 
                                                'Redistribution to river sediment', 'Redistribution to marine sediment', 
                                                'GSD']].to_numpy()
        if redistribution.size == 0:
            redistribution = np.array([[0, 0, 0, 1]])
        else:
            if redistribution[0][0] != 0:
                rng = np.random.default_rng(seed=42)
                red_soil = rng.lognormal(math.log(redistribution[0][0]), math.log(redistribution[0][4]), runs)
            else:
                red_soil = 0
            if redistribution[0][1] != 0:
                rng = np.random.default_rng(seed=45)
                red_marine_water = rng.lognormal(math.log(redistribution[0][1]), math.log(redistribution[0][4]), runs)
            else:
                red_marine_water = 0
            if redistribution[0][2] != 0:
                rng = np.random.default_rng(seed=50)
                red_river_sediment = rng.lognormal(math.log(redistribution[0][2]), math.log(redistribution[0][4]), runs)
            else:
                red_river_sediment = 0
            if redistribution[0][3] != 0:
                rng = np.random.default_rng(seed=9)
                red_marine_sediment = rng.lognormal(math.log(redistribution[0][3]), math.log(redistribution[0][4]), runs)
            else:
                red_marine_sediment = 0
            red_tot = red_soil + red_marine_water + red_river_sediment + red_marine_sediment

            red_soil = red_soil/red_tot
            red_marine_water = red_marine_water/red_tot
            red_river_sediment = red_river_sediment/red_tot
            red_marine_sediment = red_marine_sediment/red_tot
            
            rng = np.random.default_rng(seed=5)
            t_i_marine_sediment = rng.lognormal(math.log(t_i[0][1]), math.log(t_i[0][2]), runs)
            t_i_marine_water = rng.lognormal(math.log(t_i[1][1]), math.log(t_i[1][2]), runs)
            t_i_river_sediment = rng.lognormal(math.log(t_i[2][1]), math.log(t_i[2][2]), runs)
            t_i_soil = rng.lognormal(math.log(t_i[3][1]), math.log(t_i[3][2]), runs)

            FF_marine_sediment = t_i_marine_sediment*red_marine_sediment
            FF_marine_water =  t_i_marine_water*red_marine_water
            FF_river_sediment =  t_i_river_sediment*red_river_sediment 
            FF_soil = t_i_soil*red_soil

            FF_total = FF_marine_sediment + FF_marine_water + FF_river_sediment + FF_soil
            if np.sum(FF_marine_sediment) != 0:
                FF_marine_sediment = geometric_mean(FF_marine_sediment)
            else:
                FF_marine_sediment = 0
            if np.sum(FF_marine_water) != 0:
                FF_marine_water = geometric_mean(FF_marine_water)
            else:
                FF_marine_water = 0
            if np.sum(FF_river_sediment) != 0:
                FF_river_sediment = geometric_mean(FF_river_sediment)
            else:
                FF_river_sediment = 0
            if np.sum(FF_soil) != 0:
                FF_soil = geometric_mean(FF_soil)
            else:
                FF_soil = 0
            FF_total_sum = FF_marine_sediment + FF_marine_water + FF_river_sediment + FF_soil

            flows_dict[key] = flows_dict[key] + (FF_marine_sediment,
                                                 FF_marine_water,
                                                 FF_river_sediment,
                                                 FF_soil,
                                                 FF_total_sum,
                                                 scipy.stats.gstd(FF_total),
                                                 t_i[0][3],
                                                 t_i[1][3],
                                                 t_i[2][3],
                                                 t_i[3][3])

# %%
df_FF = pd.DataFrame.from_dict(flows_dict, orient='index')
df_FF.reset_index(level=0, inplace=True)
cols = {'columns': {'index': 'Environmental_flow', 0: 'Polymer type', 1: 'Shape', 2: 'Length', 3: 'Compartment',
                    4: 'FF_marine_sediment', 5: 'FF_marine_water',
                    6: 'FF_river_sediment', 7: 'FF_soil', 8: 'FF_total', 9: 'GSD',
                    10: 'Lifetime_marine_sediment', 11: 'Lifetime_marine_water',
                    12: 'Lifetime_river_sediment', 13: 'Lifetime_soil'}}
df_FF = df_FF.rename(**cols)
df_FF
# Out:
#                                     Environmental_flow  Polymer type  \
# 0              HDPE film 0.01-0.1 mm (emission to air)          HDPE
# 1      HDPE film 0.01-0.1 mm (emission to fresh water)          HDPE
# 2     HDPE film 0.01-0.1 mm (emission to marine water)          HDPE
# 3             HDPE film 0.01-0.1 mm (emission to soil)          HDPE
# 4                 HDPE film 0.1-1 mm (emission to air)          HDPE
# ..                                                 ...           ...
# 859  Starch-blend particle 0.1-1 mm (emission to soil)  Starch-blend
# 860    Starch-blend particle 1-10 mm (emission to air)  Starch-blend
# 861  Starch-blend particle 1-10 mm (emission to fre...  Starch-blend
# 862  Starch-blend particle 1-10 mm (emission to mar...  Starch-blend
# 863   Starch-blend particle 1-10 mm (emission to soil)  Starch-blend
#
#         Shape  Length   Compartment  FF_marine_sediment  FF_marine_water  \
# 0        film     0.1           air            0.000000         0.111558
# 1        film     0.1   fresh water            0.000000         2.145031
# 2        film     0.1  marine water            0.000000         2.145031
# 3        film     0.1          soil            0.000000         0.064432
# 4        film     1.0           air            0.000000         1.115576
# ..        ...     ...           ...                 ...              ...
# 859  particle     1.0          soil            0.008855         0.000000
# 860  particle    10.0           air            0.147421         0.000000
# 861  particle    10.0   fresh water            3.258542         0.000000
# 862  particle    10.0  marine water           29.453380         0.000000
# 863  particle    10.0          soil            0.088550         0.000000
#
#      FF_river_sediment    FF_soil   FF_total       GSD  \
# 0             0.000000   2.030544   2.142101  1.783331
# 1             0.000000   0.000000   2.145031  1.792868
# 2             0.000000   0.000000   2.145031  1.792868
# 3             0.000000   2.079991   2.144423  1.812068
# 4             0.000000  20.305437  21.421013  1.783331
# ..                 ...        ...        ...       ...
# 859           0.078905   2.837959   2.925719  1.257224
# 860           1.372026  27.705542  29.224989  1.250641
# 861          25.839069   0.000000  29.097611  1.332288
# 862           0.000000   0.000000  29.453380  1.389288
# 863           0.789049  28.379589  29.257189  1.257224
#
#      Lifetime_marine_sediment  Lifetime_marine_water  Lifetime_river_sediment  \
# 0                    4.273738               4.273738                 4.273738
# 1                    4.273738               4.273738                 4.273738
# 2                    4.273738               4.273738                 4.273738
# 3                    4.273738               4.273738                 4.273738
# 4                   42.737384              42.737384                42.737384
# ..                        ...                    ...                      ...
# 859                 11.698630               4.936309                11.698630
# 860                116.986301              49.363090               116.986301
# 861                116.986301              49.363090               116.986301
# 862                116.986301              49.363090               116.986301
# 863                116.986301              49.363090               116.986301
#
#      Lifetime_soil
# 0         4.273738
# 1         4.273738
# 2         4.273738
# 3         4.273738
# 4        42.737384
# ..             ...
# 859      11.698630
# 860     116.986301
# 861     116.986301
# 862     116.986301
# 863     116.986301
#
# [864 rows x 15 columns]

# %%
df_FF['Time horizon'] = 'inf'
df_FF = df_FF.append(df_FF.iloc[0:864])
df_FF = df_FF.append(df_FF.iloc[0:864])
df_FF = df_FF.append(df_FF.iloc[0:864])
df_FF.iloc[864:2*864+1, 15] = 100
df_FF.iloc[2*864:3*864+1, 15] = 500
df_FF.iloc[3*864:4*864+1, 15] = 1000

df_FF
# Out:
#                                     Environmental_flow  Polymer type  \
# 0              HDPE film 0.01-0.1 mm (emission to air)          HDPE
# 1      HDPE film 0.01-0.1 mm (emission to fresh water)          HDPE
# 2     HDPE film 0.01-0.1 mm (emission to marine water)          HDPE
# 3             HDPE film 0.01-0.1 mm (emission to soil)          HDPE
# 4                 HDPE film 0.1-1 mm (emission to air)          HDPE
# ..                                                 ...           ...
# 859  Starch-blend particle 0.1-1 mm (emission to soil)  Starch-blend
# 860    Starch-blend particle 1-10 mm (emission to air)  Starch-blend
# 861  Starch-blend particle 1-10 mm (emission to fre...  Starch-blend
# 862  Starch-blend particle 1-10 mm (emission to mar...  Starch-blend
# 863   Starch-blend particle 1-10 mm (emission to soil)  Starch-blend
#
#         Shape  Length   Compartment  FF_marine_sediment  FF_marine_water  \
# 0        film     0.1           air            0.000000         0.111558
# 1        film     0.1   fresh water            0.000000         2.145031
# 2        film     0.1  marine water            0.000000         2.145031
# 3        film     0.1          soil            0.000000         0.064432
# 4        film     1.0           air            0.000000         1.115576
# ..        ...     ...           ...                 ...              ...
# 859  particle     1.0          soil            0.008855         0.000000
# 860  particle    10.0           air            0.147421         0.000000
# 861  particle    10.0   fresh water            3.258542         0.000000
# 862  particle    10.0  marine water           29.453380         0.000000
# 863  particle    10.0          soil            0.088550         0.000000
#
#      FF_river_sediment    FF_soil   FF_total       GSD  \
# 0             0.000000   2.030544   2.142101  1.783331
# 1             0.000000   0.000000   2.145031  1.792868
# 2             0.000000   0.000000   2.145031  1.792868
# 3             0.000000   2.079991   2.144423  1.812068
# 4             0.000000  20.305437  21.421013  1.783331
# ..                 ...        ...        ...       ...
# 859           0.078905   2.837959   2.925719  1.257224
# 860           1.372026  27.705542  29.224989  1.250641
# 861          25.839069   0.000000  29.097611  1.332288
# 862           0.000000   0.000000  29.453380  1.389288
# 863           0.789049  28.379589  29.257189  1.257224
#
#      Lifetime_marine_sediment  Lifetime_marine_water  Lifetime_river_sediment  \
# 0                    4.273738               4.273738                 4.273738
# 1                    4.273738               4.273738                 4.273738
# 2                    4.273738               4.273738                 4.273738
# 3                    4.273738               4.273738                 4.273738
# 4                   42.737384              42.737384                42.737384
# ..                        ...                    ...                      ...
# 859                 11.698630               4.936309                11.698630
# 860                116.986301              49.363090               116.986301
# 861                116.986301              49.363090               116.986301
# 862                116.986301              49.363090               116.986301
# 863                116.986301              49.363090               116.986301
#
#      Lifetime_soil Time horizon
# 0         4.273738          inf
# 1         4.273738          inf
# 2         4.273738          inf
# 3         4.273738          inf
# 4        42.737384          inf
# ..             ...          ...
# 859      11.698630         1000
# 860     116.986301         1000
# 861     116.986301         1000
# 862     116.986301         1000
# 863     116.986301         1000
#
# [3456 rows x 16 columns]

# %%
def FF_time(shape, time_horizon, lifetime, FF, poly, init_comp, comp):
    if time_horizon == 'inf' or time_horizon > lifetime:
        return FF 
    else:
        time_horizon = int(time_horizon)
        if shape == 'film':
            a = 1
        elif shape == 'fiber':
            a = 2
        elif shape == 'particle':
            a = 3
        if poly in low_density_poly:
            red = df_redistribution.loc[(df_redistribution['Emission'] == 'Polymers with a density <1 g/cm3') 
                                           & (df_redistribution['Initial compartment'] == init_comp), 
                                           ['Redistribution to soil', 'Redistribution to marine water', 
                                            'Redistribution to river sediment', 'Redistribution to marine sediment']].to_numpy()
            if comp == 'marine_sediment':
                red = red[0][3]                    
            elif comp == 'marine_water':
                red = red[0][1]                    
            elif comp == 'river_sediment':
                red = red[0][2]
            elif comp == 'soil':
                red = red[0][0]
            return ((lifetime/(a+1)) * (1-((1-(time_horizon/lifetime))**(a+1))))*red    
        elif poly in high_density_poly:
            red = df_redistribution.loc[(df_redistribution['Emission'] == 'Polymers with a density ≥1 g/cm3') 
                                           & (df_redistribution['Initial compartment'] == init_comp), 
                                           ['Redistribution to soil', 'Redistribution to marine water', 
                                            'Redistribution to river sediment', 'Redistribution to marine sediment']].to_numpy()
            if comp == 'marine_sediment':
                red = red[0][3]                    
            elif comp == 'marine_water':
                red = red[0][1]                    
            elif comp == 'river_sediment':
                red = red[0][2]
            elif comp == 'soil':
                red = red[0][0]
            return ((lifetime/(a+1)) * (1-((1-(time_horizon/lifetime))**(a+1))))*red
        else:
            red = df_redistribution.loc[(df_redistribution['Emission'] == 'NR/SBR') 
                                           & (df_redistribution['Initial compartment'] == init_comp), 
                                           ['Redistribution to soil', 'Redistribution to marine water', 
                                            'Redistribution to river sediment', 'Redistribution to marine sediment']].to_numpy()
            if comp == 'marine_sediment':
                red = red[0][3]                    
            elif comp == 'marine_water':
                red = red[0][1]                    
            elif comp == 'river_sediment':
                red = red[0][2]
            elif comp == 'soil':
                red = red[0][0]
            return ((lifetime/(a+1)) * (1-((1-(time_horizon/lifetime))**(a+1))))*red

# %%
def FF_total(FF_marine_sediment, FF_marine_water, FF_river_sediment, FF_soil, time_horizon, FF):
    if time_horizon == 'inf':
        return FF
    else:
        return FF_marine_sediment + FF_marine_water + FF_river_sediment + FF_soil

# %%
df_FF['FF_marine_sediment'] = df_FF.apply(lambda row : FF_time(row['Shape'], row['Time horizon'], row['Lifetime_marine_sediment'], row['FF_marine_sediment'], row['Polymer type'], row['Compartment'], 'marine_sediment'), axis = 1)
df_FF['FF_marine_water'] = df_FF.apply(lambda row : FF_time(row['Shape'], row['Time horizon'], row['Lifetime_marine_water'], row['FF_marine_water'], row['Polymer type'], row['Compartment'], 'marine_water'), axis = 1)
df_FF['FF_river_sediment'] = df_FF.apply(lambda row : FF_time(row['Shape'], row['Time horizon'], row['Lifetime_river_sediment'], row['FF_river_sediment'], row['Polymer type'], row['Compartment'], 'river_sediment'), axis = 1)
df_FF['FF_soil'] = df_FF.apply(lambda row : FF_time(row['Shape'], row['Time horizon'], row['Lifetime_soil'], row['FF_soil'], row['Polymer type'], row['Compartment'], 'soil'), axis = 1)
df_FF['FF_total'] = df_FF.apply(lambda row : FF_total(row['FF_marine_sediment'], row['FF_marine_water'], row['FF_river_sediment'], row['FF_soil'], row['Time horizon'], row['FF_total']), axis = 1)
df_FF
# Out:
#                                     Environmental_flow  Polymer type  \
# 0              HDPE film 0.01-0.1 mm (emission to air)          HDPE
# 1      HDPE film 0.01-0.1 mm (emission to fresh water)          HDPE
# 2     HDPE film 0.01-0.1 mm (emission to marine water)          HDPE
# 3             HDPE film 0.01-0.1 mm (emission to soil)          HDPE
# 4                 HDPE film 0.1-1 mm (emission to air)          HDPE
# ..                                                 ...           ...
# 859  Starch-blend particle 0.1-1 mm (emission to soil)  Starch-blend
# 860    Starch-blend particle 1-10 mm (emission to air)  Starch-blend
# 861  Starch-blend particle 1-10 mm (emission to fre...  Starch-blend
# 862  Starch-blend particle 1-10 mm (emission to mar...  Starch-blend
# 863   Starch-blend particle 1-10 mm (emission to soil)  Starch-blend
#
#         Shape  Length   Compartment  FF_marine_sediment  FF_marine_water  \
# 0        film     0.1           air            0.000000         0.111558
# 1        film     0.1   fresh water            0.000000         2.145031
# 2        film     0.1  marine water            0.000000         2.145031
# 3        film     0.1          soil            0.000000         0.064432
# 4        film     1.0           air            0.000000         1.115576
# ..        ...     ...           ...                 ...              ...
# 859  particle     1.0          soil            0.008855         0.000000
# 860  particle    10.0           air            0.147421         0.000000
# 861  particle    10.0   fresh water            3.258542         0.000000
# 862  particle    10.0  marine water           29.453380         0.000000
# 863  particle    10.0          soil            0.088550         0.000000
#
#      FF_river_sediment    FF_soil   FF_total       GSD  \
# 0             0.000000   2.030544   2.142101  1.783331
# 1             0.000000   0.000000   2.145031  1.792868
# 2             0.000000   0.000000   2.145031  1.792868
# 3             0.000000   2.079991   2.144423  1.812068
# 4             0.000000  20.305437  21.421013  1.783331
# ..                 ...        ...        ...       ...
# 859           0.078905   2.837959   2.925719  1.257224
# 860           1.372026  27.705542  29.224989  1.250641
# 861          25.839069   0.000000  29.097611  1.332288
# 862           0.000000   0.000000  29.453380  1.389288
# 863           0.789049  28.379589  29.257189  1.257224
#
#      Lifetime_marine_sediment  Lifetime_marine_water  Lifetime_river_sediment  \
# 0                    4.273738               4.273738                 4.273738
# 1                    4.273738               4.273738                 4.273738
# 2                    4.273738               4.273738                 4.273738
# 3                    4.273738               4.273738                 4.273738
# 4                   42.737384              42.737384                42.737384
# ..                        ...                    ...                      ...
# 859                 11.698630               4.936309                11.698630
# 860                116.986301              49.363090               116.986301
# 861                116.986301              49.363090               116.986301
# 862                116.986301              49.363090               116.986301
# 863                116.986301              49.363090               116.986301
#
#      Lifetime_soil Time horizon
# 0         4.273738          inf
# 1         4.273738          inf
# 2         4.273738          inf
# 3         4.273738          inf
# 4        42.737384          inf
# ..             ...          ...
# 859      11.698630         1000
# 860     116.986301         1000
# 861     116.986301         1000
# 862     116.986301         1000
# 863     116.986301         1000
#
# [3456 rows x 16 columns]

# %%
df_FF = df_FF[['Environmental_flow', 'Time horizon', 'FF_marine_sediment', 'FF_marine_water', 'FF_river_sediment', 'FF_soil', 'FF_total', 'GSD']]
df_FF = df_FF.sort_values(by=['Environmental_flow', 'Time horizon'])
df_FF
# Out:
#                                     Environmental_flow Time horizon  \
# 12            HDPE fiber 0.01-0.1 mm (emission to air)          100
# 12            HDPE fiber 0.01-0.1 mm (emission to air)          500
# 12            HDPE fiber 0.01-0.1 mm (emission to air)         1000
# 12            HDPE fiber 0.01-0.1 mm (emission to air)          inf
# 13    HDPE fiber 0.01-0.1 mm (emission to fresh water)          100
# ..                                                 ...          ...
# 862  Starch-blend particle 1-10 mm (emission to mar...          inf
# 863   Starch-blend particle 1-10 mm (emission to soil)          100
# 863   Starch-blend particle 1-10 mm (emission to soil)          500
# 863   Starch-blend particle 1-10 mm (emission to soil)         1000
# 863   Starch-blend particle 1-10 mm (emission to soil)          inf
#
#      FF_marine_sediment  FF_marine_water  FF_river_sediment    FF_soil  \
# 12             0.000000         0.074372           0.000000   1.353696
# 12             0.000000         0.074372           0.000000   1.353696
# 12             0.000000         0.074372           0.000000   1.353696
# 12             0.000000         0.074372           0.000000   1.353696
# 13             0.000000         1.430020           0.000000   0.000000
# ..                  ...              ...                ...        ...
# 862           29.453380         0.000000           0.000000   0.000000
# 863            0.087701         0.000000           0.789307  28.356568
# 863            0.088550         0.000000           0.789049  28.379589
# 863            0.088550         0.000000           0.789049  28.379589
# 863            0.088550         0.000000           0.789049  28.379589
#
#       FF_total       GSD
# 12    1.428068  1.783331
# 12    1.428068  1.783331
# 12    1.428068  1.783331
# 12    1.428068  1.783331
# 13    1.430020  1.792868
# ..         ...       ...
# 862  29.453380  1.389288
# 863  29.233576  1.257224
# 863  29.257189  1.257224
# 863  29.257189  1.257224
# 863  29.257189  1.257224
#
# [3456 rows x 8 columns]

# %%
# creation of excel file consisting of enviornmental flows and fate factors
book = load_workbook(excel_name)
writer = pd.ExcelWriter(excel_name, engine='openpyxl')
writer.book = book
df_FF.to_excel(writer, sheet_name='FF_with_uncertainty', index=False)
writer.save()
# Out:
# C:\Users\thni\.conda\envs\py39\lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")

# %%
df_FF_reduced = df_FF[['Environmental_flow', 'Time horizon',
                       'FF_marine_sediment', 'FF_marine_water', 'FF_river_sediment', 'FF_soil']]
df_FF_reduced['Polymer_type'] = df_FF_reduced.Environmental_flow.apply(
    lambda x: x.split()[0])
df_FF_reduced['Shape'] = df_FF_reduced.Environmental_flow.apply(
    lambda x: x.split()[1])
df_FF_reduced['Characteristic_length'] = df_FF_reduced.Environmental_flow.apply(
    lambda x: x.split()[2] + ' ' + x.split()[3])
df_FF_reduced['Initial_compartment'] = df_FF_reduced.Environmental_flow.apply(lambda x: x.split(
)[4].replace('(', '').capitalize() + ' ' + x.split()[5] + ' ' + x.split()[6].replace(')', ''))
df_FF_reduced.loc[(df_FF_reduced.Initial_compartment == 'Emission to fresh'),
                  'Initial_compartment'] = 'Emission to fresh water'
df_FF_reduced.loc[(df_FF_reduced.Initial_compartment == 'Emission to marine'),
                  'Initial_compartment'] = 'Emission to marine water'
df_FF_reduced
# Out:
# <ipython-input-28-f444301cdb69>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_FF_reduced['Polymer_type'] = df_FF_reduced.Environmental_flow.apply(
#                                     Environmental_flow Time horizon  \
# 12            HDPE fiber 0.01-0.1 mm (emission to air)          100
# 12            HDPE fiber 0.01-0.1 mm (emission to air)          500
# 12            HDPE fiber 0.01-0.1 mm (emission to air)         1000
# 12            HDPE fiber 0.01-0.1 mm (emission to air)          inf
# 13    HDPE fiber 0.01-0.1 mm (emission to fresh water)          100
# ..                                                 ...          ...
# 862  Starch-blend particle 1-10 mm (emission to mar...          inf
# 863   Starch-blend particle 1-10 mm (emission to soil)          100
# 863   Starch-blend particle 1-10 mm (emission to soil)          500
# 863   Starch-blend particle 1-10 mm (emission to soil)         1000
# 863   Starch-blend particle 1-10 mm (emission to soil)          inf
#
#      FF_marine_sediment  FF_marine_water  FF_river_sediment    FF_soil  \
# 12             0.000000         0.074372           0.000000   1.353696
# 12             0.000000         0.074372           0.000000   1.353696
# 12             0.000000         0.074372           0.000000   1.353696
# 12             0.000000         0.074372           0.000000   1.353696
# 13             0.000000         1.430020           0.000000   0.000000
# ..                  ...              ...                ...        ...
# 862           29.453380         0.000000           0.000000   0.000000
# 863            0.087701         0.000000           0.789307  28.356568
# 863            0.088550         0.000000           0.789049  28.379589
# 863            0.088550         0.000000           0.789049  28.379589
# 863            0.088550         0.000000           0.789049  28.379589
#
#      Polymer_type     Shape Characteristic_length       Initial_compartment
# 12           HDPE     fiber           0.01-0.1 mm           Emission to air
# 12           HDPE     fiber           0.01-0.1 mm           Emission to air
# 12           HDPE     fiber           0.01-0.1 mm           Emission to air
# 12           HDPE     fiber           0.01-0.1 mm           Emission to air
# 13           HDPE     fiber           0.01-0.1 mm   Emission to fresh water
# ..            ...       ...                   ...                       ...
# 862  Starch-blend  particle               1-10 mm  Emission to marine water
# 863  Starch-blend  particle               1-10 mm          Emission to soil
# 863  Starch-blend  particle               1-10 mm          Emission to soil
# 863  Starch-blend  particle               1-10 mm          Emission to soil
# 863  Starch-blend  particle               1-10 mm          Emission to soil
#
# [3456 rows x 10 columns]

# %%
df_FF_reduced[['FF_marine_sediment', 'FF_marine_water', 'FF_river_sediment', 'FF_soil']] = df_FF_reduced[[
    'FF_marine_sediment', 'FF_marine_water', 'FF_river_sediment', 'FF_soil']].apply(lambda x: x*100/sum(x), axis=1)

df_FF_reduced_limited = df_FF_reduced.loc[(df_FF_reduced['Characteristic_length'] == '0.01-0.1 mm') & (df_FF_reduced['Shape'] == 'particle') & (
    df_FF_reduced['Time horizon'] == 'inf'), ['Environmental_flow', 'FF_marine_sediment', 'FF_marine_water', 'FF_river_sediment', 'FF_soil', 'Polymer_type', 'Initial_compartment']]
df_FF_reduced_limited.set_index('Environmental_flow', inplace=True)
df_FF_reduced_limited.plot(kind="bar", stacked=True, figsize=(40, 10))
# Out:
# <AxesSubplot:xlabel='Environmental_flow'>

# %%
df_FF_reduced_limited
# Out:
#                                                     FF_marine_sediment  \
# Environmental_flow
# HDPE particle 0.01-0.1 mm (emission to air)                   0.000000
# HDPE particle 0.01-0.1 mm (emission to fresh wa...            0.000000
# HDPE particle 0.01-0.1 mm (emission to marine w...            0.000000
# HDPE particle 0.01-0.1 mm (emission to soil)                  0.000000
# LDPE particle 0.01-0.1 mm (emission to air)                   0.000000
# ...                                                                ...
# PVC particle 0.01-0.1 mm (emission to soil)                   0.306439
# Starch-blend particle 0.01-0.1 mm (emission to ...            0.504435
# Starch-blend particle 0.01-0.1 mm (emission to ...           11.198659
# Starch-blend particle 0.01-0.1 mm (emission to ...          100.000000
# Starch-blend particle 0.01-0.1 mm (emission to ...            0.302660
#
#                                                     FF_marine_water  \
# Environmental_flow
# HDPE particle 0.01-0.1 mm (emission to air)                5.207856
# HDPE particle 0.01-0.1 mm (emission to fresh wa...       100.000000
# HDPE particle 0.01-0.1 mm (emission to marine w...       100.000000
# HDPE particle 0.01-0.1 mm (emission to soil)               3.004638
# LDPE particle 0.01-0.1 mm (emission to air)                5.208708
# ...                                                             ...
# PVC particle 0.01-0.1 mm (emission to soil)                0.000000
# Starch-blend particle 0.01-0.1 mm (emission to ...         0.000000
# Starch-blend particle 0.01-0.1 mm (emission to ...         0.000000
# Starch-blend particle 0.01-0.1 mm (emission to ...         0.000000
# Starch-blend particle 0.01-0.1 mm (emission to ...         0.000000
#
#                                                     FF_river_sediment  \
# Environmental_flow
# HDPE particle 0.01-0.1 mm (emission to air)                  0.000000
# HDPE particle 0.01-0.1 mm (emission to fresh wa...           0.000000
# HDPE particle 0.01-0.1 mm (emission to marine w...           0.000000
# HDPE particle 0.01-0.1 mm (emission to soil)                 0.000000
# LDPE particle 0.01-0.1 mm (emission to air)                  0.000000
# ...                                                               ...
# PVC particle 0.01-0.1 mm (emission to soil)                  2.667464
# Starch-blend particle 0.01-0.1 mm (emission to ...           4.694700
# Starch-blend particle 0.01-0.1 mm (emission to ...          88.801341
# Starch-blend particle 0.01-0.1 mm (emission to ...           0.000000
# Starch-blend particle 0.01-0.1 mm (emission to ...           2.696942
#
#                                                       FF_soil  Polymer_type  \
# Environmental_flow
# HDPE particle 0.01-0.1 mm (emission to air)         94.792144          HDPE
# HDPE particle 0.01-0.1 mm (emission to fresh wa...   0.000000          HDPE
# HDPE particle 0.01-0.1 mm (emission to marine w...   0.000000          HDPE
# HDPE particle 0.01-0.1 mm (emission to soil)        96.995362          HDPE
# LDPE particle 0.01-0.1 mm (emission to air)         94.791292          LDPE
# ...                                                       ...           ...
# PVC particle 0.01-0.1 mm (emission to soil)         97.026097           PVC
# Starch-blend particle 0.01-0.1 mm (emission to ...  94.800865  Starch-blend
# Starch-blend particle 0.01-0.1 mm (emission to ...   0.000000  Starch-blend
# Starch-blend particle 0.01-0.1 mm (emission to ...   0.000000  Starch-blend
# Starch-blend particle 0.01-0.1 mm (emission to ...  97.000399  Starch-blend
#
#                                                          Initial_compartment
# Environmental_flow
# HDPE particle 0.01-0.1 mm (emission to air)                  Emission to air
# HDPE particle 0.01-0.1 mm (emission to fresh wa...   Emission to fresh water
# HDPE particle 0.01-0.1 mm (emission to marine w...  Emission to marine water
# HDPE particle 0.01-0.1 mm (emission to soil)                Emission to soil
# LDPE particle 0.01-0.1 mm (emission to air)                  Emission to air
# ...                                                                      ...
# PVC particle 0.01-0.1 mm (emission to soil)                 Emission to soil
# Starch-blend particle 0.01-0.1 mm (emission to ...           Emission to air
# Starch-blend particle 0.01-0.1 mm (emission to ...   Emission to fresh water
# Starch-blend particle 0.01-0.1 mm (emission to ...  Emission to marine water
# Starch-blend particle 0.01-0.1 mm (emission to ...          Emission to soil
#
# [96 rows x 6 columns]

# %%
groups = df_FF_reduced_limited.Polymer_type.unique()
comp = df_FF_reduced_limited.Initial_compartment.unique()

sns.set_style("dark")
# plt.ylabel('Compartments')
fig, ax = plt.subplots(len(groups), sharex=True)

for i, Polymer_type in enumerate(groups):
    ax[i].title.set_text(Polymer_type)
    ax[i].set_xlim(0, 100)
    #ax[i].set_yticks(np.arange(0,len(comp)), comp)
    #ax[i].set_yticks(['Emission to air', 'Emission to fresh', 'Emission to marine', 'Emission to soil'])
    df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == Polymer_type].plot(
        kind='barh', rot=0, ax=ax[i], stacked=True, figsize=(20, 40), fontsize=10, legend=False)

lines, labels = fig.axes[-1].get_legend_handles_labels()
#fig.legend(lines, labels)
fig.legend(lines, labels, bbox_to_anchor=(
    [0.58, 1, 0, 0]), ncol=4, frameon=False)
plt.setp(ax[:], ylabel=None)
plt.savefig('boxplot_cat.png', dpi=300)

# %%
plt.style.use('seaborn')
fig = plt.figure(figsize=(30,40))
G = gridspec.GridSpec(7, 36)
plt.rc('font', size=15)
color = ['#dfc27d', '#018571', '#80cdc1', '#a6611a']
#axes_1 = HDPE
axes_1 = plt.subplot(G[0, 0:8])
axes_1.title.set_text('HDPE')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'HDPE'].plot(kind='barh', rot=0, ax=axes_1, stacked=True,
                                                                         legend = False, color=color)
axes_1.set_yticklabels(comp)
axes_1.set_ylabel((None))
axes_1.set_xlim(0,100)
axes_1.set_ylabel(('Polymers with a density ≤ 1 g/$cm^{3}$\n and equal SSDRs'))
#axes_2 = LDPE
axes_2 = plt.subplot(G[0, 9:17])
axes_2.title.set_text('LDPE')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'LDPE'].plot(kind='barh', rot=0, ax=axes_2, stacked=True,
                                                                         legend = False, color=color)
axes_2.set_ylabel((None))
axes_2.set_xlim(0,100)
plt.setp(axes_2.get_yticklabels(), visible=False)
#axes_3 = PEA
axes_3 = plt.subplot(G[0, 18:26])
axes_3.title.set_text('PEA')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'PEA'].plot(kind='barh', rot=0, ax=axes_3, stacked=True,
                                                                        legend = False, color=color)
axes_3.set_ylabel((None))
axes_3.set_xlim(0,100)
plt.setp(axes_3.get_yticklabels(), visible=False)
#axes_4 = PES
axes_4 = plt.subplot(G[0, 27:36])
axes_4.title.set_text('PES')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'PES'].plot(kind='barh', rot=0, ax=axes_4, stacked=True,
                                                                        legend = False, color=color)
axes_4.set_ylabel((None))
axes_4.set_xlim(0,100)
plt.setp(axes_4.get_yticklabels(), visible=False)
#axes_5 = PE
axes_5 = plt.subplot(G[1, :])
axes_5.title.set_text('PE')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'PE'].plot(kind='barh', rot=0, ax=axes_5, stacked=True,
                                                                       legend = False, color=color)
axes_5.set_yticklabels(comp)
axes_5.set_ylabel((None))
axes_5.set_xlim(0,100)
axes_5.set_ylabel(('Polymers with a density ≤ 1 g/$cm^{3}$\n and low SSDR in marine water'))
#axes_6 = PP
axes_6 = plt.subplot(G[2, :])
axes_6.title.set_text('PP')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'PP'].plot(kind='barh', rot=0, ax=axes_6, stacked=True,
                                                                       legend = False, color=color)
axes_6.set_yticklabels(comp)
axes_6.set_ylabel((None))
axes_6.set_xlim(0,100)
axes_6.set_ylabel(('Polymers with a density ≤ 1 g/$cm^{3}$\n and low SSDR in soil'))
#axes_7 = NR/SBR
axes_7 = plt.subplot(G[3, 0:4])
axes_7.title.set_text('NR/SBR')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'NR/SBR'].plot(kind='barh', rot=0, ax=axes_7, stacked=True,
                                                                           legend = False, color=color)
axes_7.set_yticklabels(comp)
axes_7.set_ylabel((None))
axes_7.set_xlim(0,100)
axes_7.set_ylabel('Polymers with a density ≥ 1 g/$cm^{3}$\n', y=0)
#axes_8 = PA
axes_8 = plt.subplot(G[3, 5:9])
axes_8.title.set_text('PA')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'PA'].plot(kind='barh', rot=0, ax=axes_8, stacked=True,
                                                                       legend = False, color=color)
axes_8.set_ylabel((None))
axes_8.set_xlim(0,100)
plt.setp(axes_8.get_yticklabels(), visible=False)
#axes_9 = PBAT
axes_9 = plt.subplot(G[3, 11:15])
axes_9.title.set_text('PBAT')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'PBAT'].plot(kind='barh', rot=0, ax=axes_9, stacked=True,
                                                                         legend = False, color=color)
axes_9.set_ylabel((None))
axes_9.set_xlim(0,100)
plt.setp(axes_9.get_yticklabels(), visible=False)
#axes_10 = PBSA
axes_10 = plt.subplot(G[3, 16:20])
axes_10.title.set_text('PBSA')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'PBSA'].plot(kind='barh', rot=0, ax=axes_10, stacked=True,
                                                                         legend = False, color=color)
axes_10.set_ylabel((None))
axes_10.set_xlim(0,100)
plt.setp(axes_10.get_yticklabels(), visible=False)
#axes_11 = PC
axes_11 = plt.subplot(G[3, 21:25])
axes_11.title.set_text('PC')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'PC'].plot(kind='barh', rot=0, ax=axes_11, stacked=True,
                                                                       legend = False, color=color)
axes_11.set_ylabel((None))
axes_11.set_xlim(0,100)
plt.setp(axes_11.get_yticklabels(), visible=False)
#axes_12 = PCL
axes_12 = plt.subplot(G[3, 27:31])
axes_12.title.set_text('PCL')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'PCL'].plot(kind='barh', rot=0, ax=axes_12, stacked=True,
                                                                        legend = False, color=color)
axes_12.set_yticklabels(comp)
axes_12.set_ylabel((None))
axes_12.set_xlim(0,100)
plt.setp(axes_12.get_yticklabels(), visible=False)
#axes_13 = PET
axes_13 = plt.subplot(G[3, 32:36])
axes_13.title.set_text('PET')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'PET'].plot(kind='barh', rot=0, ax=axes_13, stacked=True,
                                                                        legend = False, color=color)
axes_13.set_ylabel((None))
axes_13.set_xlim(0,100)
plt.setp(axes_13.get_yticklabels(), visible=False)
#axes_14 = PHB
axes_14 = plt.subplot(G[4, 0:5])
axes_14.title.set_text('PHB')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'PHB'].plot(kind='barh', rot=0, ax=axes_14, stacked=True,
                                                                        legend = False, color=color)
axes_14.set_yticklabels(comp)
axes_14.set_ylabel((None))
axes_14.set_xlim(0,100)
#axes_15 = PHBV
axes_15 = plt.subplot(G[4, 6:11])
axes_15.title.set_text('PHBV')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'PHBV'].plot(kind='barh', rot=0, ax=axes_15, stacked=True,
                                                                         legend = False, color=color)
axes_15.set_ylabel((None))
axes_15.set_xlim(0,100)
plt.setp(axes_15.get_yticklabels(), visible=False)
#axes_16 = PS
axes_16 = plt.subplot(G[4, 12:17])
axes_16.title.set_text('PS')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'PS'].plot(kind='barh', rot=0, ax=axes_16, stacked=True,
                                                                       legend = False, color=color)
axes_16.set_ylabel((None))
axes_16.set_xlim(0,100)
plt.setp(axes_16.get_yticklabels(), visible=False)
#axes_17 = PU
axes_17 = plt.subplot(G[4, 19:24])
axes_17.title.set_text('PU')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'PU'].plot(kind='barh', rot=0, ax=axes_17, stacked=True,
                                                                       legend = False, color=color)
axes_17.set_ylabel((None))
axes_17.set_xlim(0,100)
plt.setp(axes_17.get_yticklabels(), visible=False)
#axes_18 = PVC
axes_18 = plt.subplot(G[4, 25:30])
axes_18.title.set_text('PVC')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'PVC'].plot(kind='barh', rot=0, ax=axes_18, stacked=True,
                                                                        legend = False, color=color)
axes_18.set_ylabel((None))
axes_18.set_xlim(0,100)
plt.setp(axes_18.get_yticklabels(), visible=False)
#axes_19 = Starch-blend
axes_19 = plt.subplot(G[4, 31:36])
axes_19.title.set_text('Starch-blend')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'Starch-blend'].plot(kind='barh', rot=0, ax=axes_19,
                                                                                 stacked=True, legend = False,
                                                                                 color=color)
axes_19.set_ylabel((None))
axes_19.set_xlim(0,100)
plt.setp(axes_19.get_yticklabels(), visible=False)
#axes_20 = PBS
axes_20 = plt.subplot(G[5, 0:8])
axes_20.title.set_text('PBS')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'PBS'].plot(kind='barh', rot=0, ax=axes_20, stacked=True,
                                                                        legend = False, color=color)
axes_20.set_yticklabels(comp)
axes_20.set_ylabel((None))
axes_20.set_xlim(0,100)
axes_20.set_ylabel(('Polymers with a density ≥ 1 g/$cm^{3}$\n and similar SSDR in marine sediment'))
#axes_21 = PBSe
axes_21 = plt.subplot(G[5, 9:17])
axes_21.title.set_text('PBSe')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'PBSe'].plot(kind='barh', rot=0, ax=axes_21, stacked=True,
                                                                         legend = False, color=color)
axes_21.set_yticklabels(comp)
axes_21.set_ylabel((None))
axes_21.set_xlim(0,100)
plt.setp(axes_21.get_yticklabels(), visible=False)
#axes_22 = PBSeT
axes_22 = plt.subplot(G[5, 18:26])
axes_22.title.set_text('PBSeT')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'PBSeT'].plot(kind='barh', rot=0, ax=axes_22, stacked=True,
                                                                          legend = False, color=color)
axes_22.set_yticklabels(comp)
axes_22.set_ylabel((None))
axes_22.set_xlim(0,100)
plt.setp(axes_22.get_yticklabels(), visible=False)
#axes_23 = PHA
axes_23 = plt.subplot(G[5, 27:36])
axes_23.title.set_text('PHA')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'PHA'].plot(kind='barh', rot=0, ax=axes_23, stacked=True,
                                                                        legend = False, color=color)
axes_23.set_yticklabels(comp)
axes_23.set_ylabel((None))
axes_23.set_xlim(0,100)
plt.setp(axes_23.get_yticklabels(), visible=False)
#axes_24 = PLA(-blend)
axes_24 = plt.subplot(G[6, :])
axes_24.title.set_text('PLA(-blend)')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'PLA(-blend)'].plot(kind='barh', rot=0, ax=axes_24,
                                                                                stacked=True, legend = False,
                                                                                color=color)
axes_24.set_yticklabels(comp)
axes_24.set_xlabel(('Share of compartment-specific fate factors to the total fate factor [%]'))
axes_24.set_ylabel(('Polymers with a density ≥ 1 g/$cm^{3}$\n and high SSDR in soil'))
axes_24.set_xlim(0,100)
lines, labels = fig.axes[-1].get_legend_handles_labels()
fig.legend(lines, ('FF marine sediment', 'FF marine water', 'FF river sediment', 'FF soil'),
           bbox_to_anchor=([0.25, 0.0, 0.4, 0.1]), ncol=4, frameon=False)
fig.savefig('FF_contribution.png', dpi=300);
# Out:
# C:\Users\thni\.conda\envs\py39\lib\site-packages\pandas\plotting\_matplotlib\tools.py:395: MatplotlibDeprecationWarning:
# The is_last_row function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_last_row() instead.
#   if ax.is_last_row():

# %%
comp = ['air', 'fresh water', 'marine water', 'soil']

plt.style.use('seaborn')
fig = plt.figure(figsize=(11.7/2, 8.3/2))
plt.xlabel('test')
G = gridspec.GridSpec(ncols=2, nrows=3, figure=fig)
plt.rc('font', size=12)
color = ['#dfc27d', '#018571', '#80cdc1', '#a6611a']
#axes_1 = Group_1
axes_1 = plt.subplot(G[0, 0], sharex=axes_5)
axes_1.text(-0.1, 1.05, 'A', transform=axes_1.transAxes,
            size=12, weight='bold')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'HDPE'].plot(kind='barh', rot=0, ax=axes_1, stacked=True,
                                                                         legend=False, color=color)
axes_1.set(facecolor = "white")
axes_1.set_yticklabels(comp)
axes_1.set_ylabel((None))
axes_1.set_xlim(0, 100)
#axes_2 = Group_2
axes_2 = plt.subplot(G[0, 1], sharex=axes_6)
axes_2.text(-.1, 1.05, 'B', transform=axes_2.transAxes, size=12, weight='bold')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'PE'].plot(kind='barh', rot=0, ax=axes_2, stacked=True,
                                                                       legend=False, color=color)
axes_2.set(facecolor = "white")
axes_2.set_ylabel((None))
axes_2.set_xlim(0, 100)
plt.setp(axes_2.get_yticklabels(), visible=False)
#axes_3 = Group_3
axes_3 = plt.subplot(G[1, 0], sharex=axes_5)
axes_3.text(-0.1, 1.05, 'C', transform=axes_3.transAxes,
            size=12, weight='bold')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'NR/SBR'].plot(kind='barh', rot=0, ax=axes_3, stacked=True,
                                                                           legend=False, color=color)
axes_3.set(facecolor = "white")
axes_3.set_yticklabels(comp)
axes_3.set_ylabel((None))
axes_3.set_ylabel(('Emission to'))
axes_3.set_xlim(0, 100)
#axes_4 = Group_4
axes_4 = plt.subplot(G[1, 1], sharex=axes_6)
axes_4.text(-.1, 1.05, 'D', transform=axes_4.transAxes, size=12, weight='bold')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'PBS'].plot(kind='barh', rot=0, ax=axes_4, stacked=True,
                                                                        legend=False, color=color)
axes_4.set(facecolor = "white")
axes_4.set_ylabel((None))
axes_4.set_xlim(0, 100)
plt.setp(axes_4.get_yticklabels(), visible=False)
#axes_5 = Group_5
axes_5 = plt.subplot(G[2, 0])
axes_5.text(-0.1, 1.05, 'E', transform=axes_5.transAxes,
            size=12, weight='bold')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'PHA'].plot(kind='barh', rot=0, ax=axes_5, stacked=True,
                                                                        legend=False, color=color)
axes_5.set(facecolor = "white")
axes_5.set_yticklabels(comp)
axes_5.set_ylabel((None))
axes_5.set_xlim(0, 100)
#axes_6 = Group_6
axes_6 = plt.subplot(G[2, 1])
axes_6.text(-.1, 1.05, 'F', transform=axes_6.transAxes, size=12, weight='bold')
df_FF_reduced_limited[df_FF_reduced_limited.Polymer_type == 'PLA(-blend)'].plot(kind='barh', rot=0, ax=axes_6,
                                                                                stacked=True, legend=False, color=color)
axes_6.set(facecolor = "white")
axes_6.set_ylabel((None))
plt.xlabel(
    "Share of compartment-specific fate factors to the total fate factor [%]", x=0)
axes_6.set_xlim(0, 100)
plt.setp(axes_6.get_yticklabels(), visible=False)
lines, labels = fig.axes[-1].get_legend_handles_labels()
fig.legend(lines, ('marine sediment', 'marine water', 'river sediment', 'soil'),
           loc='center left', title='Persistance in', bbox_to_anchor=(1, 0.48, 0.1, 0.1), frameon=False, fontsize='medium')
fig.savefig('FF_contribution_small.png', bbox_inches='tight', dpi=600)

# %%
iteration = 1000
d = dict()

for i in range(0, len(df_FF)):
    name = df_FF.iloc[i]['Environmental_flow']
    FF = df_FF.iloc[i]['FF_total']
    GSDi = df_FF.iloc[i]['GSD']
    rng = np.random.default_rng(seed=5)
    d[name] = rng.lognormal(math.log(FF), math.log(GSDi), iteration)
df_FF_boxplot = pd.DataFrame(d)

df_FF_boxplot
# Out:
#      HDPE fiber 0.01-0.1 mm (emission to air)  \
# 0                                    0.898003
# 1                                    0.663785
# 2                                    1.236951
# 3                                    1.821286
# 4                                    2.755244
# ..                                        ...
# 995                                  1.655535
# 996                                  0.512281
# 997                                  1.191858
# 998                                  2.012485
# 999                                  0.999524
#
#      HDPE fiber 0.01-0.1 mm (emission to fresh water)  \
# 0                                            0.895393
# 1                                            0.660014
# 2                                            1.237002
# 3                                            1.827871
# 4                                            2.775780
# ..                                                ...
# 995                                          1.660060
# 996                                          0.508155
# 997                                          1.191500
# 998                                          2.021621
# 999                                          0.997604
#
#      HDPE fiber 0.01-0.1 mm (emission to marine water)  \
# 0                                             0.895393
# 1                                             0.660014
# 2                                             1.237002
# 3                                             1.827871
# 4                                             2.775780
# ..                                                 ...
# 995                                           1.660060
# 996                                           0.508155
# 997                                           1.191500
# 998                                           2.021621
# 999                                           0.997604
#
#      HDPE fiber 0.01-0.1 mm (emission to soil)  \
# 0                                     0.887526
# 1                                     0.650584
# 2                                     1.233385
# 3                                     1.835555
# 4                                     2.808778
# ..                                         ...
# 995                                   1.664112
# 996                                   0.498511
# 997                                   1.187203
# 998                                   2.033856
# 999                                   0.990791
#
#      HDPE fiber 0.1-1 mm (emission to air)  \
# 0                                 8.980032
# 1                                 6.637849
# 2                                12.369506
# 3                                18.212856
# 4                                27.552436
# ..                                     ...
# 995                              16.555349
# 996                               5.122808
# 997                              11.918579
# 998                              20.124849
# 999                               9.995241
#
#      HDPE fiber 0.1-1 mm (emission to fresh water)  \
# 0                                         8.953932
# 1                                         6.600139
# 2                                        12.370024
# 3                                        18.278706
# 4                                        27.757800
# ..                                             ...
# 995                                      16.600595
# 996                                       5.081552
# 997                                      11.914997
# 998                                      20.216211
# 999                                       9.976037
#
#      HDPE fiber 0.1-1 mm (emission to marine water)  \
# 0                                          8.953932
# 1                                          6.600139
# 2                                         12.370024
# 3                                         18.278706
# 4                                         27.757800
# ..                                              ...
# 995                                       16.600595
# 996                                        5.081552
# 997                                       11.914997
# 998                                       20.216211
# 999                                        9.976037
#
#      HDPE fiber 0.1-1 mm (emission to soil)  \
# 0                                  8.875261
# 1                                  6.505845
# 2                                 12.333850
# 3                                 18.355554
# 4                                 28.087781
# ..                                      ...
# 995                               16.641124
# 996                                4.985115
# 997                               11.872034
# 998                               20.338555
# 999                                9.907906
#
#      HDPE fiber 1-10 mm (emission to air)  \
# 0                               89.800322
# 1                               66.378489
# 2                              123.695059
# 3                              182.128558
# 4                              275.524362
# ..                                    ...
# 995                            165.553486
# 996                             51.228083
# 997                            119.185787
# 998                            201.248486
# 999                             99.952415
#
#      HDPE fiber 1-10 mm (emission to fresh water)  ...  \
# 0                                       89.539317  ...
# 1                                       66.001391  ...
# 2                                      123.700237  ...
# 3                                      182.787064  ...
# 4                                      277.577998  ...
# ..                                            ...  ...
# 995                                    166.005951  ...
# 996                                     50.815521  ...
# 997                                    119.149972  ...
# 998                                    202.162113  ...
# 999                                     99.760372  ...
#
#      Starch-blend particle 0.01-0.1 mm (emission to marine water)  \
# 0                                             0.226269
# 1                                             0.190558
# 2                                             0.271438
# 3                                             0.338198
# 4                                             0.427911
# ..                                                 ...
# 995                                           0.320345
# 996                                           0.164465
# 997                                           0.265769
# 998                                           0.357942
# 999                                           0.240471
#
#      Starch-blend particle 0.01-0.1 mm (emission to soil)  \
# 0                                             0.243506
# 1                                             0.216060
# 2                                             0.276403
# 3                                             0.322129
# 4                                             0.379463
# ..                                                 ...
# 995                                           0.310193
# 996                                           0.195007
# 997                                           0.272371
# 998                                           0.335109
# 999                                           0.254049
#
#      Starch-blend particle 0.1-1 mm (emission to air)  \
# 0                                            2.442647
# 1                                            2.173281
# 2                                            2.764588
# 3                                            3.210652
# 4                                            3.767918
# ..                                                ...
# 995                                          3.094366
# 996                                          1.966134
# 997                                          2.725178
# 998                                          3.336993
# 999                                          2.545920
#
#      Starch-blend particle 0.1-1 mm (emission to fresh water)  \
# 0                                             2.311736
# 1                                             1.989963
# 2                                             2.709642
# 3                                             3.282796
# 4                                             4.030941
# ..                                                 ...
# 995                                           3.131065
# 996                                           1.750013
# 997                                           2.660195
# 998                                           3.449416
# 999                                           2.437853
#
#      Starch-blend particle 0.1-1 mm (emission to marine water)  \
# 0                                             2.262693
# 1                                             1.905579
# 2                                             2.714382
# 3                                             3.381983
# 4                                             4.279113
# ..                                                 ...
# 995                                           3.203454
# 996                                           1.644654
# 997                                           2.657691
# 998                                           3.579421
# 999                                           2.404714
#
#      Starch-blend particle 0.1-1 mm (emission to soil)  \
# 0                                             2.435065
# 1                                             2.160601
# 2                                             2.764027
# 3                                             3.221292
# 4                                             3.794635
# ..                                                 ...
# 995                                           3.101933
# 996                                           1.950072
# 997                                           2.723708
# 998                                           3.351086
# 999                                           2.540485
#
#      Starch-blend particle 1-10 mm (emission to air)  \
# 0                                          24.426469
# 1                                          21.732814
# 2                                          27.645876
# 3                                          32.106523
# 4                                          37.679181
# ..                                               ...
# 995                                        30.943657
# 996                                        19.661345
# 997                                        27.251782
# 998                                        33.369925
# 999                                        25.459198
#
#      Starch-blend particle 1-10 mm (emission to fresh water)  \
# 0                                            23.117365
# 1                                            19.899626
# 2                                            27.096424
# 3                                            32.827964
# 4                                            40.309407
# ..                                                 ...
# 995                                          31.310645
# 996                                          17.500129
# 997                                          26.601946
# 998                                          34.494159
# 999                                          24.378531
#
#      Starch-blend particle 1-10 mm (emission to marine water)  \
# 0                                            22.626927
# 1                                            19.055791
# 2                                            27.143824
# 3                                            33.819832
# 4                                            42.791128
# ..                                                 ...
# 995                                          32.034536
# 996                                          16.446544
# 997                                          26.576909
# 998                                          35.794211
# 999                                          24.047140
#
#      Starch-blend particle 1-10 mm (emission to soil)
# 0                                           24.350645
# 1                                           21.606010
# 2                                           27.640272
# 3                                           32.212925
# 4                                           37.946347
# ..                                                ...
# 995                                         31.019332
# 996                                         19.500720
# 997                                         27.237077
# 998                                         33.510861
# 999                                         25.404850
#
# [1000 rows x 864 columns]

# %%
df_FF_boxplot_long = pd.concat(pd.DataFrame(
    {'Environmental_flow': k, 'Fate_factor': v}) for k, v in d.items()).reset_index(drop=True)
df_FF_boxplot_long['Polymer_type'] = df_FF_boxplot_long.Environmental_flow.apply(
    lambda x: x.split()[0])
df_FF_boxplot_long['Shape'] = df_FF_boxplot_long.Environmental_flow.apply(
    lambda x: x.split()[1])
df_FF_boxplot_long['Characteristic_length'] = df_FF_boxplot_long.Environmental_flow.apply(
    lambda x: x.split()[2] + ' ' + x.split()[3])
df_FF_boxplot_long['Initial_compartment'] = df_FF_boxplot_long.Environmental_flow.apply(
    lambda x: x.split()[4].replace('(', '') + ' ' + x.split()[5] + ' ' + x.split()[6].replace(')', ''))
df_FF_boxplot_long
# Out:
#                                       Environmental_flow  Fate_factor  \
# 0               HDPE fiber 0.01-0.1 mm (emission to air)     0.898003
# 1               HDPE fiber 0.01-0.1 mm (emission to air)     0.663785
# 2               HDPE fiber 0.01-0.1 mm (emission to air)     1.236951
# 3               HDPE fiber 0.01-0.1 mm (emission to air)     1.821286
# 4               HDPE fiber 0.01-0.1 mm (emission to air)     2.755244
# ...                                                  ...          ...
# 863995  Starch-blend particle 1-10 mm (emission to soil)    31.019332
# 863996  Starch-blend particle 1-10 mm (emission to soil)    19.500720
# 863997  Starch-blend particle 1-10 mm (emission to soil)    27.237077
# 863998  Starch-blend particle 1-10 mm (emission to soil)    33.510861
# 863999  Starch-blend particle 1-10 mm (emission to soil)    25.404850
#
#         Polymer_type     Shape Characteristic_length Initial_compartment
# 0               HDPE     fiber           0.01-0.1 mm     emission to air
# 1               HDPE     fiber           0.01-0.1 mm     emission to air
# 2               HDPE     fiber           0.01-0.1 mm     emission to air
# 3               HDPE     fiber           0.01-0.1 mm     emission to air
# 4               HDPE     fiber           0.01-0.1 mm     emission to air
# ...              ...       ...                   ...                 ...
# 863995  Starch-blend  particle               1-10 mm    emission to soil
# 863996  Starch-blend  particle               1-10 mm    emission to soil
# 863997  Starch-blend  particle               1-10 mm    emission to soil
# 863998  Starch-blend  particle               1-10 mm    emission to soil
# 863999  Starch-blend  particle               1-10 mm    emission to soil
#
# [864000 rows x 6 columns]

# %%
df_FF_boxplot_long_limited = df_FF_boxplot_long.loc[(df_FF_boxplot_long['Characteristic_length'] == '0.01-0.1 mm') & (
    df_FF_boxplot_long['Shape'] == 'particle'), ['Environmental_flow', 'Fate_factor', 'Polymer_type', 'Shape', 'Initial_compartment']]
df_FF_boxplot_long_limited
# Out:
#                                        Environmental_flow  Fate_factor  \
# 24000         HDPE particle 0.01-0.1 mm (emission to air)     0.673502
# 24001         HDPE particle 0.01-0.1 mm (emission to air)     0.497839
# 24002         HDPE particle 0.01-0.1 mm (emission to air)     0.927713
# 24003         HDPE particle 0.01-0.1 mm (emission to air)     1.365964
# 24004         HDPE particle 0.01-0.1 mm (emission to air)     2.066433
# ...                                                   ...          ...
# 855995  Starch-blend particle 0.01-0.1 mm (emission to...     0.310193
# 855996  Starch-blend particle 0.01-0.1 mm (emission to...     0.195007
# 855997  Starch-blend particle 0.01-0.1 mm (emission to...     0.272371
# 855998  Starch-blend particle 0.01-0.1 mm (emission to...     0.335109
# 855999  Starch-blend particle 0.01-0.1 mm (emission to...     0.254049
#
#         Polymer_type     Shape Initial_compartment
# 24000           HDPE  particle     emission to air
# 24001           HDPE  particle     emission to air
# 24002           HDPE  particle     emission to air
# 24003           HDPE  particle     emission to air
# 24004           HDPE  particle     emission to air
# ...              ...       ...                 ...
# 855995  Starch-blend  particle    emission to soil
# 855996  Starch-blend  particle    emission to soil
# 855997  Starch-blend  particle    emission to soil
# 855998  Starch-blend  particle    emission to soil
# 855999  Starch-blend  particle    emission to soil
#
# [96000 rows x 5 columns]

# %%
g = sns.catplot(x="Initial_compartment", y="Fate_factor", col_wrap=6,
                col="Polymer_type", sharey=False,
                data=df_FF_boxplot_long_limited, kind="box",
                height=10, aspect=.7)
g.set_xticklabels(rotation=30)

g.savefig('boxplot_cat.png', dpi=300)

# %%
filter_col = [col for col in df_FF_boxplot if col.startswith(
    'HDPE') and '0.01-0.1' in col]
filter_col
df_FF_boxplot_HDPE = df_FF_boxplot[filter_col]

# %%
FF_dict = dict()

for i in range(0, len(df_FF)):
    name = df_FF.iloc[i]['Environmental_flow'].split()[0]
    GSDi = df_FF.loc[(
        df_FF['Environmental_flow'].str.startswith(name + ' ')), ['GSD']]
    GSDi = GSDi['GSD'].values.tolist()
    FF_dict[name] = GSDi
FF_GSD_boxplot = pd.DataFrame.from_dict(FF_dict)
sorted_index = FF_GSD_boxplot.median().sort_values().index
FF_GSD_boxplot_sorted = FF_GSD_boxplot[sorted_index]

# %%
sns.set(font_scale=1.5)
g = sns.catplot(data=FF_GSD_boxplot, orient="v", kind="box")

g.set(xlabel='Plastic type', ylabel='Geometric standard deviation of Fate factors')
g.fig.set_figwidth(40)
g.fig.set_figheight(10)

g.savefig('boxplot_PE_FF.png', dpi=600)

# %%
FF_GSD_boxplot_sorted = FF_GSD_boxplot_sorted.rename(columns={'Starch-blend': 'Starch\n-blend',
                                                              'PLA(-blend)': 'PLA\n(-blend)',
                                                              'NR/SBR': 'NR/\nSBR'})

df_new = df.rename(columns={'A': 'Col_1'}, index={'ONE': 'Row_1'})
sns.set(font_scale=1.9)
sns.set_style("whitegrid")

g = sns.catplot(data=FF_GSD_boxplot_sorted, orient="v",
                kind="box", color='#018571')
g.set(xlabel='Plastic type', ylabel='Geometric standard deviation of fate factors')
# g.set_xticklabels(rotation=30)
g.fig.set_figwidth(30)
g.fig.set_figheight(10)

g.savefig('FF_GSD_boxplot_sorted.png', dpi=600)

# %%
df['Polymer type'] = df['Polymer type'].replace(
    ['Starch-blend', 'PLA(-blend)', 'NR/SBR'], ['Starch\n-blend', 'PLA\n(-blend)', 'NR/\nSBR'])
non_expert = df[df['SSDR expert judgment based on'].isna() & (
    df['Source'] != "Experts' estimate")]
expert = df[(df['SSDR expert judgment based on'].notnull())
            | (df['Source'] == "Experts' estimate")]
color = ['#018571', '#dfc27d', '#a6611a', '#80cdc1']
legend_elements = [Line2D([0], [0], linewidth=0, marker='o', color='#dfc27d', label='marine sediment', markersize=8),
                   Line2D([0], [0], linewidth=0, marker='o',
                          color='#018571', label='marine water', markersize=8),
                   Line2D([0], [0], linewidth=0, marker='o',
                          color='#80cdc1', label='river sediment', markersize=8),
                   Line2D([0], [0], linewidth=0, marker='o',
                          color='#a6611a', label='soil', markersize=8),
                   Line2D([0], [0], linewidth=0, marker='^', color='#dfc27d',
                          label='marine sediment', markersize=8),
                   Line2D([0], [0], linewidth=0, marker='^',
                          color='#018571', label='marine water', markersize=8),
                   Line2D([0], [0], linewidth=0, marker='^',
                          color='#80cdc1', label='river sediment', markersize=8),
                   Line2D([0], [0], linewidth=0, marker='^', color='#a6611a', label='soil', markersize=8)]
df_sorted = df.sort_values(by='SSDR')
poly_sorted_by_SSDR = df_sorted['Polymer type'].unique().tolist()
poly_sorted_by_SSDR

sns.set(font_scale=2, rc={'figure.figsize': (30, 10)})
sns.set_style("whitegrid")
g = sns.stripplot(x="Polymer type", y="SSDR", hue='Compartment', palette=sns.color_palette(color),
                  data=non_expert, size=10, jitter=0.2, order=poly_sorted_by_SSDR)
n = sns.stripplot(x="Polymer type", y="SSDR", hue='Compartment', palette=sns.color_palette(color),
                  data=expert, marker='^', size=10, jitter=0.2, order=poly_sorted_by_SSDR)
n.set(xlabel='Plastic type',
      ylabel='SSDR [µ*$a^{-1}$]', ylim=(10**(-3.5), 10**4))
plot = g.get_figure()
n.set_yscale('log')
n.legend(title='Literature values              Expert estimates',
         handles=legend_elements, ncol=2, frameon=False)
poly_sorted_by_SSDR[1] = 'PLA\n(-blend)'
plot = n.get_figure()

plot.savefig('SSDR.png', dpi=600, bbox_inches='tight')
